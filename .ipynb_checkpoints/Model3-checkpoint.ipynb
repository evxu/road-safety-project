# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import folium
import time
from IPython.display import display
# %matplotlib inline
matplotlib.style.use('ggplot')
# Out:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
olddata1 = np.load('data4/num_accident2_2009-2015.npy')
olddata2 = np.load('data4/num_accident_tri_OHweekday_2009-2015.npy')
newdata = np.zeros(shape = (2352, 9))
newdata[:, 0:6] = olddata2[:,0:6]
newdata[:, 7] = (olddata1[:,1] - 0.5)/23.5
m = np.mean(olddata1[:,2])
st = np.std(olddata1[:,2])
print (m)
print (st)
newdata[:, 8] = (olddata1[:,2] - m)/st
np.save('data4/num_accident_OH_norm2.npy', newdata)
# Out:
# 43.699829932
# 30.3345860169

# %% [markdown]
# ### Validation
# start with 10 - 30

# %%
import warnings
warnings.filterwarnings('ignore')

olddata = np.load('data4/num_accident_OH_norm2.npy')

week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
models = []
total_loss = np.zeros(7)
#nfig = 1
#plt.figure(figsize = (12,10))
n = range(10, 50)  # number of degree
loss = np.zeros(40) # record loss of different degree
n_model = 0
for d in n:
    start = 0
    for wd in range(7):
        # Abstract each weekday data
        newdata = np.zeros(shape = (336,2))
        i = start
        j = 0
        while j<7:
            newdata[j*48:j*48+48, :] = olddata[i:i+48, -2:]
            j+=1
            i+=336
        npdata = newdata
        x = npdata[0:240, 0]
        y = npdata[0:240, 1]
        z = np.polyfit(x, y, d)
        fitline = np.poly1d(z)
        models.append(fitline)

    #     plt.subplot(3,3,nfig)
    #     plt.plot(fitline(npdata[240:288, 0]), color = 'r', label = 'prediction')
    #     plt.plot(npdata[240:288, -1], color = 'k', label = 'observation')
    #     plt.xlabel('time slot')
    #     plt.ylabel('number of accident(normalised)')
        plt.title(week[wd])
        # compute test loss
        pre = fitline(npdata[240:288, 0])
        ob = npdata[240:288, -1]
        test_err = (pre - ob)**2
        test_err = np.mean(test_err)
        #print ('{}test loss:\t\t\t{}'.format(week[wd], test_err))
        total_loss[wd] = test_err
        start += 48
        nfig += 1

    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    print ('{} degree - average error:\t\t\t{}'.format(d, total_loss.mean()))
    loss[n_model] = total_loss.mean()
    n_model += 1

plt.plot(loss)
# Out:
# 10 degree - average error:			0.192912381878
# 11 degree - average error:			0.192429619232
# 12 degree - average error:			0.189984918897
# 13 degree - average error:			0.170924117587
# 14 degree - average error:			0.16461728517
# 15 degree - average error:			0.149543542838
# 16 degree - average error:			0.145316907759
# 17 degree - average error:			0.143870789037
# 18 degree - average error:			0.144173969416
# 19 degree - average error:			0.142721604498
# 20 degree - average error:			0.143200434739
# 21 degree - average error:			0.142657137818
# 22 degree - average error:			0.14282405747
# 23 degree - average error:			0.143127154129
# 24 degree - average error:			0.141764093031
# 25 degree - average error:			0.140937224311
# 26 degree - average error:			0.140133690433
# 27 degree - average error:			0.13948053159
# 28 degree - average error:			0.138835966913
# 29 degree - average error:			0.139185690831
# 30 degree - average error:			0.139361534229
# 31 degree - average error:			0.139373681169
# 32 degree - average error:			0.139263695574
# 33 degree - average error:			0.138416454495
# 34 degree - average error:			0.138774647516
# 35 degree - average error:			0.139114006613
# 36 degree - average error:			0.139397208308
# 37 degree - average error:			0.139598548012
# 38 degree - average error:			0.139705724172
# 39 degree - average error:			0.136923007047
# 40 degree - average error:			0.136931442102
# 41 degree - average error:			0.136976464318
# 42 degree - average error:			0.137048686328
# 43 degree - average error:			0.137145349836
# 44 degree - average error:			0.13725315596
# 45 degree - average error:			0.137363435269
# 46 degree - average error:			0.137467911337
# 47 degree - average error:			0.136837464739
# 48 degree - average error:			0.136805271932
# 49 degree - average error:			0.136779251928

# %% [markdown]
# ### test

# %%
olddata = np.load('data4/num_accident_OH_norm2.npy')
start = time.clock()
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
models = []
total_loss = np.zeros(7)
start = 0
nfig = 1
plt.figure(figsize = (12,10))
for wd in range(7):
    # Abstract each weekday data
    print (week[wd] + ':')
    newdata = np.zeros(shape = (336,2))
    i = start
    j = 0
    while j<7:
        newdata[j*48:j*48+48, :] = olddata[i:i+48, -2:]
        j+=1
        i+=336
    npdata = newdata
    x = npdata[0:288, 0]
    y = npdata[0:288, 1]
    z = np.polyfit(x, y, 25)
    fitline = np.poly1d(z)
    models.append(fitline)
    
    plt.subplot(3,3,nfig)
    plt.plot(fitline(npdata[288:336, 0]), color = 'r', label = 'prediction')
    plt.plot(npdata[288:336, -1], color = 'k', label = 'observation')
#     plt.xlabel('time slot')
#     plt.ylabel('number of accident(normalised)')
    plt.title(week[wd])
    # compute test loss
    pre = fitline(npdata[288:336, 0])
    ob = npdata[288:336, -1]
    test_err = (pre - ob)**2
    test_err = np.mean(test_err)
    print ('{}test loss:\t\t\t{}'.format(week[wd], test_err))
    total_loss[wd] = test_err
    start += 48
    nfig += 1

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('image/polynomial_fit2.eps',format="eps",transparent=True, grid = True, bbox_inches='tight', pad_inches=0.1)
print ('Average error on all weekday:\t\t\t{}'.format(total_loss.mean()))

end = time.clock()
print ("cost time: {:10.6} s".format(end - start))
# Out:
# Sunday:
# Sundaytest loss:			0.0843963379143
# Monday:
# Mondaytest loss:			0.165274982197
# Tuesday:
# Tuesdaytest loss:			0.197196196224
# Wednesday:
# Wednesdaytest loss:			0.1535663454
# Thursday:
# Thursdaytest loss:			0.122868977529
# Friday:
# Fridaytest loss:			0.214062126206
# Saturday:
# Saturdaytest loss:			0.100220626371
# Average error on all weekday:			0.14822651312
# cost time:    1279.87 s

# %%
from __future__ import print_function

import sys
import os
import time

import numpy as np
import theano
import theano.tensor as T

import lasagne

# ############################# Batch iterator ###############################
# This is just a simple helper function iterating over training data in
# mini-batches of a particular size, optionally in random order. It assumes
# data is available as numpy arrays. For big datasets, you could load numpy
# arrays as memory-mapped files (np.load(..., mmap_mode='r')), or write your
# own custom data iteration function. For small datasets, you can also copy
# them to GPU at once for slightly improved performance. This would involve
# several changes in the main program, though, and is not demonstrated here.
# Notice that this function returns only mini-batches of size `batchsize`.
# If the size of the data is not a multiple of `batchsize`, it will not
# return the last (remaining) mini-batch.

def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]


def train_mlp(model='mlp', num_epochs=50, learning_rate=0.001, train_shuffle=True, batchsize = 336):
    # Load the dataset
    print("Loading data...")
    X_train, y_train, X_val, y_val, X_test, y_test = load_dataset()

    # Prepare Theano variables for inputs and targets
    input_var = T.tensor3('inputs')
    target_var = T.matrix('targets')

    # Create neural network model (depending on first command line parameter)
    print("Building model and compiling functions...")
    
    network = build_mlp(input_var)
    

    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss = lasagne.objectives.squared_error(prediction, target_var)
    loss = loss.mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(
            loss, params, learning_rate=learning_rate, momentum=0.9)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    test_loss = lasagne.objectives.squared_error(test_prediction,
                                                            target_var)
    test_loss = test_loss.mean()
    
    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates, allow_input_downcast = True)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], test_loss, allow_input_downcast = True)

    # Finally, launch the training loop.
    print("Starting training...")
    # We iterate over epochs:
    
    train_loss = np.zeros(num_epochs)
    val_loss = np.zeros(num_epochs)
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time.time()
        for batch in iterate_minibatches(X_train, y_train, batchsize = batchsize, shuffle=train_shuffle):
            inputs, targets = batch
            train_err += train_fn(inputs, targets)
            train_batches += 1

        # And a full pass over the validation data:
        val_err = 0
        val_batches = 0
        for batch in iterate_minibatches(X_val, y_val, y_val.shape[0], shuffle=False):
            inputs, targets = batch
            #print (inputs.shape, targets.shape)
            err = val_fn(inputs, targets)
            val_err += err
            val_batches += 1
        
        # save the loss value
        train_loss[epoch] = train_err / train_batches
        val_loss[epoch] = val_err / val_batches
        
        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss:\t\t{:.6f}".format(train_loss[epoch]))
        print("  validation loss:\t\t{:.6f}".format(val_loss[epoch]))    

    # After training, we compute and print the test error:
    test_err = 0
    test_batches = 0
    for batch in iterate_minibatches(X_test, y_test, y_test.shape[0], shuffle=False):
        inputs, targets = batch
        err = val_fn(inputs, targets)
        test_err += err
        test_batches += 1
    print("Final results:")
    print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
    return network, train_loss, val_loss
# Optionally, you could now dump the network weights to a file like this:
# np.savez('model.npz', *lasagne.layers.get_all_param_values(network))
#
# And load them again later on like this:
# with np.load('model.npz') as f:
#     param_values = [f['arr_%d' % i] for i in range(len(f.files))]
# lasagne.layers.set_all_param_values(network, param_values)
# Out:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### ANN network

# %%
def load_dataset():
    npdata = np.load('data4/num_accident_OH_norm2.npy')
    npdata = npdata.astype(np.float32)
    X_train, X_val = npdata[0:1680, 0:-1].reshape(1680,1,8), npdata[1680:2016, 0:-1].reshape(336,1,8)
    y_train, y_val = npdata[0:1680, -1].reshape(1680,1), npdata[1680:2016, -1].reshape(336,1)
    x_test, y_test = npdata[2016:2352, 0:-1].reshape(336,1,8), npdata[2016:2352, -1].reshape(336,1)
    #print (X_train.shape, y_train.shape, X_val.shape, y_val.shape, npdata.shape)
    return X_train, y_train, X_val, y_val, x_test, y_test


def build_mlp(input_var=None, units = 15):
    
    # Input layer, specifying the expected input shape of the network
    l_in = lasagne.layers.InputLayer(shape=(None,1,8),
                                     input_var=input_var)

    l_hid1 = lasagne.layers.LSTMLayer(
            l_in, num_units = units)
    
    l_hid2 = lasagne.layers.DenseLayer(
            l_hid1, num_units = units,
            nonlinearity=lasagne.nonlinearities.sigmoid,
            W=lasagne.init.GlorotUniform())
    
    l_hid3 = lasagne.layers.DenseLayer(
            l_hid2, num_units = units,
            nonlinearity=lasagne.nonlinearities.sigmoid,
            W=lasagne.init.GlorotUniform())
        
    l_out = lasagne.layers.DenseLayer(
            l_hid3, num_units=1,
            nonlinearity=lasagne.nonlinearities.linear)

    return l_out

start = time.clock()
network, train_loss, val_loss = train_mlp(num_epochs=2500, learning_rate=0.02)
end = time.clock()
print ("cost time: {:10.6} s".format(end - start))
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 2500 took 0.025s
#   training loss:		1.023840
#   validation loss:		1.011956
# Epoch 2 of 2500 took 0.022s
#   training loss:		1.010973
#   validation loss:		1.001047
# Epoch 3 of 2500 took 0.024s
#   training loss:		1.008780
#   validation loss:		1.001658
# Epoch 4 of 2500 took 0.024s
#   training loss:		1.008143
#   validation loss:		1.003204
# Epoch 5 of 2500 took 0.024s
#   training loss:		1.008551
#   validation loss:		1.000963
# Epoch 6 of 2500 took 0.023s
#   training loss:		1.008319
#   validation loss:		1.002175
# Epoch 7 of 2500 took 0.023s
#   training loss:		1.008889
#   validation loss:		1.001029
# Epoch 8 of 2500 took 0.024s
#   training loss:		1.009768
#   validation loss:		1.001789
# Epoch 9 of 2500 took 0.022s
#   training loss:		1.008715
#   validation loss:		1.002811
# Epoch 10 of 2500 took 0.025s
#   training loss:		1.009220
#   validation loss:		1.000871
# Epoch 11 of 2500 took 0.029s
#   training loss:		1.008635
#   validation loss:		1.001192
# Epoch 12 of 2500 took 0.023s
#   training loss:		1.008192
#   validation loss:		1.004896
# Epoch 13 of 2500 took 0.024s
#   training loss:		1.010480
#   validation loss:		1.000741
# Epoch 14 of 2500 took 0.024s
#   training loss:		1.008749
#   validation loss:		1.000719
# Epoch 15 of 2500 took 0.024s
#   training loss:		1.007981
#   validation loss:		1.003115
# Epoch 16 of 2500 took 0.025s
#   training loss:		1.008460
#   validation loss:		1.000912
# Epoch 17 of 2500 took 0.023s
#   training loss:		1.008060
#   validation loss:		1.001181
# Epoch 18 of 2500 took 0.024s
#   training loss:		1.008607
#   validation loss:		1.001397
# Epoch 19 of 2500 took 0.025s
#   training loss:		1.008377
#   validation loss:		1.002580
# Epoch 20 of 2500 took 0.026s
#   training loss:		1.008025
#   validation loss:		1.002256
# Epoch 21 of 2500 took 0.023s
#   training loss:		1.008599
#   validation loss:		1.002847
# Epoch 22 of 2500 took 0.023s
#   training loss:		1.008752
#   validation loss:		1.001417
# Epoch 23 of 2500 took 0.020s
#   training loss:		1.007723
#   validation loss:		1.001190
# Epoch 24 of 2500 took 0.021s
#   training loss:		1.008544
#   validation loss:		1.002553
# Epoch 25 of 2500 took 0.022s
#   training loss:		1.008175
#   validation loss:		1.003461
# Epoch 26 of 2500 took 0.021s
#   training loss:		1.008876
#   validation loss:		1.000668
# Epoch 27 of 2500 took 0.022s
#   training loss:		1.009394
#   validation loss:		1.000649
# Epoch 28 of 2500 took 0.024s
#   training loss:		1.007648
#   validation loss:		1.003577
# Epoch 29 of 2500 took 0.025s
#   training loss:		1.010354
#   validation loss:		1.000483
# Epoch 30 of 2500 took 0.024s
#   training loss:		1.010218
#   validation loss:		1.001611
# Epoch 31 of 2500 took 0.024s
#   training loss:		1.007764
#   validation loss:		1.001624
# Epoch 32 of 2500 took 0.023s
#   training loss:		1.008285
#   validation loss:		1.001765
# Epoch 33 of 2500 took 0.023s
#   training loss:		1.007580
#   validation loss:		1.000392
# Epoch 34 of 2500 took 0.024s
#   training loss:		1.008055
#   validation loss:		1.000227
# Epoch 35 of 2500 took 0.025s
#   training loss:		1.008547
#   validation loss:		1.001152
# Epoch 36 of 2500 took 0.024s
#   training loss:		1.008195
#   validation loss:		1.000672
# Epoch 37 of 2500 took 0.025s
#   training loss:		1.007601
#   validation loss:		1.001573
# Epoch 38 of 2500 took 0.025s
#   training loss:		1.008018
#   validation loss:		1.002503
# Epoch 39 of 2500 took 0.025s
#   training loss:		1.008510
#   validation loss:		1.000114
# Epoch 40 of 2500 took 0.025s
#   training loss:		1.007835
#   validation loss:		1.000048
# Epoch 41 of 2500 took 0.022s
#   training loss:		1.008231
#   validation loss:		1.000300
# Epoch 42 of 2500 took 0.022s
#   training loss:		1.008645
#   validation loss:		1.000201
# Epoch 43 of 2500 took 0.023s
#   training loss:		1.008753
#   validation loss:		1.000034
# Epoch 44 of 2500 took 0.024s
#   training loss:		1.007490
#   validation loss:		1.000085
# Epoch 45 of 2500 took 0.024s
#   training loss:		1.006765
#   validation loss:		1.001954
# Epoch 46 of 2500 took 0.024s
#   training loss:		1.007779
#   validation loss:		0.999981
# Epoch 47 of 2500 took 0.023s
#   training loss:		1.007654
#   validation loss:		1.000089
# Epoch 48 of 2500 took 0.023s
#   training loss:		1.009799
#   validation loss:		0.999883
# Epoch 49 of 2500 took 0.023s
#   training loss:		1.008129
#   validation loss:		1.002432
# Epoch 50 of 2500 took 0.024s
#   training loss:		1.009885
#   validation loss:		0.999702
# Epoch 51 of 2500 took 0.025s
#   training loss:		1.008040
#   validation loss:		0.999730
# Epoch 52 of 2500 took 0.020s
#   training loss:		1.008710
#   validation loss:		1.006034
# Epoch 53 of 2500 took 0.022s
#   training loss:		1.009721
#   validation loss:		1.004614
# Epoch 54 of 2500 took 0.022s
#   training loss:		1.008057
#   validation loss:		1.000245
# Epoch 55 of 2500 took 0.022s
#   training loss:		1.006418
#   validation loss:		0.999625
# Epoch 56 of 2500 took 0.021s
#   training loss:		1.007398
#   validation loss:		1.001314
# Epoch 57 of 2500 took 0.022s
#   training loss:		1.007159
#   validation loss:		1.002203
# Epoch 58 of 2500 took 0.024s
#   training loss:		1.008534
#   validation loss:		1.001037
# Epoch 59 of 2500 took 0.029s
#   training loss:		1.007361
#   validation loss:		1.001314
# Epoch 60 of 2500 took 0.022s
#   training loss:		1.008207
#   validation loss:		0.999513
# Epoch 61 of 2500 took 0.023s
#   training loss:		1.008882
#   validation loss:		1.000985
# Epoch 62 of 2500 took 0.025s
#   training loss:		1.010405
#   validation loss:		0.999235
# Epoch 63 of 2500 took 0.022s
#   training loss:		1.006764
#   validation loss:		0.999841
# Epoch 64 of 2500 took 0.025s
#   training loss:		1.005969
#   validation loss:		1.000743
# Epoch 65 of 2500 took 0.025s
#   training loss:		1.006905
#   validation loss:		0.999239
# Epoch 66 of 2500 took 0.025s
#   training loss:		1.007125
#   validation loss:		1.000299
# Epoch 67 of 2500 took 0.025s
#   training loss:		1.009118
#   validation loss:		0.998973
# Epoch 68 of 2500 took 0.023s
#   training loss:		1.007527
#   validation loss:		1.000433
# Epoch 69 of 2500 took 0.021s
#   training loss:		1.007446
#   validation loss:		1.001758
# Epoch 70 of 2500 took 0.024s
#   training loss:		1.008112
#   validation loss:		1.001371
# Epoch 71 of 2500 took 0.024s
#   training loss:		1.007941
#   validation loss:		0.998749
# Epoch 72 of 2500 took 0.023s
#   training loss:		1.006431
#   validation loss:		0.999467
# Epoch 73 of 2500 took 0.026s
#   training loss:		1.007807
#   validation loss:		0.999257
# Epoch 74 of 2500 took 0.022s
#   training loss:		1.007535
#   validation loss:		0.998817
# Epoch 75 of 2500 took 0.024s
#   training loss:		1.005786
#   validation loss:		0.999195
# Epoch 76 of 2500 took 0.025s
#   training loss:		1.007554
#   validation loss:		0.998673
# Epoch 77 of 2500 took 0.022s
#   training loss:		1.005645
#   validation loss:		1.000636
# Epoch 78 of 2500 took 0.025s
#   training loss:		1.006263
#   validation loss:		1.001301
# Epoch 79 of 2500 took 0.025s
#   training loss:		1.008476
#   validation loss:		0.999851
# Epoch 80 of 2500 took 0.024s
#   training loss:		1.005074
#   validation loss:		0.998179
# Epoch 81 of 2500 took 0.023s
#   training loss:		1.006360
#   validation loss:		1.001907
# Epoch 82 of 2500 took 0.026s
#   training loss:		1.007040
#   validation loss:		0.998016
# Epoch 83 of 2500 took 0.022s
#   training loss:		1.007483
#   validation loss:		1.000842
# Epoch 84 of 2500 took 0.024s
#   training loss:		1.007319
#   validation loss:		0.999173
# Epoch 85 of 2500 took 0.022s
#   training loss:		1.005068
#   validation loss:		0.997991
# Epoch 86 of 2500 took 0.022s
#   training loss:		1.004806
#   validation loss:		0.998451
# Epoch 87 of 2500 took 0.021s
#   training loss:		1.006913
#   validation loss:		0.998985
# Epoch 88 of 2500 took 0.021s
#   training loss:		1.005053
#   validation loss:		0.997521
# Epoch 89 of 2500 took 0.021s
#   training loss:		1.005174
#   validation loss:		0.998671
# Epoch 90 of 2500 took 0.024s
#   training loss:		1.005353
#   validation loss:		0.998578
# Epoch 91 of 2500 took 0.023s
#   training loss:		1.005667
#   validation loss:		1.000371
# Epoch 92 of 2500 took 0.023s
#   training loss:		1.005978
#   validation loss:		0.998543
# Epoch 93 of 2500 took 0.022s
#   training loss:		1.005784
#   validation loss:		0.999911
# Epoch 94 of 2500 took 0.021s
#   training loss:		1.005048
#   validation loss:		0.999057
# Epoch 95 of 2500 took 0.023s
#   training loss:		1.004449
#   validation loss:		0.996941
# Epoch 96 of 2500 took 0.022s
#   training loss:		1.005326
#   validation loss:		0.996996
# Epoch 97 of 2500 took 0.022s
#   training loss:		1.004682
#   validation loss:		0.996948
# Epoch 98 of 2500 took 0.021s
#   training loss:		1.003901
#   validation loss:		0.996479
# Epoch 99 of 2500 took 0.022s
#   training loss:		1.004381
#   validation loss:		0.998465
# Epoch 100 of 2500 took 0.020s
#   training loss:		1.003937
#   validation loss:		0.998859
# Epoch 101 of 2500 took 0.022s
#   training loss:		1.005406
#   validation loss:		0.996721
# Epoch 102 of 2500 took 0.024s
#   training loss:		1.003431
#   validation loss:		0.996263
# Epoch 103 of 2500 took 0.024s
#   training loss:		1.004791
#   validation loss:		0.997917
# Epoch 104 of 2500 took 0.025s
#   training loss:		1.005271
#   validation loss:		0.996125
# Epoch 105 of 2500 took 0.023s
#   training loss:		1.003497
#   validation loss:		0.997301
# Epoch 106 of 2500 took 0.026s
#   training loss:		1.003353
#   validation loss:		0.996052
# Epoch 107 of 2500 took 0.025s
#   training loss:		1.010438
#   validation loss:		0.999955
# Epoch 108 of 2500 took 0.024s
#   training loss:		1.003421
#   validation loss:		0.995457
# Epoch 109 of 2500 took 0.023s
#   training loss:		1.003352
#   validation loss:		0.995328
# Epoch 110 of 2500 took 0.023s
#   training loss:		1.003795
#   validation loss:		0.994986
# Epoch 111 of 2500 took 0.023s
#   training loss:		1.002129
#   validation loss:		0.994996
# Epoch 112 of 2500 took 0.022s
#   training loss:		1.001564
#   validation loss:		0.997131
# Epoch 113 of 2500 took 0.022s
#   training loss:		1.002683
#   validation loss:		0.996558
# Epoch 114 of 2500 took 0.021s
#   training loss:		1.002218
#   validation loss:		0.995633
# Epoch 115 of 2500 took 0.020s
#   training loss:		1.001753
#   validation loss:		0.994059
# Epoch 116 of 2500 took 0.024s
#   training loss:		1.001281
#   validation loss:		0.993897
# Epoch 117 of 2500 took 0.022s
#   training loss:		1.004516
#   validation loss:		0.993695
# Epoch 118 of 2500 took 0.021s
#   training loss:		1.000131
#   validation loss:		0.995502
# Epoch 119 of 2500 took 0.021s
#   training loss:		1.000856
#   validation loss:		0.994193
# Epoch 120 of 2500 took 0.023s
#   training loss:		1.001944
#   validation loss:		0.993115
# Epoch 121 of 2500 took 0.022s
#   training loss:		1.001165
#   validation loss:		0.993992
# Epoch 122 of 2500 took 0.022s
#   training loss:		1.001515
#   validation loss:		0.994377
# Epoch 123 of 2500 took 0.023s
#   training loss:		0.999905
#   validation loss:		0.993752
# Epoch 124 of 2500 took 0.021s
#   training loss:		0.999052
#   validation loss:		0.992167
# Epoch 125 of 2500 took 0.024s
#   training loss:		0.999335
#   validation loss:		0.992240
# Epoch 126 of 2500 took 0.023s
#   training loss:		0.999895
#   validation loss:		0.994494
# Epoch 127 of 2500 took 0.023s
#   training loss:		1.003430
#   validation loss:		0.990950
# Epoch 128 of 2500 took 0.024s
#   training loss:		0.998717
#   validation loss:		0.990895
# Epoch 129 of 2500 took 0.025s
#   training loss:		0.998846
#   validation loss:		0.992246
# Epoch 130 of 2500 took 0.024s
#   training loss:		0.998988
#   validation loss:		0.990103
# Epoch 131 of 2500 took 0.022s
#   training loss:		0.997267
#   validation loss:		0.989617
# Epoch 132 of 2500 took 0.022s
#   training loss:		0.997264
#   validation loss:		0.989418
# Epoch 133 of 2500 took 0.023s
#   training loss:		0.996833
#   validation loss:		0.989241
# Epoch 134 of 2500 took 0.021s
#   training loss:		0.997368
#   validation loss:		0.988775
# Epoch 135 of 2500 took 0.024s
#   training loss:		0.998412
#   validation loss:		0.992161
# Epoch 136 of 2500 took 0.022s
#   training loss:		0.997750
#   validation loss:		0.988634
# Epoch 137 of 2500 took 0.021s
#   training loss:		0.994710
#   validation loss:		0.987359
# Epoch 138 of 2500 took 0.022s
#   training loss:		0.994671
#   validation loss:		0.989509
# Epoch 139 of 2500 took 0.024s
#   training loss:		0.994710
#   validation loss:		0.986517
# Epoch 140 of 2500 took 0.023s
#   training loss:		0.993546
#   validation loss:		0.986297
# Epoch 141 of 2500 took 0.022s
#   training loss:		0.993990
#   validation loss:		0.986203
# Epoch 142 of 2500 took 0.025s
#   training loss:		0.992545
#   validation loss:		0.987080
# Epoch 143 of 2500 took 0.024s
#   training loss:		0.992130
#   validation loss:		0.984472
# Epoch 144 of 2500 took 0.023s
#   training loss:		0.991928
#   validation loss:		0.985673
# Epoch 145 of 2500 took 0.022s
#   training loss:		0.993088
#   validation loss:		0.984356
# Epoch 146 of 2500 took 0.023s
#   training loss:		0.992016
#   validation loss:		0.982518
# Epoch 147 of 2500 took 0.022s
#   training loss:		0.990059
#   validation loss:		0.982257
# Epoch 148 of 2500 took 0.027s
#   training loss:		0.988279
#   validation loss:		0.981419
# Epoch 149 of 2500 took 0.024s
#   training loss:		0.989735
#   validation loss:		0.980462
# Epoch 150 of 2500 took 0.022s
#   training loss:		0.988082
#   validation loss:		0.981178
# Epoch 151 of 2500 took 0.024s
#   training loss:		0.987667
#   validation loss:		0.979724
# Epoch 152 of 2500 took 0.022s
#   training loss:		0.986385
#   validation loss:		0.980988
# Epoch 153 of 2500 took 0.022s
#   training loss:		0.985381
#   validation loss:		0.977580
# Epoch 154 of 2500 took 0.023s
#   training loss:		0.983866
#   validation loss:		0.976236
# Epoch 155 of 2500 took 0.021s
#   training loss:		0.982637
#   validation loss:		0.975616
# Epoch 156 of 2500 took 0.022s
#   training loss:		0.981824
#   validation loss:		0.975223
# Epoch 157 of 2500 took 0.022s
#   training loss:		0.981271
#   validation loss:		0.973880
# Epoch 158 of 2500 took 0.022s
#   training loss:		0.980399
#   validation loss:		0.971941
# Epoch 159 of 2500 took 0.021s
#   training loss:		0.979538
#   validation loss:		0.971631
# Epoch 160 of 2500 took 0.022s
#   training loss:		0.978075
#   validation loss:		0.972180
# Epoch 161 of 2500 took 0.022s
#   training loss:		0.976939
#   validation loss:		0.970322
# Epoch 162 of 2500 took 0.021s
#   training loss:		0.975458
#   validation loss:		0.967466
# Epoch 163 of 2500 took 0.026s
#   training loss:		0.973980
#   validation loss:		0.965634
# Epoch 164 of 2500 took 0.022s
#   training loss:		0.972804
#   validation loss:		0.965940
# Epoch 165 of 2500 took 0.022s
#   training loss:		0.971459
#   validation loss:		0.962513
# Epoch 166 of 2500 took 0.024s
#   training loss:		0.969288
#   validation loss:		0.961855
# Epoch 167 of 2500 took 0.024s
#   training loss:		0.967797
#   validation loss:		0.960082
# Epoch 168 of 2500 took 0.021s
#   training loss:		0.965132
#   validation loss:		0.957968
# Epoch 169 of 2500 took 0.023s
#   training loss:		0.963832
#   validation loss:		0.958902
# Epoch 170 of 2500 took 0.023s
#   training loss:		0.963093
#   validation loss:		0.952890
# Epoch 171 of 2500 took 0.024s
#   training loss:		0.959890
#   validation loss:		0.952281
# Epoch 172 of 2500 took 0.022s
#   training loss:		0.957120
#   validation loss:		0.949763
# Epoch 173 of 2500 took 0.022s
#   training loss:		0.954318
#   validation loss:		0.947560
# Epoch 174 of 2500 took 0.024s
#   training loss:		0.955273
#   validation loss:		0.944513
# Epoch 175 of 2500 took 0.021s
#   training loss:		0.952353
#   validation loss:		0.943449
# Epoch 176 of 2500 took 0.025s
#   training loss:		0.949762
#   validation loss:		0.942015
# Epoch 177 of 2500 took 0.023s
#   training loss:		0.944532
#   validation loss:		0.935148
# Epoch 178 of 2500 took 0.022s
#   training loss:		0.942059
#   validation loss:		0.932067
# Epoch 179 of 2500 took 0.020s
#   training loss:		0.939503
#   validation loss:		0.934392
# Epoch 180 of 2500 took 0.022s
#   training loss:		0.936074
#   validation loss:		0.927756
# Epoch 181 of 2500 took 0.022s
#   training loss:		0.931966
#   validation loss:		0.922927
# Epoch 182 of 2500 took 0.024s
#   training loss:		0.932012
#   validation loss:		0.922214
# Epoch 183 of 2500 took 0.023s
#   training loss:		0.925571
#   validation loss:		0.915217
# Epoch 184 of 2500 took 0.024s
#   training loss:		0.920773
#   validation loss:		0.914531
# Epoch 185 of 2500 took 0.021s
#   training loss:		0.917936
#   validation loss:		0.909263
# Epoch 186 of 2500 took 0.023s
#   training loss:		0.913467
#   validation loss:		0.904257
# Epoch 187 of 2500 took 0.022s
#   training loss:		0.908456
#   validation loss:		0.899628
# Epoch 188 of 2500 took 0.021s
#   training loss:		0.904672
#   validation loss:		0.897006
# Epoch 189 of 2500 took 0.023s
#   training loss:		0.901547
#   validation loss:		0.890325
# Epoch 190 of 2500 took 0.023s
#   training loss:		0.897009
#   validation loss:		0.891096
# Epoch 191 of 2500 took 0.021s
#   training loss:		0.896238
#   validation loss:		0.883474
# Epoch 192 of 2500 took 0.021s
#   training loss:		0.887035
#   validation loss:		0.877301
# Epoch 193 of 2500 took 0.022s
#   training loss:		0.884678
#   validation loss:		0.873184
# Epoch 194 of 2500 took 0.024s
#   training loss:		0.880057
#   validation loss:		0.870010
# Epoch 195 of 2500 took 0.023s
#   training loss:		0.875625
#   validation loss:		0.865150
# Epoch 196 of 2500 took 0.023s
#   training loss:		0.871150
#   validation loss:		0.865752
# Epoch 197 of 2500 took 0.022s
#   training loss:		0.867604
#   validation loss:		0.856238
# Epoch 198 of 2500 took 0.024s
#   training loss:		0.863453
#   validation loss:		0.852430
# Epoch 199 of 2500 took 0.024s
#   training loss:		0.861722
#   validation loss:		0.848244
# Epoch 200 of 2500 took 0.024s
#   training loss:		0.857623
#   validation loss:		0.845751
# Epoch 201 of 2500 took 0.024s
#   training loss:		0.854090
#   validation loss:		0.840428
# Epoch 202 of 2500 took 0.024s
#   training loss:		0.846971
#   validation loss:		0.837094
# Epoch 203 of 2500 took 0.023s
#   training loss:		0.844704
#   validation loss:		0.833156
# Epoch 204 of 2500 took 0.022s
#   training loss:		0.842043
#   validation loss:		0.829692
# Epoch 205 of 2500 took 0.023s
#   training loss:		0.836247
#   validation loss:		0.825734
# Epoch 206 of 2500 took 0.022s
#   training loss:		0.834286
#   validation loss:		0.822837
# Epoch 207 of 2500 took 0.022s
#   training loss:		0.830440
#   validation loss:		0.820904
# Epoch 208 of 2500 took 0.023s
#   training loss:		0.827711
#   validation loss:		0.815338
# Epoch 209 of 2500 took 0.022s
#   training loss:		0.823511
#   validation loss:		0.811345
# Epoch 210 of 2500 took 0.022s
#   training loss:		0.822506
#   validation loss:		0.815837
# Epoch 211 of 2500 took 0.023s
#   training loss:		0.818661
#   validation loss:		0.804749
# Epoch 212 of 2500 took 0.024s
#   training loss:		0.814717
#   validation loss:		0.800881
# Epoch 213 of 2500 took 0.023s
#   training loss:		0.809252
#   validation loss:		0.800803
# Epoch 214 of 2500 took 0.021s
#   training loss:		0.806594
#   validation loss:		0.795709
# Epoch 215 of 2500 took 0.026s
#   training loss:		0.805373
#   validation loss:		0.796768
# Epoch 216 of 2500 took 0.022s
#   training loss:		0.802686
#   validation loss:		0.787691
# Epoch 217 of 2500 took 0.022s
#   training loss:		0.797550
#   validation loss:		0.789775
# Epoch 218 of 2500 took 0.022s
#   training loss:		0.794997
#   validation loss:		0.780667
# Epoch 219 of 2500 took 0.022s
#   training loss:		0.789665
#   validation loss:		0.780592
# Epoch 220 of 2500 took 0.024s
#   training loss:		0.786784
#   validation loss:		0.774541
# Epoch 221 of 2500 took 0.025s
#   training loss:		0.783056
#   validation loss:		0.770442
# Epoch 222 of 2500 took 0.024s
#   training loss:		0.780286
#   validation loss:		0.768364
# Epoch 223 of 2500 took 0.024s
#   training loss:		0.778138
#   validation loss:		0.767608
# Epoch 224 of 2500 took 0.023s
#   training loss:		0.778946
#   validation loss:		0.760825
# Epoch 225 of 2500 took 0.023s
#   training loss:		0.772104
#   validation loss:		0.758960
# Epoch 226 of 2500 took 0.021s
#   training loss:		0.771010
#   validation loss:		0.754527
# Epoch 227 of 2500 took 0.022s
#   training loss:		0.764934
#   validation loss:		0.751367
# Epoch 228 of 2500 took 0.023s
#   training loss:		0.761642
#   validation loss:		0.748454
# Epoch 229 of 2500 took 0.023s
#   training loss:		0.759538
#   validation loss:		0.745069
# Epoch 230 of 2500 took 0.023s
#   training loss:		0.755078
#   validation loss:		0.742140
# Epoch 231 of 2500 took 0.024s
#   training loss:		0.754198
#   validation loss:		0.739265
# Epoch 232 of 2500 took 0.022s
#   training loss:		0.755179
#   validation loss:		0.739629
# Epoch 233 of 2500 took 0.024s
#   training loss:		0.749834
#   validation loss:		0.733318
# Epoch 234 of 2500 took 0.028s
#   training loss:		0.745372
#   validation loss:		0.731666
# Epoch 235 of 2500 took 0.022s
#   training loss:		0.741370
#   validation loss:		0.727013
# Epoch 236 of 2500 took 0.022s
#   training loss:		0.739575
#   validation loss:		0.724289
# Epoch 237 of 2500 took 0.025s
#   training loss:		0.736230
#   validation loss:		0.722420
# Epoch 238 of 2500 took 0.023s
#   training loss:		0.734740
#   validation loss:		0.718355
# Epoch 239 of 2500 took 0.022s
#   training loss:		0.729007
#   validation loss:		0.715167
# Epoch 240 of 2500 took 0.022s
#   training loss:		0.725520
#   validation loss:		0.713001
# Epoch 241 of 2500 took 0.023s
#   training loss:		0.722067
#   validation loss:		0.710952
# Epoch 242 of 2500 took 0.025s
#   training loss:		0.721766
#   validation loss:		0.706523
# Epoch 243 of 2500 took 0.024s
#   training loss:		0.716639
#   validation loss:		0.704151
# Epoch 244 of 2500 took 0.026s
#   training loss:		0.712776
#   validation loss:		0.700909
# Epoch 245 of 2500 took 0.024s
#   training loss:		0.709959
#   validation loss:		0.700615
# Epoch 246 of 2500 took 0.024s
#   training loss:		0.707123
#   validation loss:		0.695135
# Epoch 247 of 2500 took 0.023s
#   training loss:		0.702786
#   validation loss:		0.690452
# Epoch 248 of 2500 took 0.024s
#   training loss:		0.700481
#   validation loss:		0.686693
# Epoch 249 of 2500 took 0.025s
#   training loss:		0.695487
#   validation loss:		0.683984
# Epoch 250 of 2500 took 0.024s
#   training loss:		0.693045
#   validation loss:		0.681367
# Epoch 251 of 2500 took 0.025s
#   training loss:		0.692041
#   validation loss:		0.676907
# Epoch 252 of 2500 took 0.024s
#   training loss:		0.684235
#   validation loss:		0.675544
# Epoch 253 of 2500 took 0.024s
#   training loss:		0.682755
#   validation loss:		0.667974
# Epoch 254 of 2500 took 0.022s
#   training loss:		0.675248
#   validation loss:		0.664997
# Epoch 255 of 2500 took 0.023s
#   training loss:		0.670865
#   validation loss:		0.659997
# Epoch 256 of 2500 took 0.023s
#   training loss:		0.668150
#   validation loss:		0.656934
# Epoch 257 of 2500 took 0.026s
#   training loss:		0.662569
#   validation loss:		0.651422
# Epoch 258 of 2500 took 0.026s
#   training loss:		0.658360
#   validation loss:		0.647159
# Epoch 259 of 2500 took 0.024s
#   training loss:		0.650943
#   validation loss:		0.641004
# Epoch 260 of 2500 took 0.023s
#   training loss:		0.645305
#   validation loss:		0.635108
# Epoch 261 of 2500 took 0.024s
#   training loss:		0.641388
#   validation loss:		0.629276
# Epoch 262 of 2500 took 0.024s
#   training loss:		0.634396
#   validation loss:		0.624030
# Epoch 263 of 2500 took 0.024s
#   training loss:		0.629101
#   validation loss:		0.619198
# Epoch 264 of 2500 took 0.022s
#   training loss:		0.622636
#   validation loss:		0.613307
# Epoch 265 of 2500 took 0.025s
#   training loss:		0.616515
#   validation loss:		0.612540
# Epoch 266 of 2500 took 0.023s
#   training loss:		0.612303
#   validation loss:		0.601711
# Epoch 267 of 2500 took 0.026s
#   training loss:		0.605171
#   validation loss:		0.595474
# Epoch 268 of 2500 took 0.025s
#   training loss:		0.600589
#   validation loss:		0.591242
# Epoch 269 of 2500 took 0.024s
#   training loss:		0.592095
#   validation loss:		0.587141
# Epoch 270 of 2500 took 0.022s
#   training loss:		0.587654
#   validation loss:		0.578186
# Epoch 271 of 2500 took 0.023s
#   training loss:		0.579478
#   validation loss:		0.573821
# Epoch 272 of 2500 took 0.021s
#   training loss:		0.573919
#   validation loss:		0.567369
# Epoch 273 of 2500 took 0.023s
#   training loss:		0.567705
#   validation loss:		0.560769
# Epoch 274 of 2500 took 0.023s
#   training loss:		0.564501
#   validation loss:		0.554740
# Epoch 275 of 2500 took 0.024s
#   training loss:		0.556235
#   validation loss:		0.552069
# Epoch 276 of 2500 took 0.022s
#   training loss:		0.550575
#   validation loss:		0.543441
# Epoch 277 of 2500 took 0.023s
#   training loss:		0.544381
#   validation loss:		0.538233
# Epoch 278 of 2500 took 0.025s
#   training loss:		0.539860
#   validation loss:		0.533393
# Epoch 279 of 2500 took 0.023s
#   training loss:		0.535133
#   validation loss:		0.535809
# Epoch 280 of 2500 took 0.024s
#   training loss:		0.529683
#   validation loss:		0.521563
# Epoch 281 of 2500 took 0.022s
#   training loss:		0.521497
#   validation loss:		0.519149
# Epoch 282 of 2500 took 0.023s
#   training loss:		0.515395
#   validation loss:		0.510875
# Epoch 283 of 2500 took 0.023s
#   training loss:		0.510773
#   validation loss:		0.505929
# Epoch 284 of 2500 took 0.023s
#   training loss:		0.505085
#   validation loss:		0.502308
# Epoch 285 of 2500 took 0.024s
#   training loss:		0.500531
#   validation loss:		0.497727
# Epoch 286 of 2500 took 0.022s
#   training loss:		0.494889
#   validation loss:		0.496554
# Epoch 287 of 2500 took 0.024s
#   training loss:		0.493066
#   validation loss:		0.488718
# Epoch 288 of 2500 took 0.023s
#   training loss:		0.487354
#   validation loss:		0.482807
# Epoch 289 of 2500 took 0.029s
#   training loss:		0.480753
#   validation loss:		0.478941
# Epoch 290 of 2500 took 0.023s
#   training loss:		0.477508
#   validation loss:		0.474523
# Epoch 291 of 2500 took 0.021s
#   training loss:		0.473683
#   validation loss:		0.471570
# Epoch 292 of 2500 took 0.023s
#   training loss:		0.470316
#   validation loss:		0.468643
# Epoch 293 of 2500 took 0.021s
#   training loss:		0.467669
#   validation loss:		0.467378
# Epoch 294 of 2500 took 0.024s
#   training loss:		0.466160
#   validation loss:		0.463581
# Epoch 295 of 2500 took 0.022s
#   training loss:		0.463254
#   validation loss:		0.463371
# Epoch 296 of 2500 took 0.024s
#   training loss:		0.461402
#   validation loss:		0.464189
# Epoch 297 of 2500 took 0.021s
#   training loss:		0.463126
#   validation loss:		0.465015
# Epoch 298 of 2500 took 0.022s
#   training loss:		0.459248
#   validation loss:		0.459144
# Epoch 299 of 2500 took 0.022s
#   training loss:		0.456957
#   validation loss:		0.456644
# Epoch 300 of 2500 took 0.023s
#   training loss:		0.458728
#   validation loss:		0.455985
# Epoch 301 of 2500 took 0.021s
#   training loss:		0.455416
#   validation loss:		0.455858
# Epoch 302 of 2500 took 0.023s
#   training loss:		0.456180
#   validation loss:		0.459973
# Epoch 303 of 2500 took 0.023s
#   training loss:		0.454496
#   validation loss:		0.454390
# Epoch 304 of 2500 took 0.022s
#   training loss:		0.457009
#   validation loss:		0.455056
# Epoch 305 of 2500 took 0.021s
#   training loss:		0.452771
#   validation loss:		0.458604
# Epoch 306 of 2500 took 0.024s
#   training loss:		0.453671
#   validation loss:		0.456514
# Epoch 307 of 2500 took 0.024s
#   training loss:		0.452342
#   validation loss:		0.452682
# Epoch 308 of 2500 took 0.023s
#   training loss:		0.453607
#   validation loss:		0.452324
# Epoch 309 of 2500 took 0.023s
#   training loss:		0.452607
#   validation loss:		0.452288
# Epoch 310 of 2500 took 0.026s
#   training loss:		0.451733
#   validation loss:		0.453209
# Epoch 311 of 2500 took 0.022s
#   training loss:		0.453606
#   validation loss:		0.451505
# Epoch 312 of 2500 took 0.024s
#   training loss:		0.450611
#   validation loss:		0.455125
# Epoch 313 of 2500 took 0.025s
#   training loss:		0.450788
#   validation loss:		0.452677
# Epoch 314 of 2500 took 0.026s
#   training loss:		0.450524
#   validation loss:		0.451139
# Epoch 315 of 2500 took 0.023s
#   training loss:		0.452983
#   validation loss:		0.451297
# Epoch 316 of 2500 took 0.021s
#   training loss:		0.453071
#   validation loss:		0.454384
# Epoch 317 of 2500 took 0.022s
#   training loss:		0.449392
#   validation loss:		0.449817
# Epoch 318 of 2500 took 0.024s
#   training loss:		0.449737
#   validation loss:		0.450801
# Epoch 319 of 2500 took 0.025s
#   training loss:		0.448209
#   validation loss:		0.449639
# Epoch 320 of 2500 took 0.021s
#   training loss:		0.448185
#   validation loss:		0.449580
# Epoch 321 of 2500 took 0.022s
#   training loss:		0.447192
#   validation loss:		0.451328
# Epoch 322 of 2500 took 0.023s
#   training loss:		0.448069
#   validation loss:		0.448654
# Epoch 323 of 2500 took 0.022s
#   training loss:		0.449761
#   validation loss:		0.448302
# Epoch 324 of 2500 took 0.022s
#   training loss:		0.446015
#   validation loss:		0.447980
# Epoch 325 of 2500 took 0.023s
#   training loss:		0.448127
#   validation loss:		0.449480
# Epoch 326 of 2500 took 0.022s
#   training loss:		0.453401
#   validation loss:		0.451913
# Epoch 327 of 2500 took 0.024s
#   training loss:		0.448116
#   validation loss:		0.454805
# Epoch 328 of 2500 took 0.024s
#   training loss:		0.449822
#   validation loss:		0.455477
# Epoch 329 of 2500 took 0.027s
#   training loss:		0.445410
#   validation loss:		0.446648
# Epoch 330 of 2500 took 0.023s
#   training loss:		0.444353
#   validation loss:		0.450648
# Epoch 331 of 2500 took 0.022s
#   training loss:		0.444639
#   validation loss:		0.445948
# Epoch 332 of 2500 took 0.022s
#   training loss:		0.445264
#   validation loss:		0.445942
# Epoch 333 of 2500 took 0.024s
#   training loss:		0.445656
#   validation loss:		0.446483
# Epoch 334 of 2500 took 0.025s
#   training loss:		0.443380
#   validation loss:		0.445205
# Epoch 335 of 2500 took 0.023s
#   training loss:		0.444366
#   validation loss:		0.445497
# Epoch 336 of 2500 took 0.023s
#   training loss:		0.443021
#   validation loss:		0.445044
# Epoch 337 of 2500 took 0.025s
#   training loss:		0.444390
#   validation loss:		0.449839
# Epoch 338 of 2500 took 0.024s
#   training loss:		0.443671
#   validation loss:		0.444601
# Epoch 339 of 2500 took 0.023s
#   training loss:		0.442266
#   validation loss:		0.445585
# Epoch 340 of 2500 took 0.024s
#   training loss:		0.443915
#   validation loss:		0.443636
# Epoch 341 of 2500 took 0.023s
#   training loss:		0.441800
#   validation loss:		0.443432
# Epoch 342 of 2500 took 0.024s
#   training loss:		0.441772
#   validation loss:		0.443086
# Epoch 343 of 2500 took 0.025s
#   training loss:		0.441019
#   validation loss:		0.443912
# Epoch 344 of 2500 took 0.023s
#   training loss:		0.441872
#   validation loss:		0.445520
# Epoch 345 of 2500 took 0.022s
#   training loss:		0.443225
#   validation loss:		0.443480
# Epoch 346 of 2500 took 0.023s
#   training loss:		0.440110
#   validation loss:		0.443863
# Epoch 347 of 2500 took 0.024s
#   training loss:		0.444372
#   validation loss:		0.442726
# Epoch 348 of 2500 took 0.024s
#   training loss:		0.442851
#   validation loss:		0.443598
# Epoch 349 of 2500 took 0.024s
#   training loss:		0.440722
#   validation loss:		0.446508
# Epoch 350 of 2500 took 0.022s
#   training loss:		0.442646
#   validation loss:		0.441250
# Epoch 351 of 2500 took 0.023s
#   training loss:		0.439431
#   validation loss:		0.444360
# Epoch 352 of 2500 took 0.024s
#   training loss:		0.439445
#   validation loss:		0.441250
# Epoch 353 of 2500 took 0.022s
#   training loss:		0.438843
#   validation loss:		0.441279
# Epoch 354 of 2500 took 0.024s
#   training loss:		0.439608
#   validation loss:		0.440490
# Epoch 355 of 2500 took 0.023s
#   training loss:		0.440451
#   validation loss:		0.440431
# Epoch 356 of 2500 took 0.025s
#   training loss:		0.438742
#   validation loss:		0.444416
# Epoch 357 of 2500 took 0.026s
#   training loss:		0.439102
#   validation loss:		0.443198
# Epoch 358 of 2500 took 0.024s
#   training loss:		0.437940
#   validation loss:		0.440085
# Epoch 359 of 2500 took 0.026s
#   training loss:		0.438475
#   validation loss:		0.439055
# Epoch 360 of 2500 took 0.025s
#   training loss:		0.437266
#   validation loss:		0.438963
# Epoch 361 of 2500 took 0.023s
#   training loss:		0.436261
#   validation loss:		0.438588
# Epoch 362 of 2500 took 0.024s
#   training loss:		0.436859
#   validation loss:		0.443026
# Epoch 363 of 2500 took 0.024s
#   training loss:		0.437433
#   validation loss:		0.438979
# Epoch 364 of 2500 took 0.023s
#   training loss:		0.437428
#   validation loss:		0.439273
# Epoch 365 of 2500 took 0.022s
#   training loss:		0.435991
#   validation loss:		0.437664
# Epoch 366 of 2500 took 0.025s
#   training loss:		0.438256
#   validation loss:		0.439144
# Epoch 367 of 2500 took 0.024s
#   training loss:		0.437851
#   validation loss:		0.437818
# Epoch 368 of 2500 took 0.022s
#   training loss:		0.437715
#   validation loss:		0.439152
# Epoch 369 of 2500 took 0.024s
#   training loss:		0.436171
#   validation loss:		0.436605
# Epoch 370 of 2500 took 0.024s
#   training loss:		0.436706
#   validation loss:		0.436097
# Epoch 371 of 2500 took 0.023s
#   training loss:		0.434441
#   validation loss:		0.441229
# Epoch 372 of 2500 took 0.026s
#   training loss:		0.434765
#   validation loss:		0.435890
# Epoch 373 of 2500 took 0.022s
#   training loss:		0.435019
#   validation loss:		0.436120
# Epoch 374 of 2500 took 0.025s
#   training loss:		0.432949
#   validation loss:		0.439903
# Epoch 375 of 2500 took 0.022s
#   training loss:		0.434200
#   validation loss:		0.435639
# Epoch 376 of 2500 took 0.022s
#   training loss:		0.433724
#   validation loss:		0.434899
# Epoch 377 of 2500 took 0.023s
#   training loss:		0.432903
#   validation loss:		0.435839
# Epoch 378 of 2500 took 0.024s
#   training loss:		0.432277
#   validation loss:		0.434227
# Epoch 379 of 2500 took 0.024s
#   training loss:		0.432061
#   validation loss:		0.434886
# Epoch 380 of 2500 took 0.021s
#   training loss:		0.431861
#   validation loss:		0.434823
# Epoch 381 of 2500 took 0.022s
#   training loss:		0.431340
#   validation loss:		0.435344
# Epoch 382 of 2500 took 0.023s
#   training loss:		0.431444
#   validation loss:		0.433840
# Epoch 383 of 2500 took 0.022s
#   training loss:		0.431102
#   validation loss:		0.436778
# Epoch 384 of 2500 took 0.026s
#   training loss:		0.431691
#   validation loss:		0.433230
# Epoch 385 of 2500 took 0.023s
#   training loss:		0.430899
#   validation loss:		0.433160
# Epoch 386 of 2500 took 0.023s
#   training loss:		0.431801
#   validation loss:		0.432974
# Epoch 387 of 2500 took 0.025s
#   training loss:		0.432824
#   validation loss:		0.432192
# Epoch 388 of 2500 took 0.024s
#   training loss:		0.430302
#   validation loss:		0.433087
# Epoch 389 of 2500 took 0.022s
#   training loss:		0.430920
#   validation loss:		0.433047
# Epoch 390 of 2500 took 0.024s
#   training loss:		0.429737
#   validation loss:		0.431784
# Epoch 391 of 2500 took 0.024s
#   training loss:		0.432354
#   validation loss:		0.433444
# Epoch 392 of 2500 took 0.023s
#   training loss:		0.430197
#   validation loss:		0.433282
# Epoch 393 of 2500 took 0.026s
#   training loss:		0.431529
#   validation loss:		0.431489
# Epoch 394 of 2500 took 0.023s
#   training loss:		0.429050
#   validation loss:		0.436769
# Epoch 395 of 2500 took 0.024s
#   training loss:		0.429806
#   validation loss:		0.430350
# Epoch 396 of 2500 took 0.024s
#   training loss:		0.430367
#   validation loss:		0.430061
# Epoch 397 of 2500 took 0.025s
#   training loss:		0.429357
#   validation loss:		0.431603
# Epoch 398 of 2500 took 0.021s
#   training loss:		0.427362
#   validation loss:		0.429505
# Epoch 399 of 2500 took 0.021s
#   training loss:		0.429246
#   validation loss:		0.429372
# Epoch 400 of 2500 took 0.023s
#   training loss:		0.428246
#   validation loss:		0.433483
# Epoch 401 of 2500 took 0.024s
#   training loss:		0.428281
#   validation loss:		0.429005
# Epoch 402 of 2500 took 0.024s
#   training loss:		0.427786
#   validation loss:		0.428434
# Epoch 403 of 2500 took 0.023s
#   training loss:		0.426743
#   validation loss:		0.429546
# Epoch 404 of 2500 took 0.024s
#   training loss:		0.426095
#   validation loss:		0.428808
# Epoch 405 of 2500 took 0.027s
#   training loss:		0.428081
#   validation loss:		0.429035
# Epoch 406 of 2500 took 0.024s
#   training loss:		0.428824
#   validation loss:		0.430256
# Epoch 407 of 2500 took 0.022s
#   training loss:		0.426909
#   validation loss:		0.427943
# Epoch 408 of 2500 took 0.025s
#   training loss:		0.425793
#   validation loss:		0.438119
# Epoch 409 of 2500 took 0.022s
#   training loss:		0.426651
#   validation loss:		0.427315
# Epoch 410 of 2500 took 0.023s
#   training loss:		0.428263
#   validation loss:		0.428927
# Epoch 411 of 2500 took 0.024s
#   training loss:		0.425446
#   validation loss:		0.430194
# Epoch 412 of 2500 took 0.022s
#   training loss:		0.426441
#   validation loss:		0.426060
# Epoch 413 of 2500 took 0.023s
#   training loss:		0.425714
#   validation loss:		0.426997
# Epoch 414 of 2500 took 0.023s
#   training loss:		0.427027
#   validation loss:		0.425820
# Epoch 415 of 2500 took 0.026s
#   training loss:		0.426509
#   validation loss:		0.432819
# Epoch 416 of 2500 took 0.021s
#   training loss:		0.425914
#   validation loss:		0.425410
# Epoch 417 of 2500 took 0.021s
#   training loss:		0.423575
#   validation loss:		0.429657
# Epoch 418 of 2500 took 0.023s
#   training loss:		0.427248
#   validation loss:		0.425152
# Epoch 419 of 2500 took 0.024s
#   training loss:		0.424692
#   validation loss:		0.426086
# Epoch 420 of 2500 took 0.023s
#   training loss:		0.426500
#   validation loss:		0.424893
# Epoch 421 of 2500 took 0.023s
#   training loss:		0.424608
#   validation loss:		0.426271
# Epoch 422 of 2500 took 0.025s
#   training loss:		0.423538
#   validation loss:		0.427969
# Epoch 423 of 2500 took 0.023s
#   training loss:		0.423774
#   validation loss:		0.423739
# Epoch 424 of 2500 took 0.024s
#   training loss:		0.422791
#   validation loss:		0.423516
# Epoch 425 of 2500 took 0.021s
#   training loss:		0.422806
#   validation loss:		0.423151
# Epoch 426 of 2500 took 0.023s
#   training loss:		0.423400
#   validation loss:		0.423121
# Epoch 427 of 2500 took 0.024s
#   training loss:		0.422102
#   validation loss:		0.424456
# Epoch 428 of 2500 took 0.025s
#   training loss:		0.423195
#   validation loss:		0.425386
# Epoch 429 of 2500 took 0.024s
#   training loss:		0.422850
#   validation loss:		0.424939
# Epoch 430 of 2500 took 0.024s
#   training loss:		0.421042
#   validation loss:		0.421751
# Epoch 431 of 2500 took 0.025s
#   training loss:		0.421641
#   validation loss:		0.422171
# Epoch 432 of 2500 took 0.025s
#   training loss:		0.422670
#   validation loss:		0.424761
# Epoch 433 of 2500 took 0.023s
#   training loss:		0.423226
#   validation loss:		0.421363
# Epoch 434 of 2500 took 0.021s
#   training loss:		0.422413
#   validation loss:		0.421031
# Epoch 435 of 2500 took 0.026s
#   training loss:		0.420312
#   validation loss:		0.421894
# Epoch 436 of 2500 took 0.024s
#   training loss:		0.422109
#   validation loss:		0.420819
# Epoch 437 of 2500 took 0.021s
#   training loss:		0.420177
#   validation loss:		0.421569
# Epoch 438 of 2500 took 0.025s
#   training loss:		0.421161
#   validation loss:		0.421417
# Epoch 439 of 2500 took 0.024s
#   training loss:		0.422696
#   validation loss:		0.422389
# Epoch 440 of 2500 took 0.023s
#   training loss:		0.421529
#   validation loss:		0.421323
# Epoch 441 of 2500 took 0.024s
#   training loss:		0.421378
#   validation loss:		0.419761
# Epoch 442 of 2500 took 0.026s
#   training loss:		0.420254
#   validation loss:		0.419513
# Epoch 443 of 2500 took 0.022s
#   training loss:		0.419528
#   validation loss:		0.420185
# Epoch 444 of 2500 took 0.023s
#   training loss:		0.420057
#   validation loss:		0.420072
# Epoch 445 of 2500 took 0.024s
#   training loss:		0.418156
#   validation loss:		0.420548
# Epoch 446 of 2500 took 0.022s
#   training loss:		0.419072
#   validation loss:		0.419293
# Epoch 447 of 2500 took 0.023s
#   training loss:		0.421104
#   validation loss:		0.418610
# Epoch 448 of 2500 took 0.023s
#   training loss:		0.418670
#   validation loss:		0.421118
# Epoch 449 of 2500 took 0.022s
#   training loss:		0.417355
#   validation loss:		0.430586
# Epoch 450 of 2500 took 0.023s
#   training loss:		0.420006
#   validation loss:		0.418621
# Epoch 451 of 2500 took 0.024s
#   training loss:		0.418689
#   validation loss:		0.418456
# Epoch 452 of 2500 took 0.020s
#   training loss:		0.419289
#   validation loss:		0.421704
# Epoch 453 of 2500 took 0.022s
#   training loss:		0.416734
#   validation loss:		0.417442
# Epoch 454 of 2500 took 0.022s
#   training loss:		0.416615
#   validation loss:		0.433240
# Epoch 455 of 2500 took 0.023s
#   training loss:		0.418405
#   validation loss:		0.420222
# Epoch 456 of 2500 took 0.022s
#   training loss:		0.417571
#   validation loss:		0.420944
# Epoch 457 of 2500 took 0.023s
#   training loss:		0.415944
#   validation loss:		0.418889
# Epoch 458 of 2500 took 0.024s
#   training loss:		0.416800
#   validation loss:		0.421209
# Epoch 459 of 2500 took 0.023s
#   training loss:		0.417339
#   validation loss:		0.416191
# Epoch 460 of 2500 took 0.025s
#   training loss:		0.415997
#   validation loss:		0.416312
# Epoch 461 of 2500 took 0.021s
#   training loss:		0.417125
#   validation loss:		0.416267
# Epoch 462 of 2500 took 0.024s
#   training loss:		0.415390
#   validation loss:		0.419680
# Epoch 463 of 2500 took 0.025s
#   training loss:		0.416722
#   validation loss:		0.418933
# Epoch 464 of 2500 took 0.024s
#   training loss:		0.415903
#   validation loss:		0.415091
# Epoch 465 of 2500 took 0.025s
#   training loss:		0.416135
#   validation loss:		0.415326
# Epoch 466 of 2500 took 0.022s
#   training loss:		0.414912
#   validation loss:		0.419028
# Epoch 467 of 2500 took 0.024s
#   training loss:		0.415543
#   validation loss:		0.414646
# Epoch 468 of 2500 took 0.024s
#   training loss:		0.417049
#   validation loss:		0.415536
# Epoch 469 of 2500 took 0.025s
#   training loss:		0.418195
#   validation loss:		0.417417
# Epoch 470 of 2500 took 0.021s
#   training loss:		0.416783
#   validation loss:		0.414436
# Epoch 471 of 2500 took 0.022s
#   training loss:		0.414899
#   validation loss:		0.413706
# Epoch 472 of 2500 took 0.024s
#   training loss:		0.414110
#   validation loss:		0.413800
# Epoch 473 of 2500 took 0.022s
#   training loss:		0.413928
#   validation loss:		0.415337
# Epoch 474 of 2500 took 0.023s
#   training loss:		0.414018
#   validation loss:		0.415021
# Epoch 475 of 2500 took 0.025s
#   training loss:		0.415503
#   validation loss:		0.414568
# Epoch 476 of 2500 took 0.025s
#   training loss:		0.414257
#   validation loss:		0.412869
# Epoch 477 of 2500 took 0.022s
#   training loss:		0.414404
#   validation loss:		0.413776
# Epoch 478 of 2500 took 0.024s
#   training loss:		0.413175
#   validation loss:		0.412678
# Epoch 479 of 2500 took 0.021s
#   training loss:		0.413008
#   validation loss:		0.419450
# Epoch 480 of 2500 took 0.024s
#   training loss:		0.414087
#   validation loss:		0.412627
# Epoch 481 of 2500 took 0.025s
#   training loss:		0.413288
#   validation loss:		0.413668
# Epoch 482 of 2500 took 0.024s
#   training loss:		0.413093
#   validation loss:		0.412010
# Epoch 483 of 2500 took 0.023s
#   training loss:		0.413842
#   validation loss:		0.412443
# Epoch 484 of 2500 took 0.023s
#   training loss:		0.413836
#   validation loss:		0.413060
# Epoch 485 of 2500 took 0.023s
#   training loss:		0.415649
#   validation loss:		0.413187
# Epoch 486 of 2500 took 0.022s
#   training loss:		0.413781
#   validation loss:		0.411585
# Epoch 487 of 2500 took 0.024s
#   training loss:		0.411727
#   validation loss:		0.412246
# Epoch 488 of 2500 took 0.021s
#   training loss:		0.413043
#   validation loss:		0.411084
# Epoch 489 of 2500 took 0.024s
#   training loss:		0.412267
#   validation loss:		0.413472
# Epoch 490 of 2500 took 0.023s
#   training loss:		0.411479
#   validation loss:		0.410485
# Epoch 491 of 2500 took 0.023s
#   training loss:		0.412421
#   validation loss:		0.410493
# Epoch 492 of 2500 took 0.025s
#   training loss:		0.412263
#   validation loss:		0.413101
# Epoch 493 of 2500 took 0.025s
#   training loss:		0.412008
#   validation loss:		0.409986
# Epoch 494 of 2500 took 0.024s
#   training loss:		0.411746
#   validation loss:		0.410122
# Epoch 495 of 2500 took 0.022s
#   training loss:		0.411935
#   validation loss:		0.410735
# Epoch 496 of 2500 took 0.025s
#   training loss:		0.413619
#   validation loss:		0.409812
# Epoch 497 of 2500 took 0.022s
#   training loss:		0.413383
#   validation loss:		0.409691
# Epoch 498 of 2500 took 0.021s
#   training loss:		0.412533
#   validation loss:		0.409842
# Epoch 499 of 2500 took 0.023s
#   training loss:		0.410943
#   validation loss:		0.410163
# Epoch 500 of 2500 took 0.024s
#   training loss:		0.411427
#   validation loss:		0.409470
# Epoch 501 of 2500 took 0.023s
#   training loss:		0.410629
#   validation loss:		0.409365
# Epoch 502 of 2500 took 0.025s
#   training loss:		0.411773
#   validation loss:		0.410282
# Epoch 503 of 2500 took 0.024s
#   training loss:		0.409867
#   validation loss:		0.409521
# Epoch 504 of 2500 took 0.024s
#   training loss:		0.412399
#   validation loss:		0.409824
# Epoch 505 of 2500 took 0.025s
#   training loss:		0.410039
#   validation loss:		0.411101
# Epoch 506 of 2500 took 0.021s
#   training loss:		0.410553
#   validation loss:		0.409063
# Epoch 507 of 2500 took 0.025s
#   training loss:		0.409783
#   validation loss:		0.408966
# Epoch 508 of 2500 took 0.025s
#   training loss:		0.410364
#   validation loss:		0.408868
# Epoch 509 of 2500 took 0.023s
#   training loss:		0.412730
#   validation loss:		0.408305
# Epoch 510 of 2500 took 0.024s
#   training loss:		0.410931
#   validation loss:		0.410787
# Epoch 511 of 2500 took 0.023s
#   training loss:		0.409637
#   validation loss:		0.410427
# Epoch 512 of 2500 took 0.024s
#   training loss:		0.410080
#   validation loss:		0.407647
# Epoch 513 of 2500 took 0.026s
#   training loss:		0.409326
#   validation loss:		0.409678
# Epoch 514 of 2500 took 0.025s
#   training loss:		0.409162
#   validation loss:		0.411196
# Epoch 515 of 2500 took 0.021s
#   training loss:		0.410047
#   validation loss:		0.407392
# Epoch 516 of 2500 took 0.023s
#   training loss:		0.409419
#   validation loss:		0.407713
# Epoch 517 of 2500 took 0.022s
#   training loss:		0.413554
#   validation loss:		0.410350
# Epoch 518 of 2500 took 0.024s
#   training loss:		0.409429
#   validation loss:		0.408510
# Epoch 519 of 2500 took 0.025s
#   training loss:		0.410343
#   validation loss:		0.407301
# Epoch 520 of 2500 took 0.022s
#   training loss:		0.410574
#   validation loss:		0.407192
# Epoch 521 of 2500 took 0.022s
#   training loss:		0.409137
#   validation loss:		0.407564
# Epoch 522 of 2500 took 0.025s
#   training loss:		0.409139
#   validation loss:		0.411394
# Epoch 523 of 2500 took 0.025s
#   training loss:		0.409549
#   validation loss:		0.407666
# Epoch 524 of 2500 took 0.021s
#   training loss:		0.409296
#   validation loss:		0.407802
# Epoch 525 of 2500 took 0.024s
#   training loss:		0.409443
#   validation loss:		0.406636
# Epoch 526 of 2500 took 0.024s
#   training loss:		0.409274
#   validation loss:		0.410312
# Epoch 527 of 2500 took 0.026s
#   training loss:		0.411756
#   validation loss:		0.406603
# Epoch 528 of 2500 took 0.025s
#   training loss:		0.410168
#   validation loss:		0.408547
# Epoch 529 of 2500 took 0.023s
#   training loss:		0.409802
#   validation loss:		0.409185
# Epoch 530 of 2500 took 0.025s
#   training loss:		0.410045
#   validation loss:		0.406286
# Epoch 531 of 2500 took 0.023s
#   training loss:		0.407859
#   validation loss:		0.405670
# Epoch 532 of 2500 took 0.024s
#   training loss:		0.408064
#   validation loss:		0.405384
# Epoch 533 of 2500 took 0.022s
#   training loss:		0.408202
#   validation loss:		0.405838
# Epoch 534 of 2500 took 0.022s
#   training loss:		0.409213
#   validation loss:		0.407706
# Epoch 535 of 2500 took 0.024s
#   training loss:		0.410698
#   validation loss:		0.412628
# Epoch 536 of 2500 took 0.025s
#   training loss:		0.409743
#   validation loss:		0.405559
# Epoch 537 of 2500 took 0.024s
#   training loss:		0.410826
#   validation loss:		0.409425
# Epoch 538 of 2500 took 0.024s
#   training loss:		0.410745
#   validation loss:		0.407144
# Epoch 539 of 2500 took 0.023s
#   training loss:		0.408622
#   validation loss:		0.407552
# Epoch 540 of 2500 took 0.025s
#   training loss:		0.408335
#   validation loss:		0.405219
# Epoch 541 of 2500 took 0.025s
#   training loss:		0.407466
#   validation loss:		0.404570
# Epoch 542 of 2500 took 0.021s
#   training loss:		0.407804
#   validation loss:		0.405117
# Epoch 543 of 2500 took 0.024s
#   training loss:		0.407033
#   validation loss:		0.405702
# Epoch 544 of 2500 took 0.022s
#   training loss:		0.407112
#   validation loss:		0.404834
# Epoch 545 of 2500 took 0.025s
#   training loss:		0.406803
#   validation loss:		0.404539
# Epoch 546 of 2500 took 0.023s
#   training loss:		0.407733
#   validation loss:		0.404132
# Epoch 547 of 2500 took 0.024s
#   training loss:		0.407123
#   validation loss:		0.404516
# Epoch 548 of 2500 took 0.023s
#   training loss:		0.407603
#   validation loss:		0.404490
# Epoch 549 of 2500 took 0.024s
#   training loss:		0.405778
#   validation loss:		0.407387
# Epoch 550 of 2500 took 0.026s
#   training loss:		0.406786
#   validation loss:		0.403837
# Epoch 551 of 2500 took 0.020s
#   training loss:		0.408442
#   validation loss:		0.405747
# Epoch 552 of 2500 took 0.022s
#   training loss:		0.406787
#   validation loss:		0.404851
# Epoch 553 of 2500 took 0.024s
#   training loss:		0.408736
#   validation loss:		0.404197
# Epoch 554 of 2500 took 0.023s
#   training loss:		0.409119
#   validation loss:		0.405116
# Epoch 555 of 2500 took 0.024s
#   training loss:		0.407801
#   validation loss:		0.405477
# Epoch 556 of 2500 took 0.023s
#   training loss:		0.407986
#   validation loss:		0.406597
# Epoch 557 of 2500 took 0.023s
#   training loss:		0.407849
#   validation loss:		0.406763
# Epoch 558 of 2500 took 0.022s
#   training loss:		0.407014
#   validation loss:		0.403508
# Epoch 559 of 2500 took 0.026s
# ...
# Epoch 2318 of 2500 took 0.021s
#   training loss:		0.150776
#   validation loss:		0.141952
# Epoch 2319 of 2500 took 0.023s
#   training loss:		0.150815
#   validation loss:		0.143656
# Epoch 2320 of 2500 took 0.025s
#   training loss:		0.150916
#   validation loss:		0.143325
# Epoch 2321 of 2500 took 0.026s
#   training loss:		0.151945
#   validation loss:		0.142792
# Epoch 2322 of 2500 took 0.029s
#   training loss:		0.150591
#   validation loss:		0.142545
# Epoch 2323 of 2500 took 0.024s
#   training loss:		0.150779
#   validation loss:		0.142550
# Epoch 2324 of 2500 took 0.021s
#   training loss:		0.150696
#   validation loss:		0.142372
# Epoch 2325 of 2500 took 0.020s
#   training loss:		0.151482
#   validation loss:		0.143145
# Epoch 2326 of 2500 took 0.020s
#   training loss:		0.151005
#   validation loss:		0.142750
# Epoch 2327 of 2500 took 0.020s
#   training loss:		0.150829
#   validation loss:		0.141938
# Epoch 2328 of 2500 took 0.020s
#   training loss:		0.150930
#   validation loss:		0.143028
# Epoch 2329 of 2500 took 0.024s
#   training loss:		0.151777
#   validation loss:		0.142380
# Epoch 2330 of 2500 took 0.024s
#   training loss:		0.150754
#   validation loss:		0.143429
# Epoch 2331 of 2500 took 0.025s
#   training loss:		0.150887
#   validation loss:		0.142339
# Epoch 2332 of 2500 took 0.023s
#   training loss:		0.150372
#   validation loss:		0.141852
# Epoch 2333 of 2500 took 0.024s
#   training loss:		0.150394
#   validation loss:		0.142476
# Epoch 2334 of 2500 took 0.021s
#   training loss:		0.150632
#   validation loss:		0.143305
# Epoch 2335 of 2500 took 0.020s
#   training loss:		0.150341
#   validation loss:		0.141907
# Epoch 2336 of 2500 took 0.021s
#   training loss:		0.151808
#   validation loss:		0.141410
# Epoch 2337 of 2500 took 0.020s
#   training loss:		0.150725
#   validation loss:		0.143238
# Epoch 2338 of 2500 took 0.022s
#   training loss:		0.151051
#   validation loss:		0.141814
# Epoch 2339 of 2500 took 0.021s
#   training loss:		0.150444
#   validation loss:		0.141783
# Epoch 2340 of 2500 took 0.022s
#   training loss:		0.150557
#   validation loss:		0.144798
# Epoch 2341 of 2500 took 0.024s
#   training loss:		0.150984
#   validation loss:		0.142761
# Epoch 2342 of 2500 took 0.024s
#   training loss:		0.150962
#   validation loss:		0.142499
# Epoch 2343 of 2500 took 0.025s
#   training loss:		0.150551
#   validation loss:		0.142542
# Epoch 2344 of 2500 took 0.023s
#   training loss:		0.150167
#   validation loss:		0.142020
# Epoch 2345 of 2500 took 0.023s
#   training loss:		0.151219
#   validation loss:		0.141558
# Epoch 2346 of 2500 took 0.022s
#   training loss:		0.150744
#   validation loss:		0.141977
# Epoch 2347 of 2500 took 0.022s
#   training loss:		0.150154
#   validation loss:		0.142013
# Epoch 2348 of 2500 took 0.025s
#   training loss:		0.151344
#   validation loss:		0.142246
# Epoch 2349 of 2500 took 0.024s
#   training loss:		0.150731
#   validation loss:		0.142606
# Epoch 2350 of 2500 took 0.024s
#   training loss:		0.150544
#   validation loss:		0.143280
# Epoch 2351 of 2500 took 0.025s
#   training loss:		0.151124
#   validation loss:		0.141958
# Epoch 2352 of 2500 took 0.025s
#   training loss:		0.150522
#   validation loss:		0.141887
# Epoch 2353 of 2500 took 0.023s
#   training loss:		0.150156
#   validation loss:		0.142035
# Epoch 2354 of 2500 took 0.022s
#   training loss:		0.150525
#   validation loss:		0.142334
# Epoch 2355 of 2500 took 0.024s
#   training loss:		0.150474
#   validation loss:		0.141070
# Epoch 2356 of 2500 took 0.024s
#   training loss:		0.150664
#   validation loss:		0.143783
# Epoch 2357 of 2500 took 0.026s
#   training loss:		0.150426
#   validation loss:		0.141101
# Epoch 2358 of 2500 took 0.026s
#   training loss:		0.150064
#   validation loss:		0.142157
# Epoch 2359 of 2500 took 0.025s
#   training loss:		0.150095
#   validation loss:		0.143166
# Epoch 2360 of 2500 took 0.025s
#   training loss:		0.149714
#   validation loss:		0.141713
# Epoch 2361 of 2500 took 0.027s
#   training loss:		0.150177
#   validation loss:		0.141510
# Epoch 2362 of 2500 took 0.023s
#   training loss:		0.150379
#   validation loss:		0.141209
# Epoch 2363 of 2500 took 0.024s
#   training loss:		0.150268
#   validation loss:		0.142624
# Epoch 2364 of 2500 took 0.024s
#   training loss:		0.149877
#   validation loss:		0.142627
# Epoch 2365 of 2500 took 0.030s
#   training loss:		0.150731
#   validation loss:		0.141684
# Epoch 2366 of 2500 took 0.024s
#   training loss:		0.150129
#   validation loss:		0.143422
# Epoch 2367 of 2500 took 0.026s
#   training loss:		0.149856
#   validation loss:		0.141671
# Epoch 2368 of 2500 took 0.024s
#   training loss:		0.150469
#   validation loss:		0.141418
# Epoch 2369 of 2500 took 0.025s
#   training loss:		0.150044
#   validation loss:		0.142647
# Epoch 2370 of 2500 took 0.023s
#   training loss:		0.150145
#   validation loss:		0.142206
# Epoch 2371 of 2500 took 0.022s
#   training loss:		0.149774
#   validation loss:		0.141682
# Epoch 2372 of 2500 took 0.023s
#   training loss:		0.150084
#   validation loss:		0.141698
# Epoch 2373 of 2500 took 0.023s
#   training loss:		0.150061
#   validation loss:		0.141742
# Epoch 2374 of 2500 took 0.022s
#   training loss:		0.150848
#   validation loss:		0.141603
# Epoch 2375 of 2500 took 0.023s
#   training loss:		0.149584
#   validation loss:		0.141798
# Epoch 2376 of 2500 took 0.025s
#   training loss:		0.149638
#   validation loss:		0.141952
# Epoch 2377 of 2500 took 0.025s
#   training loss:		0.149687
#   validation loss:		0.141191
# Epoch 2378 of 2500 took 0.026s
#   training loss:		0.149965
#   validation loss:		0.143004
# Epoch 2379 of 2500 took 0.026s
#   training loss:		0.150083
#   validation loss:		0.141737
# Epoch 2380 of 2500 took 0.024s
#   training loss:		0.150549
#   validation loss:		0.142569
# Epoch 2381 of 2500 took 0.021s
#   training loss:		0.150513
#   validation loss:		0.141645
# Epoch 2382 of 2500 took 0.022s
#   training loss:		0.150068
#   validation loss:		0.141992
# Epoch 2383 of 2500 took 0.022s
#   training loss:		0.150018
#   validation loss:		0.142354
# Epoch 2384 of 2500 took 0.024s
#   training loss:		0.149899
#   validation loss:		0.141781
# Epoch 2385 of 2500 took 0.027s
#   training loss:		0.149975
#   validation loss:		0.143244
# Epoch 2386 of 2500 took 0.024s
#   training loss:		0.149655
#   validation loss:		0.141322
# Epoch 2387 of 2500 took 0.025s
#   training loss:		0.149602
#   validation loss:		0.142109
# Epoch 2388 of 2500 took 0.024s
#   training loss:		0.149524
#   validation loss:		0.141738
# Epoch 2389 of 2500 took 0.021s
#   training loss:		0.149737
#   validation loss:		0.142497
# Epoch 2390 of 2500 took 0.022s
#   training loss:		0.149681
#   validation loss:		0.141746
# Epoch 2391 of 2500 took 0.053s
#   training loss:		0.149377
#   validation loss:		0.140808
# Epoch 2392 of 2500 took 0.080s
#   training loss:		0.149866
#   validation loss:		0.141803
# Epoch 2393 of 2500 took 0.025s
#   training loss:		0.149686
#   validation loss:		0.142405
# Epoch 2394 of 2500 took 0.023s
#   training loss:		0.149377
#   validation loss:		0.140973
# Epoch 2395 of 2500 took 0.021s
#   training loss:		0.149379
#   validation loss:		0.141088
# Epoch 2396 of 2500 took 0.021s
#   training loss:		0.149413
#   validation loss:		0.142801
# Epoch 2397 of 2500 took 0.021s
#   training loss:		0.149739
#   validation loss:		0.141949
# Epoch 2398 of 2500 took 0.022s
#   training loss:		0.149918
#   validation loss:		0.142835
# Epoch 2399 of 2500 took 0.023s
#   training loss:		0.149015
#   validation loss:		0.141690
# Epoch 2400 of 2500 took 0.023s
#   training loss:		0.149225
#   validation loss:		0.141130
# Epoch 2401 of 2500 took 0.025s
#   training loss:		0.149638
#   validation loss:		0.141482
# Epoch 2402 of 2500 took 0.024s
#   training loss:		0.149532
#   validation loss:		0.141399
# Epoch 2403 of 2500 took 0.026s
#   training loss:		0.150779
#   validation loss:		0.141547
# Epoch 2404 of 2500 took 0.020s
#   training loss:		0.149630
#   validation loss:		0.140766
# Epoch 2405 of 2500 took 0.020s
#   training loss:		0.149559
#   validation loss:		0.143548
# Epoch 2406 of 2500 took 0.021s
#   training loss:		0.149810
#   validation loss:		0.141271
# Epoch 2407 of 2500 took 0.022s
#   training loss:		0.149134
#   validation loss:		0.141015
# Epoch 2408 of 2500 took 0.021s
#   training loss:		0.149660
#   validation loss:		0.141460
# Epoch 2409 of 2500 took 0.023s
#   training loss:		0.149796
#   validation loss:		0.141549
# Epoch 2410 of 2500 took 0.024s
#   training loss:		0.149190
#   validation loss:		0.142178
# Epoch 2411 of 2500 took 0.024s
#   training loss:		0.149014
#   validation loss:		0.141527
# Epoch 2412 of 2500 took 0.028s
#   training loss:		0.148724
#   validation loss:		0.141094
# Epoch 2413 of 2500 took 0.029s
#   training loss:		0.149115
#   validation loss:		0.142044
# Epoch 2414 of 2500 took 0.025s
#   training loss:		0.148923
#   validation loss:		0.141944
# Epoch 2415 of 2500 took 0.025s
#   training loss:		0.148841
#   validation loss:		0.141807
# Epoch 2416 of 2500 took 0.024s
#   training loss:		0.149995
#   validation loss:		0.141260
# Epoch 2417 of 2500 took 0.023s
#   training loss:		0.149521
#   validation loss:		0.141795
# Epoch 2418 of 2500 took 0.024s
#   training loss:		0.148845
#   validation loss:		0.141876
# Epoch 2419 of 2500 took 0.024s
#   training loss:		0.149140
#   validation loss:		0.141017
# Epoch 2420 of 2500 took 0.022s
#   training loss:		0.149117
#   validation loss:		0.141924
# Epoch 2421 of 2500 took 0.024s
#   training loss:		0.148698
#   validation loss:		0.140536
# Epoch 2422 of 2500 took 0.023s
#   training loss:		0.149609
#   validation loss:		0.141581
# Epoch 2423 of 2500 took 0.022s
#   training loss:		0.148776
#   validation loss:		0.141430
# Epoch 2424 of 2500 took 0.023s
#   training loss:		0.148786
#   validation loss:		0.140641
# Epoch 2425 of 2500 took 0.022s
#   training loss:		0.148616
#   validation loss:		0.141315
# Epoch 2426 of 2500 took 0.023s
#   training loss:		0.148977
#   validation loss:		0.142706
# Epoch 2427 of 2500 took 0.025s
#   training loss:		0.148948
#   validation loss:		0.142400
# Epoch 2428 of 2500 took 0.026s
#   training loss:		0.148646
#   validation loss:		0.140650
# Epoch 2429 of 2500 took 0.024s
#   training loss:		0.148853
#   validation loss:		0.141028
# Epoch 2430 of 2500 took 0.025s
#   training loss:		0.148682
#   validation loss:		0.142466
# Epoch 2431 of 2500 took 0.024s
#   training loss:		0.149186
#   validation loss:		0.140332
# Epoch 2432 of 2500 took 0.023s
#   training loss:		0.150110
#   validation loss:		0.140655
# Epoch 2433 of 2500 took 0.023s
#   training loss:		0.148399
#   validation loss:		0.142884
# Epoch 2434 of 2500 took 0.032s
#   training loss:		0.148763
#   validation loss:		0.141475
# Epoch 2435 of 2500 took 0.025s
#   training loss:		0.148865
#   validation loss:		0.140553
# Epoch 2436 of 2500 took 0.022s
#   training loss:		0.149576
#   validation loss:		0.140650
# Epoch 2437 of 2500 took 0.022s
#   training loss:		0.148906
#   validation loss:		0.141405
# Epoch 2438 of 2500 took 0.022s
#   training loss:		0.148571
#   validation loss:		0.141211
# Epoch 2439 of 2500 took 0.024s
#   training loss:		0.148717
#   validation loss:		0.144215
# Epoch 2440 of 2500 took 0.020s
#   training loss:		0.148982
#   validation loss:		0.140455
# Epoch 2441 of 2500 took 0.021s
#   training loss:		0.148887
#   validation loss:		0.140657
# Epoch 2442 of 2500 took 0.020s
#   training loss:		0.148581
#   validation loss:		0.141815
# Epoch 2443 of 2500 took 0.021s
#   training loss:		0.149066
#   validation loss:		0.141066
# Epoch 2444 of 2500 took 0.021s
#   training loss:		0.148576
#   validation loss:		0.139943
# Epoch 2445 of 2500 took 0.023s
#   training loss:		0.148535
#   validation loss:		0.141704
# Epoch 2446 of 2500 took 0.025s
#   training loss:		0.148940
#   validation loss:		0.142183
# Epoch 2447 of 2500 took 0.023s
#   training loss:		0.148950
#   validation loss:		0.141537
# Epoch 2448 of 2500 took 0.021s
#   training loss:		0.148851
#   validation loss:		0.140717
# Epoch 2449 of 2500 took 0.022s
#   training loss:		0.149117
#   validation loss:		0.141785
# Epoch 2450 of 2500 took 0.024s
#   training loss:		0.148161
#   validation loss:		0.141075
# Epoch 2451 of 2500 took 0.030s
#   training loss:		0.149606
#   validation loss:		0.141996
# Epoch 2452 of 2500 took 0.025s
#   training loss:		0.148944
#   validation loss:		0.139681
# Epoch 2453 of 2500 took 0.022s
#   training loss:		0.148472
#   validation loss:		0.141898
# Epoch 2454 of 2500 took 0.023s
#   training loss:		0.148764
#   validation loss:		0.142120
# Epoch 2455 of 2500 took 0.023s
#   training loss:		0.148861
#   validation loss:		0.141599
# Epoch 2456 of 2500 took 0.022s
#   training loss:		0.148533
#   validation loss:		0.140828
# Epoch 2457 of 2500 took 0.022s
#   training loss:		0.148895
#   validation loss:		0.141966
# Epoch 2458 of 2500 took 0.024s
#   training loss:		0.148590
#   validation loss:		0.139633
# Epoch 2459 of 2500 took 0.023s
#   training loss:		0.148401
#   validation loss:		0.141397
# Epoch 2460 of 2500 took 0.022s
#   training loss:		0.148745
#   validation loss:		0.141590
# Epoch 2461 of 2500 took 0.020s
#   training loss:		0.147822
#   validation loss:		0.140334
# Epoch 2462 of 2500 took 0.020s
#   training loss:		0.148300
#   validation loss:		0.142230
# Epoch 2463 of 2500 took 0.021s
#   training loss:		0.148432
#   validation loss:		0.140925
# Epoch 2464 of 2500 took 0.025s
#   training loss:		0.148253
#   validation loss:		0.140514
# Epoch 2465 of 2500 took 0.024s
#   training loss:		0.147783
#   validation loss:		0.139790
# Epoch 2466 of 2500 took 0.022s
#   training loss:		0.148194
#   validation loss:		0.141664
# Epoch 2467 of 2500 took 0.021s
#   training loss:		0.148366
#   validation loss:		0.140928
# Epoch 2468 of 2500 took 0.022s
#   training loss:		0.147941
#   validation loss:		0.140609
# Epoch 2469 of 2500 took 0.023s
#   training loss:		0.147886
#   validation loss:		0.142008
# Epoch 2470 of 2500 took 0.021s
#   training loss:		0.148365
#   validation loss:		0.140800
# Epoch 2471 of 2500 took 0.020s
#   training loss:		0.148153
#   validation loss:		0.141361
# Epoch 2472 of 2500 took 0.020s
#   training loss:		0.147801
#   validation loss:		0.140873
# Epoch 2473 of 2500 took 0.021s
#   training loss:		0.148877
#   validation loss:		0.140315
# Epoch 2474 of 2500 took 0.023s
#   training loss:		0.147825
#   validation loss:		0.142087
# Epoch 2475 of 2500 took 0.022s
#   training loss:		0.148167
#   validation loss:		0.140562
# Epoch 2476 of 2500 took 0.021s
#   training loss:		0.148302
#   validation loss:		0.141250
# Epoch 2477 of 2500 took 0.024s
#   training loss:		0.147907
#   validation loss:		0.140860
# Epoch 2478 of 2500 took 0.026s
#   training loss:		0.147968
#   validation loss:		0.140008
# Epoch 2479 of 2500 took 0.020s
#   training loss:		0.148342
#   validation loss:		0.140959
# Epoch 2480 of 2500 took 0.021s
#   training loss:		0.148077
#   validation loss:		0.140701
# Epoch 2481 of 2500 took 0.023s
#   training loss:		0.148677
#   validation loss:		0.140818
# Epoch 2482 of 2500 took 0.020s
#   training loss:		0.147868
#   validation loss:		0.140837
# Epoch 2483 of 2500 took 0.020s
#   training loss:		0.147440
#   validation loss:		0.140870
# Epoch 2484 of 2500 took 0.025s
#   training loss:		0.147836
#   validation loss:		0.141771
# Epoch 2485 of 2500 took 0.025s
#   training loss:		0.148282
#   validation loss:		0.140316
# Epoch 2486 of 2500 took 0.023s
#   training loss:		0.147593
#   validation loss:		0.141091
# Epoch 2487 of 2500 took 0.024s
#   training loss:		0.148171
#   validation loss:		0.140194
# Epoch 2488 of 2500 took 0.022s
#   training loss:		0.147597
#   validation loss:		0.140686
# Epoch 2489 of 2500 took 0.020s
#   training loss:		0.148195
#   validation loss:		0.140859
# Epoch 2490 of 2500 took 0.025s
#   training loss:		0.148204
#   validation loss:		0.140094
# Epoch 2491 of 2500 took 0.020s
#   training loss:		0.147777
#   validation loss:		0.140588
# Epoch 2492 of 2500 took 0.021s
#   training loss:		0.147594
#   validation loss:		0.140939
# Epoch 2493 of 2500 took 0.021s
#   training loss:		0.147392
#   validation loss:		0.140771
# Epoch 2494 of 2500 took 0.023s
#   training loss:		0.148521
#   validation loss:		0.140299
# Epoch 2495 of 2500 took 0.024s
#   training loss:		0.148590
#   validation loss:		0.141112
# Epoch 2496 of 2500 took 0.023s
#   training loss:		0.147355
#   validation loss:		0.141089
# Epoch 2497 of 2500 took 0.025s
#   training loss:		0.147524
#   validation loss:		0.140618
# Epoch 2498 of 2500 took 0.024s
#   training loss:		0.147787
#   validation loss:		0.140189
# Epoch 2499 of 2500 took 0.020s
#   training loss:		0.147677
#   validation loss:		0.140049
# Epoch 2500 of 2500 took 0.021s
#   training loss:		0.147494
#   validation loss:		0.140158
# Final results:
#   test loss:			0.141284
# cost time:    78.2405 s

# %%
np.savez('model/MLP_1.npz', *lasagne.layers.get_all_param_values(network))

# %%
epoch = range(2500)
plt.figure()
plt.plot(epoch, train_loss, label = 'train loss')
plt.plot(epoch, val_loss, label = 'val loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('epoch')
plt.ylabel('error')
plt.savefig('image/MLP_1_epoch.eps',format="eps",transparent=True, bbox_inches='tight', pad_inches=0.1)

# %%
npdata = np.load('data4/num_accident_OH_norm2.npy')
output = lasagne.layers.get_output(network, inputs= npdata[2016:2352, 0:-1].reshape(336,1,8)).eval()
prediction = np.zeros(336)
prediction = output.reshape(336)
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
i = 0
plt.figure(figsize = (10.5,4))
plt.plot(prediction[0:144], color='r', label = 'Prediction')
plt.plot(npdata[2016:2160, -1], color = 'k', label = 'Observation')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 3:
    plt.text(24+i*48, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1
plt.savefig('image/MLP_1_fit_1.eps',format="eps",transparent=True, bbox_inches='tight', pad_inches=0.1)

plt.figure(figsize = (14,4))
plt.plot(prediction[144:], color='r')
plt.plot(npdata[2160:2353, -1], color = 'k')
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 7:
    plt.text(i*48-120, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1
plt.savefig('image/MLP_1_fit_2.eps',format="eps",transparent=True, bbox_inches='tight', pad_inches=0.1)

# %%
# compute mean  square error on different weekday
olddata = np.load('data4/num_accident_OH_norm2.npy')
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
npdata = olddata[2016:2352, :]
for wd in range(7):
    # Abstract each weekday data
    x = npdata[wd*48:wd*48+48, 0:-1]
    y = npdata[wd*48:wd*48+48, -1]
    output = lasagne.layers.get_output(network, inputs= x.reshape(48,1,8)).eval()
    pre = output.reshape(48)
    ob = y
    test_err = (pre - ob)**2
    test_err = np.mean(test_err)
    print ('{} loss:\t\t\t{}'.format(week[wd], test_err))
# Out:
# Sunday loss:			0.0899353698994
# Monday loss:			0.164571019254
# Tuesday loss:			0.164333973065
# Wednesday loss:			0.138454820732
# Thursday loss:			0.114575505613
# Friday loss:			0.210351932458
# Saturday loss:			0.106765227998

# %% [markdown]
# ### LSTM

# %%
def load_dataset():
    npdata = np.load('data4/num_accident_OH_norm2.npy')
    npdata = npdata.astype(np.float32)
    X_train, X_val = npdata[0:1680, 0:-1].reshape(1680,1,8), npdata[1680:2016, 0:-1].reshape(336,1,8)
    y_train, y_val = npdata[0:1680, -1].reshape(1680,1), npdata[1680:2016, -1].reshape(336,1)
    x_test, y_test = npdata[2016:2352, 0:-1].reshape(336,1,8), npdata[2016:2352, -1].reshape(336,1)
    #print (X_train.shape, y_train.shape, X_val.shape, y_val.shape, npdata.shape)
    return X_train, y_train, X_val, y_val, x_test, y_test


def build_mlp(input_var=None, units = 15):
    
    # Input layer, specifying the expected input shape of the network
    l_in = lasagne.layers.InputLayer(shape=(None,1,8),
                                     input_var=input_var)

    l_hid1 = lasagne.layers.LSTMLayer(
            l_in, num_units = units)
    
    l_hid2 = lasagne.layers.LSTMLayer(
            l_hid1, num_units = units)
    
    l_hid3 = lasagne.layers.LSTMLayer(
            l_hid2, num_units = units)
    
#     l_hid2 = lasagne.layers.DenseLayer(
#             l_hid1, num_units = units*2,
#             nonlinearity=lasagne.nonlinearities.sigmoid,
#             W=lasagne.init.GlorotUniform())
    
#     l_hid3 = lasagne.layers.DenseLayer(
#             l_hid2, num_units = units*2,
#             nonlinearity=lasagne.nonlinearities.sigmoid,
#             W=lasagne.init.GlorotUniform())
        
    l_out = lasagne.layers.DenseLayer(
            l_hid3, num_units=1,
            nonlinearity=lasagne.nonlinearities.linear)

    return l_out

start = time.clock()
network, train_loss, val_loss = train_mlp(num_epochs=2500, learning_rate=0.02)
end = time.clock()
print ("cost time: {:10.6} s".format(end - start))
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 2500 took 0.057s
#   training loss:		1.008848
#   validation loss:		1.001791
# Epoch 2 of 2500 took 0.055s
#   training loss:		1.008278
#   validation loss:		1.002349
# Epoch 3 of 2500 took 0.053s
#   training loss:		1.008992
#   validation loss:		1.002900
# Epoch 4 of 2500 took 0.062s
#   training loss:		1.008661
#   validation loss:		1.002566
# Epoch 5 of 2500 took 0.064s
#   training loss:		1.008247
#   validation loss:		1.001814
# Epoch 6 of 2500 took 0.058s
#   training loss:		1.008855
#   validation loss:		1.001587
# Epoch 7 of 2500 took 0.059s
#   training loss:		1.009739
#   validation loss:		1.002566
# Epoch 8 of 2500 took 0.063s
#   training loss:		1.008861
#   validation loss:		1.002317
# Epoch 9 of 2500 took 0.056s
#   training loss:		1.008449
#   validation loss:		1.001881
# Epoch 10 of 2500 took 0.054s
#   training loss:		1.008972
#   validation loss:		1.001653
# Epoch 11 of 2500 took 0.057s
#   training loss:		1.008374
#   validation loss:		1.002335
# Epoch 12 of 2500 took 0.067s
#   training loss:		1.008596
#   validation loss:		1.002377
# Epoch 13 of 2500 took 0.064s
#   training loss:		1.008900
#   validation loss:		1.002299
# Epoch 14 of 2500 took 0.062s
#   training loss:		1.008299
#   validation loss:		1.002549
# Epoch 15 of 2500 took 0.058s
#   training loss:		1.008539
#   validation loss:		1.002453
# Epoch 16 of 2500 took 0.058s
#   training loss:		1.008884
#   validation loss:		1.001858
# Epoch 17 of 2500 took 0.057s
#   training loss:		1.008744
#   validation loss:		1.002156
# Epoch 18 of 2500 took 0.055s
#   training loss:		1.008508
#   validation loss:		1.002184
# Epoch 19 of 2500 took 0.057s
#   training loss:		1.008369
#   validation loss:		1.002522
# Epoch 20 of 2500 took 0.058s
#   training loss:		1.008816
#   validation loss:		1.002228
# Epoch 21 of 2500 took 0.060s
#   training loss:		1.008334
#   validation loss:		1.002512
# Epoch 22 of 2500 took 0.060s
#   training loss:		1.008399
#   validation loss:		1.002417
# Epoch 23 of 2500 took 0.059s
#   training loss:		1.008502
#   validation loss:		1.002472
# Epoch 24 of 2500 took 0.063s
#   training loss:		1.008580
#   validation loss:		1.002013
# Epoch 25 of 2500 took 0.063s
#   training loss:		1.008723
#   validation loss:		1.002017
# Epoch 26 of 2500 took 0.057s
#   training loss:		1.008479
#   validation loss:		1.002435
# Epoch 27 of 2500 took 0.057s
#   training loss:		1.008611
#   validation loss:		1.002344
# Epoch 28 of 2500 took 0.061s
#   training loss:		1.008613
#   validation loss:		1.002367
# Epoch 29 of 2500 took 0.057s
#   training loss:		1.008480
#   validation loss:		1.001762
# Epoch 30 of 2500 took 0.054s
#   training loss:		1.008899
#   validation loss:		1.001663
# Epoch 31 of 2500 took 0.057s
#   training loss:		1.008503
#   validation loss:		1.002290
# Epoch 32 of 2500 took 0.060s
#   training loss:		1.008436
#   validation loss:		1.002194
# Epoch 33 of 2500 took 0.057s
#   training loss:		1.008410
#   validation loss:		1.002472
# Epoch 34 of 2500 took 0.061s
#   training loss:		1.008351
#   validation loss:		1.002182
# Epoch 35 of 2500 took 0.058s
#   training loss:		1.008312
#   validation loss:		1.001998
# Epoch 36 of 2500 took 0.058s
#   training loss:		1.008694
#   validation loss:		1.001858
# Epoch 37 of 2500 took 0.058s
#   training loss:		1.009979
#   validation loss:		1.002862
# Epoch 38 of 2500 took 0.055s
#   training loss:		1.008670
#   validation loss:		1.002152
# Epoch 39 of 2500 took 0.054s
#   training loss:		1.008344
#   validation loss:		1.001786
# Epoch 40 of 2500 took 0.061s
#   training loss:		1.008482
#   validation loss:		1.001823
# Epoch 41 of 2500 took 0.057s
#   training loss:		1.008522
#   validation loss:		1.002140
# Epoch 42 of 2500 took 0.057s
#   training loss:		1.008291
#   validation loss:		1.002139
# Epoch 43 of 2500 took 0.057s
#   training loss:		1.008627
#   validation loss:		1.002399
# Epoch 44 of 2500 took 0.057s
#   training loss:		1.008709
#   validation loss:		1.002264
# Epoch 45 of 2500 took 0.058s
#   training loss:		1.008661
#   validation loss:		1.001937
# Epoch 46 of 2500 took 0.055s
#   training loss:		1.008311
#   validation loss:		1.001959
# Epoch 47 of 2500 took 0.056s
#   training loss:		1.008485
#   validation loss:		1.002230
# Epoch 48 of 2500 took 0.061s
#   training loss:		1.008699
#   validation loss:		1.002547
# Epoch 49 of 2500 took 0.056s
#   training loss:		1.008516
#   validation loss:		1.002193
# Epoch 50 of 2500 took 0.055s
#   training loss:		1.009007
#   validation loss:		1.001612
# Epoch 51 of 2500 took 0.057s
#   training loss:		1.008499
#   validation loss:		1.001930
# Epoch 52 of 2500 took 0.059s
#   training loss:		1.008237
#   validation loss:		1.002216
# Epoch 53 of 2500 took 0.057s
#   training loss:		1.008542
#   validation loss:		1.002738
# Epoch 54 of 2500 took 0.057s
#   training loss:		1.008618
#   validation loss:		1.002379
# Epoch 55 of 2500 took 0.058s
#   training loss:		1.008216
#   validation loss:		1.001867
# Epoch 56 of 2500 took 0.057s
#   training loss:		1.008365
#   validation loss:		1.001728
# Epoch 57 of 2500 took 0.057s
#   training loss:		1.008697
#   validation loss:		1.001793
# Epoch 58 of 2500 took 0.058s
#   training loss:		1.008443
#   validation loss:		1.001983
# Epoch 59 of 2500 took 0.056s
#   training loss:		1.008362
#   validation loss:		1.002323
# Epoch 60 of 2500 took 0.060s
#   training loss:		1.008651
#   validation loss:		1.002429
# Epoch 61 of 2500 took 0.054s
#   training loss:		1.008308
#   validation loss:		1.002158
# Epoch 62 of 2500 took 0.057s
#   training loss:		1.008382
#   validation loss:		1.001923
# Epoch 63 of 2500 took 0.054s
#   training loss:		1.008601
#   validation loss:		1.001719
# Epoch 64 of 2500 took 0.058s
#   training loss:		1.008480
#   validation loss:		1.002103
# Epoch 65 of 2500 took 0.057s
#   training loss:		1.008451
#   validation loss:		1.002528
# Epoch 66 of 2500 took 0.055s
#   training loss:		1.009118
#   validation loss:		1.002704
# Epoch 67 of 2500 took 0.058s
#   training loss:		1.008478
#   validation loss:		1.001664
# Epoch 68 of 2500 took 0.061s
#   training loss:		1.008512
#   validation loss:		1.001823
# Epoch 69 of 2500 took 0.058s
#   training loss:		1.008281
#   validation loss:		1.001842
# Epoch 70 of 2500 took 0.055s
#   training loss:		1.008937
#   validation loss:		1.001677
# Epoch 71 of 2500 took 0.055s
#   training loss:		1.008383
#   validation loss:		1.002220
# Epoch 72 of 2500 took 0.058s
#   training loss:		1.008311
#   validation loss:		1.002523
# Epoch 73 of 2500 took 0.059s
#   training loss:		1.008721
#   validation loss:		1.002413
# Epoch 74 of 2500 took 0.059s
#   training loss:		1.008579
#   validation loss:		1.001843
# Epoch 75 of 2500 took 0.054s
#   training loss:		1.008484
#   validation loss:		1.002047
# Epoch 76 of 2500 took 0.055s
#   training loss:		1.008231
#   validation loss:		1.002087
# Epoch 77 of 2500 took 0.058s
#   training loss:		1.008294
#   validation loss:		1.001962
# Epoch 78 of 2500 took 0.058s
#   training loss:		1.008413
#   validation loss:		1.001927
# Epoch 79 of 2500 took 0.056s
#   training loss:		1.008490
#   validation loss:		1.002068
# Epoch 80 of 2500 took 0.059s
#   training loss:		1.008256
#   validation loss:		1.002371
# Epoch 81 of 2500 took 0.058s
#   training loss:		1.008746
#   validation loss:		1.002534
# Epoch 82 of 2500 took 0.055s
#   training loss:		1.008328
#   validation loss:		1.001837
# Epoch 83 of 2500 took 0.060s
#   training loss:		1.008489
#   validation loss:		1.001839
# Epoch 84 of 2500 took 0.057s
#   training loss:		1.008460
#   validation loss:		1.002028
# Epoch 85 of 2500 took 0.056s
#   training loss:		1.008280
#   validation loss:		1.002045
# Epoch 86 of 2500 took 0.057s
#   training loss:		1.008303
#   validation loss:		1.001939
# Epoch 87 of 2500 took 0.055s
#   training loss:		1.009129
#   validation loss:		1.001965
# Epoch 88 of 2500 took 0.059s
#   training loss:		1.008379
#   validation loss:		1.001925
# Epoch 89 of 2500 took 0.060s
#   training loss:		1.008509
#   validation loss:		1.001777
# Epoch 90 of 2500 took 0.055s
#   training loss:		1.008473
#   validation loss:		1.001658
# Epoch 91 of 2500 took 0.056s
#   training loss:		1.008386
#   validation loss:		1.002088
# Epoch 92 of 2500 took 0.057s
#   training loss:		1.008548
#   validation loss:		1.001934
# Epoch 93 of 2500 took 0.059s
#   training loss:		1.008332
#   validation loss:		1.002218
# Epoch 94 of 2500 took 0.057s
#   training loss:		1.009296
#   validation loss:		1.001959
# Epoch 95 of 2500 took 0.055s
#   training loss:		1.008738
#   validation loss:		1.001707
# Epoch 96 of 2500 took 0.060s
#   training loss:		1.008860
#   validation loss:		1.002346
# Epoch 97 of 2500 took 0.055s
#   training loss:		1.008576
#   validation loss:		1.002607
# Epoch 98 of 2500 took 0.056s
#   training loss:		1.008496
#   validation loss:		1.001885
# Epoch 99 of 2500 took 0.057s
#   training loss:		1.009056
#   validation loss:		1.002200
# Epoch 100 of 2500 took 0.064s
#   training loss:		1.008241
#   validation loss:		1.001854
# Epoch 101 of 2500 took 0.057s
#   training loss:		1.008362
#   validation loss:		1.001808
# Epoch 102 of 2500 took 0.056s
#   training loss:		1.008243
#   validation loss:		1.001791
# Epoch 103 of 2500 took 0.056s
#   training loss:		1.008789
#   validation loss:		1.002260
# Epoch 104 of 2500 took 0.059s
#   training loss:		1.008229
#   validation loss:		1.001928
# Epoch 105 of 2500 took 0.055s
#   training loss:		1.008380
#   validation loss:		1.001718
# Epoch 106 of 2500 took 0.057s
#   training loss:		1.008357
#   validation loss:		1.002083
# Epoch 107 of 2500 took 0.055s
#   training loss:		1.008555
#   validation loss:		1.001830
# Epoch 108 of 2500 took 0.061s
#   training loss:		1.008288
#   validation loss:		1.002260
# Epoch 109 of 2500 took 0.060s
#   training loss:		1.008316
#   validation loss:		1.002221
# Epoch 110 of 2500 took 0.059s
#   training loss:		1.008703
#   validation loss:		1.002032
# Epoch 111 of 2500 took 0.056s
#   training loss:		1.008357
#   validation loss:		1.002046
# Epoch 112 of 2500 took 0.059s
#   training loss:		1.008753
#   validation loss:		1.001813
# Epoch 113 of 2500 took 0.055s
#   training loss:		1.008183
#   validation loss:		1.002426
# Epoch 114 of 2500 took 0.059s
#   training loss:		1.008557
#   validation loss:		1.002698
# Epoch 115 of 2500 took 0.057s
#   training loss:		1.009846
#   validation loss:		1.001609
# Epoch 116 of 2500 took 0.059s
#   training loss:		1.008343
#   validation loss:		1.002223
# Epoch 117 of 2500 took 0.056s
#   training loss:		1.008322
#   validation loss:		1.002386
# Epoch 118 of 2500 took 0.057s
#   training loss:		1.008774
#   validation loss:		1.001872
# Epoch 119 of 2500 took 0.058s
#   training loss:		1.008220
#   validation loss:		1.002055
# Epoch 120 of 2500 took 0.057s
#   training loss:		1.008367
#   validation loss:		1.002489
# Epoch 121 of 2500 took 0.057s
#   training loss:		1.008423
#   validation loss:		1.002273
# Epoch 122 of 2500 took 0.055s
#   training loss:		1.008212
#   validation loss:		1.001955
# Epoch 123 of 2500 took 0.058s
#   training loss:		1.008338
#   validation loss:		1.001779
# Epoch 124 of 2500 took 0.057s
#   training loss:		1.008403
#   validation loss:		1.002024
# Epoch 125 of 2500 took 0.060s
#   training loss:		1.008302
#   validation loss:		1.001909
# Epoch 126 of 2500 took 0.054s
#   training loss:		1.008197
#   validation loss:		1.001893
# Epoch 127 of 2500 took 0.056s
#   training loss:		1.008472
#   validation loss:		1.001656
# Epoch 128 of 2500 took 0.059s
#   training loss:		1.008446
#   validation loss:		1.002081
# Epoch 129 of 2500 took 0.064s
#   training loss:		1.008545
#   validation loss:		1.001985
# Epoch 130 of 2500 took 0.055s
#   training loss:		1.008354
#   validation loss:		1.002261
# Epoch 131 of 2500 took 0.058s
#   training loss:		1.008453
#   validation loss:		1.002143
# Epoch 132 of 2500 took 0.059s
#   training loss:		1.008658
#   validation loss:		1.002438
# Epoch 133 of 2500 took 0.053s
#   training loss:		1.008581
#   validation loss:		1.002433
# Epoch 134 of 2500 took 0.055s
#   training loss:		1.008245
#   validation loss:		1.001849
# Epoch 135 of 2500 took 0.055s
#   training loss:		1.009479
#   validation loss:		1.001432
# Epoch 136 of 2500 took 0.063s
#   training loss:		1.009408
#   validation loss:		1.002453
# Epoch 137 of 2500 took 0.057s
#   training loss:		1.008934
#   validation loss:		1.001841
# Epoch 138 of 2500 took 0.062s
#   training loss:		1.009192
#   validation loss:		1.002525
# Epoch 139 of 2500 took 0.058s
#   training loss:		1.008580
#   validation loss:		1.001676
# Epoch 140 of 2500 took 0.060s
#   training loss:		1.008365
#   validation loss:		1.001737
# Epoch 141 of 2500 took 0.059s
#   training loss:		1.008197
#   validation loss:		1.001872
# Epoch 142 of 2500 took 0.056s
#   training loss:		1.008433
#   validation loss:		1.002405
# Epoch 143 of 2500 took 0.055s
#   training loss:		1.008656
#   validation loss:		1.002003
# Epoch 144 of 2500 took 0.057s
#   training loss:		1.008530
#   validation loss:		1.002171
# Epoch 145 of 2500 took 0.058s
#   training loss:		1.008347
#   validation loss:		1.002007
# Epoch 146 of 2500 took 0.054s
#   training loss:		1.008794
#   validation loss:		1.001654
# Epoch 147 of 2500 took 0.057s
#   training loss:		1.008911
#   validation loss:		1.002142
# Epoch 148 of 2500 took 0.059s
#   training loss:		1.008294
#   validation loss:		1.002033
# Epoch 149 of 2500 took 0.057s
#   training loss:		1.008749
#   validation loss:		1.001515
# Epoch 150 of 2500 took 0.057s
#   training loss:		1.008247
#   validation loss:		1.001799
# Epoch 151 of 2500 took 0.056s
#   training loss:		1.008522
#   validation loss:		1.001967
# Epoch 152 of 2500 took 0.057s
#   training loss:		1.008118
#   validation loss:		1.002649
# Epoch 153 of 2500 took 0.059s
#   training loss:		1.009073
#   validation loss:		1.002814
# Epoch 154 of 2500 took 0.055s
#   training loss:		1.008330
#   validation loss:		1.001830
# Epoch 155 of 2500 took 0.057s
#   training loss:		1.008552
#   validation loss:		1.001572
# Epoch 156 of 2500 took 0.058s
#   training loss:		1.009422
#   validation loss:		1.001584
# Epoch 157 of 2500 took 0.061s
#   training loss:		1.009169
#   validation loss:		1.002926
# Epoch 158 of 2500 took 0.056s
#   training loss:		1.008428
#   validation loss:		1.002242
# Epoch 159 of 2500 took 0.057s
#   training loss:		1.008899
#   validation loss:		1.001671
# Epoch 160 of 2500 took 0.059s
#   training loss:		1.009008
#   validation loss:		1.002522
# Epoch 161 of 2500 took 0.057s
#   training loss:		1.008704
#   validation loss:		1.001741
# Epoch 162 of 2500 took 0.057s
#   training loss:		1.008439
#   validation loss:		1.002048
# Epoch 163 of 2500 took 0.056s
#   training loss:		1.009239
#   validation loss:		1.002442
# Epoch 164 of 2500 took 0.063s
#   training loss:		1.008193
#   validation loss:		1.001987
# Epoch 165 of 2500 took 0.059s
#   training loss:		1.008265
#   validation loss:		1.001591
# Epoch 166 of 2500 took 0.058s
#   training loss:		1.008458
#   validation loss:		1.001376
# Epoch 167 of 2500 took 0.059s
#   training loss:		1.008586
#   validation loss:		1.001907
# Epoch 168 of 2500 took 0.059s
#   training loss:		1.008615
#   validation loss:		1.001783
# Epoch 169 of 2500 took 0.058s
#   training loss:		1.008304
#   validation loss:		1.002158
# Epoch 170 of 2500 took 0.055s
#   training loss:		1.008336
#   validation loss:		1.002528
# Epoch 171 of 2500 took 0.057s
#   training loss:		1.008345
#   validation loss:		1.002111
# Epoch 172 of 2500 took 0.057s
#   training loss:		1.009011
#   validation loss:		1.002264
# Epoch 173 of 2500 took 0.056s
#   training loss:		1.008247
#   validation loss:		1.001559
# Epoch 174 of 2500 took 0.057s
#   training loss:		1.008193
#   validation loss:		1.001525
# Epoch 175 of 2500 took 0.058s
#   training loss:		1.008401
#   validation loss:		1.001703
# Epoch 176 of 2500 took 0.057s
#   training loss:		1.008572
#   validation loss:		1.001863
# Epoch 177 of 2500 took 0.059s
#   training loss:		1.008203
#   validation loss:		1.002525
# Epoch 178 of 2500 took 0.054s
#   training loss:		1.008544
#   validation loss:		1.002361
# Epoch 179 of 2500 took 0.055s
#   training loss:		1.008148
#   validation loss:		1.001954
# Epoch 180 of 2500 took 0.057s
#   training loss:		1.008318
#   validation loss:		1.001937
# Epoch 181 of 2500 took 0.058s
#   training loss:		1.008537
#   validation loss:		1.001798
# Epoch 182 of 2500 took 0.055s
#   training loss:		1.008750
#   validation loss:		1.002409
# Epoch 183 of 2500 took 0.057s
#   training loss:		1.008258
#   validation loss:		1.001875
# Epoch 184 of 2500 took 0.058s
#   training loss:		1.008196
#   validation loss:		1.001799
# Epoch 185 of 2500 took 0.055s
#   training loss:		1.008161
#   validation loss:		1.001872
# Epoch 186 of 2500 took 0.057s
#   training loss:		1.008395
#   validation loss:		1.002338
# Epoch 187 of 2500 took 0.057s
#   training loss:		1.008198
#   validation loss:		1.002089
# Epoch 188 of 2500 took 0.057s
#   training loss:		1.008134
#   validation loss:		1.001704
# Epoch 189 of 2500 took 0.057s
#   training loss:		1.008659
#   validation loss:		1.001577
# Epoch 190 of 2500 took 0.058s
#   training loss:		1.008157
#   validation loss:		1.002088
# Epoch 191 of 2500 took 0.055s
#   training loss:		1.008309
#   validation loss:		1.002077
# Epoch 192 of 2500 took 0.059s
#   training loss:		1.008199
#   validation loss:		1.002215
# Epoch 193 of 2500 took 0.057s
#   training loss:		1.008143
#   validation loss:		1.002026
# Epoch 194 of 2500 took 0.057s
#   training loss:		1.008585
#   validation loss:		1.002101
# Epoch 195 of 2500 took 0.057s
#   training loss:		1.008035
#   validation loss:		1.001716
# Epoch 196 of 2500 took 0.060s
#   training loss:		1.008542
#   validation loss:		1.001396
# Epoch 197 of 2500 took 0.055s
#   training loss:		1.008160
#   validation loss:		1.001830
# Epoch 198 of 2500 took 0.055s
#   training loss:		1.008196
#   validation loss:		1.002073
# Epoch 199 of 2500 took 0.057s
#   training loss:		1.008326
#   validation loss:		1.002328
# Epoch 200 of 2500 took 0.059s
#   training loss:		1.008566
#   validation loss:		1.002239
# Epoch 201 of 2500 took 0.058s
#   training loss:		1.008101
#   validation loss:		1.001914
# Epoch 202 of 2500 took 0.056s
#   training loss:		1.008427
#   validation loss:		1.001544
# Epoch 203 of 2500 took 0.058s
#   training loss:		1.008167
#   validation loss:		1.001768
# Epoch 204 of 2500 took 0.056s
#   training loss:		1.008591
#   validation loss:		1.001856
# Epoch 205 of 2500 took 0.059s
#   training loss:		1.008218
#   validation loss:		1.002481
# Epoch 206 of 2500 took 0.055s
#   training loss:		1.008419
#   validation loss:		1.002236
# Epoch 207 of 2500 took 0.055s
#   training loss:		1.008179
#   validation loss:		1.001767
# Epoch 208 of 2500 took 0.058s
#   training loss:		1.008781
#   validation loss:		1.002122
# Epoch 209 of 2500 took 0.059s
#   training loss:		1.008160
#   validation loss:		1.001580
# Epoch 210 of 2500 took 0.060s
#   training loss:		1.008338
#   validation loss:		1.001570
# Epoch 211 of 2500 took 0.055s
#   training loss:		1.008845
#   validation loss:		1.002031
# Epoch 212 of 2500 took 0.059s
#   training loss:		1.008098
#   validation loss:		1.001636
# Epoch 213 of 2500 took 0.054s
#   training loss:		1.008677
#   validation loss:		1.001877
# Epoch 214 of 2500 took 0.055s
#   training loss:		1.008284
#   validation loss:		1.001440
# Epoch 215 of 2500 took 0.056s
#   training loss:		1.008299
#   validation loss:		1.001537
# Epoch 216 of 2500 took 0.056s
#   training loss:		1.008458
#   validation loss:		1.002166
# Epoch 217 of 2500 took 0.058s
#   training loss:		1.008425
#   validation loss:		1.002157
# Epoch 218 of 2500 took 0.054s
#   training loss:		1.008314
#   validation loss:		1.001482
# Epoch 219 of 2500 took 0.056s
#   training loss:		1.008285
#   validation loss:		1.001435
# Epoch 220 of 2500 took 0.057s
#   training loss:		1.008055
#   validation loss:		1.001825
# Epoch 221 of 2500 took 0.059s
#   training loss:		1.007950
#   validation loss:		1.002266
# Epoch 222 of 2500 took 0.055s
#   training loss:		1.008149
#   validation loss:		1.002448
# Epoch 223 of 2500 took 0.058s
#   training loss:		1.008043
#   validation loss:		1.002025
# Epoch 224 of 2500 took 0.057s
#   training loss:		1.008065
#   validation loss:		1.001661
# Epoch 225 of 2500 took 0.056s
#   training loss:		1.008225
#   validation loss:		1.001629
# Epoch 226 of 2500 took 0.056s
#   training loss:		1.008105
#   validation loss:		1.001477
# Epoch 227 of 2500 took 0.056s
#   training loss:		1.008356
#   validation loss:		1.001555
# Epoch 228 of 2500 took 0.058s
#   training loss:		1.008742
#   validation loss:		1.002269
# Epoch 229 of 2500 took 0.057s
#   training loss:		1.008125
#   validation loss:		1.001835
# Epoch 230 of 2500 took 0.058s
#   training loss:		1.008128
#   validation loss:		1.001777
# Epoch 231 of 2500 took 0.055s
#   training loss:		1.008564
#   validation loss:		1.001743
# Epoch 232 of 2500 took 0.058s
#   training loss:		1.008925
#   validation loss:		1.002635
# Epoch 233 of 2500 took 0.057s
#   training loss:		1.008058
#   validation loss:		1.001878
# Epoch 234 of 2500 took 0.058s
#   training loss:		1.009036
#   validation loss:		1.001302
# Epoch 235 of 2500 took 0.056s
#   training loss:		1.008198
#   validation loss:		1.001895
# Epoch 236 of 2500 took 0.058s
#   training loss:		1.008116
#   validation loss:		1.002079
# Epoch 237 of 2500 took 0.058s
#   training loss:		1.008358
#   validation loss:		1.002478
# Epoch 238 of 2500 took 0.059s
#   training loss:		1.008219
#   validation loss:		1.001729
# Epoch 239 of 2500 took 0.057s
#   training loss:		1.007960
#   validation loss:		1.001696
# Epoch 240 of 2500 took 0.064s
#   training loss:		1.008124
#   validation loss:		1.001691
# Epoch 241 of 2500 took 0.057s
#   training loss:		1.008447
#   validation loss:		1.002082
# Epoch 242 of 2500 took 0.054s
#   training loss:		1.008268
#   validation loss:		1.001754
# Epoch 243 of 2500 took 0.057s
#   training loss:		1.008006
#   validation loss:		1.001680
# Epoch 244 of 2500 took 0.057s
#   training loss:		1.007979
#   validation loss:		1.001590
# Epoch 245 of 2500 took 0.056s
#   training loss:		1.008631
#   validation loss:		1.001903
# Epoch 246 of 2500 took 0.058s
#   training loss:		1.008454
#   validation loss:		1.002284
# Epoch 247 of 2500 took 0.057s
#   training loss:		1.008403
#   validation loss:		1.001592
# Epoch 248 of 2500 took 0.057s
#   training loss:		1.008091
#   validation loss:		1.001589
# Epoch 249 of 2500 took 0.056s
#   training loss:		1.007977
#   validation loss:		1.001692
# Epoch 250 of 2500 took 0.059s
#   training loss:		1.008274
#   validation loss:		1.002004
# Epoch 251 of 2500 took 0.057s
#   training loss:		1.008060
#   validation loss:		1.001583
# Epoch 252 of 2500 took 0.058s
#   training loss:		1.008032
#   validation loss:		1.001570
# Epoch 253 of 2500 took 0.060s
#   training loss:		1.008223
#   validation loss:		1.001645
# Epoch 254 of 2500 took 0.055s
#   training loss:		1.007949
#   validation loss:		1.001906
# Epoch 255 of 2500 took 0.055s
#   training loss:		1.008435
#   validation loss:		1.001866
# Epoch 256 of 2500 took 0.055s
#   training loss:		1.008081
#   validation loss:		1.001755
# Epoch 257 of 2500 took 0.056s
#   training loss:		1.007917
#   validation loss:		1.002003
# Epoch 258 of 2500 took 0.058s
#   training loss:		1.008060
#   validation loss:		1.002184
# Epoch 259 of 2500 took 0.060s
#   training loss:		1.008006
#   validation loss:		1.001877
# Epoch 260 of 2500 took 0.058s
#   training loss:		1.008877
#   validation loss:		1.001317
# Epoch 261 of 2500 took 0.059s
#   training loss:		1.008105
#   validation loss:		1.001776
# Epoch 262 of 2500 took 0.055s
#   training loss:		1.008283
#   validation loss:		1.001940
# Epoch 263 of 2500 took 0.056s
#   training loss:		1.008659
#   validation loss:		1.002400
# Epoch 264 of 2500 took 0.058s
#   training loss:		1.007977
#   validation loss:		1.001613
# Epoch 265 of 2500 took 0.057s
#   training loss:		1.008605
#   validation loss:		1.001342
# Epoch 266 of 2500 took 0.056s
#   training loss:		1.007902
#   validation loss:		1.001670
# Epoch 267 of 2500 took 0.057s
#   training loss:		1.008589
#   validation loss:		1.002188
# Epoch 268 of 2500 took 0.057s
#   training loss:		1.007938
#   validation loss:		1.001773
# Epoch 269 of 2500 took 0.056s
#   training loss:		1.008235
#   validation loss:		1.001419
# Epoch 270 of 2500 took 0.057s
#   training loss:		1.008096
#   validation loss:		1.001660
# Epoch 271 of 2500 took 0.062s
#   training loss:		1.007845
#   validation loss:		1.002010
# Epoch 272 of 2500 took 0.056s
#   training loss:		1.008189
#   validation loss:		1.001871
# Epoch 273 of 2500 took 0.058s
#   training loss:		1.008499
#   validation loss:		1.002163
# Epoch 274 of 2500 took 0.054s
#   training loss:		1.008034
#   validation loss:		1.001580
# Epoch 275 of 2500 took 0.056s
#   training loss:		1.008065
#   validation loss:		1.001460
# Epoch 276 of 2500 took 0.058s
#   training loss:		1.008011
#   validation loss:		1.001533
# Epoch 277 of 2500 took 0.058s
#   training loss:		1.008102
#   validation loss:		1.001710
# Epoch 278 of 2500 took 0.056s
#   training loss:		1.008346
#   validation loss:		1.002510
# Epoch 279 of 2500 took 0.057s
#   training loss:		1.008284
#   validation loss:		1.001955
# Epoch 280 of 2500 took 0.058s
#   training loss:		1.008438
#   validation loss:		1.001233
# Epoch 281 of 2500 took 0.060s
#   training loss:		1.007920
#   validation loss:		1.001512
# Epoch 282 of 2500 took 0.055s
#   training loss:		1.008028
#   validation loss:		1.001886
# Epoch 283 of 2500 took 0.055s
#   training loss:		1.007895
#   validation loss:		1.001628
# Epoch 284 of 2500 took 0.058s
#   training loss:		1.008126
#   validation loss:		1.001637
# Epoch 285 of 2500 took 0.058s
#   training loss:		1.007866
#   validation loss:		1.001623
# Epoch 286 of 2500 took 0.055s
#   training loss:		1.008154
#   validation loss:		1.001870
# Epoch 287 of 2500 took 0.055s
#   training loss:		1.007872
#   validation loss:		1.001673
# Epoch 288 of 2500 took 0.057s
#   training loss:		1.007907
#   validation loss:		1.001580
# Epoch 289 of 2500 took 0.057s
#   training loss:		1.007910
#   validation loss:		1.001714
# Epoch 290 of 2500 took 0.057s
#   training loss:		1.008008
#   validation loss:		1.001730
# Epoch 291 of 2500 took 0.056s
#   training loss:		1.007850
#   validation loss:		1.001600
# Epoch 292 of 2500 took 0.057s
#   training loss:		1.007849
#   validation loss:		1.001742
# Epoch 293 of 2500 took 0.058s
#   training loss:		1.007959
#   validation loss:		1.001661
# Epoch 294 of 2500 took 0.057s
#   training loss:		1.008019
#   validation loss:		1.001885
# Epoch 295 of 2500 took 0.059s
#   training loss:		1.008463
#   validation loss:		1.001372
# Epoch 296 of 2500 took 0.060s
#   training loss:		1.008292
#   validation loss:		1.001160
# Epoch 297 of 2500 took 0.053s
#   training loss:		1.007775
#   validation loss:		1.001619
# Epoch 298 of 2500 took 0.060s
#   training loss:		1.008139
#   validation loss:		1.002070
# Epoch 299 of 2500 took 0.058s
#   training loss:		1.008293
#   validation loss:		1.002214
# Epoch 300 of 2500 took 0.058s
#   training loss:		1.007785
#   validation loss:		1.001574
# Epoch 301 of 2500 took 0.058s
#   training loss:		1.008013
#   validation loss:		1.001246
# Epoch 302 of 2500 took 0.056s
#   training loss:		1.008474
#   validation loss:		1.001098
# Epoch 303 of 2500 took 0.057s
#   training loss:		1.007800
#   validation loss:		1.001672
# Epoch 304 of 2500 took 0.058s
#   training loss:		1.007868
#   validation loss:		1.002142
# Epoch 305 of 2500 took 0.065s
#   training loss:		1.008785
#   validation loss:		1.003043
# Epoch 306 of 2500 took 0.068s
#   training loss:		1.007968
#   validation loss:		1.001583
# Epoch 307 of 2500 took 0.059s
#   training loss:		1.008002
#   validation loss:		1.001304
# Epoch 308 of 2500 took 0.057s
#   training loss:		1.007894
#   validation loss:		1.001101
# Epoch 309 of 2500 took 0.057s
#   training loss:		1.007827
#   validation loss:		1.001429
# Epoch 310 of 2500 took 0.060s
#   training loss:		1.008081
#   validation loss:		1.001667
# Epoch 311 of 2500 took 0.058s
#   training loss:		1.007942
#   validation loss:		1.001641
# Epoch 312 of 2500 took 0.061s
#   training loss:		1.007968
#   validation loss:		1.001889
# Epoch 313 of 2500 took 0.060s
#   training loss:		1.008007
#   validation loss:		1.001282
# Epoch 314 of 2500 took 0.058s
#   training loss:		1.007809
#   validation loss:		1.001262
# Epoch 315 of 2500 took 0.059s
#   training loss:		1.007728
#   validation loss:		1.001591
# Epoch 316 of 2500 took 0.064s
#   training loss:		1.007830
#   validation loss:		1.001745
# Epoch 317 of 2500 took 0.060s
#   training loss:		1.007829
#   validation loss:		1.001503
# Epoch 318 of 2500 took 0.056s
#   training loss:		1.007831
#   validation loss:		1.001383
# Epoch 319 of 2500 took 0.059s
#   training loss:		1.007760
#   validation loss:		1.001294
# Epoch 320 of 2500 took 0.102s
#   training loss:		1.007839
#   validation loss:		1.001474
# Epoch 321 of 2500 took 0.089s
#   training loss:		1.007801
#   validation loss:		1.001708
# Epoch 322 of 2500 took 0.057s
#   training loss:		1.007772
#   validation loss:		1.001576
# Epoch 323 of 2500 took 0.058s
#   training loss:		1.007818
#   validation loss:		1.001454
# Epoch 324 of 2500 took 0.058s
#   training loss:		1.008020
#   validation loss:		1.001551
# Epoch 325 of 2500 took 0.069s
#   training loss:		1.007766
#   validation loss:		1.001369
# Epoch 326 of 2500 took 0.070s
#   training loss:		1.007924
#   validation loss:		1.001163
# Epoch 327 of 2500 took 0.062s
#   training loss:		1.008039
#   validation loss:		1.001676
# Epoch 328 of 2500 took 0.065s
#   training loss:		1.007779
#   validation loss:		1.001469
# Epoch 329 of 2500 took 0.061s
#   training loss:		1.007816
#   validation loss:		1.001314
# Epoch 330 of 2500 took 0.060s
#   training loss:		1.007730
#   validation loss:		1.001430
# Epoch 331 of 2500 took 0.060s
#   training loss:		1.008325
#   validation loss:		1.002089
# Epoch 332 of 2500 took 0.059s
#   training loss:		1.007822
#   validation loss:		1.001295
# Epoch 333 of 2500 took 0.057s
#   training loss:		1.008135
#   validation loss:		1.001367
# Epoch 334 of 2500 took 0.055s
#   training loss:		1.007754
#   validation loss:		1.001111
# Epoch 335 of 2500 took 0.058s
#   training loss:		1.008362
#   validation loss:		1.001022
# Epoch 336 of 2500 took 0.059s
#   training loss:		1.008513
#   validation loss:		1.002134
# Epoch 337 of 2500 took 0.059s
#   training loss:		1.008144
#   validation loss:		1.001344
# Epoch 338 of 2500 took 0.062s
#   training loss:		1.007677
#   validation loss:		1.001332
# Epoch 339 of 2500 took 0.058s
#   training loss:		1.007789
#   validation loss:		1.001643
# Epoch 340 of 2500 took 0.055s
#   training loss:		1.007659
#   validation loss:		1.001293
# Epoch 341 of 2500 took 0.057s
#   training loss:		1.007950
#   validation loss:		1.001446
# Epoch 342 of 2500 took 0.058s
#   training loss:		1.007815
#   validation loss:		1.001042
# Epoch 343 of 2500 took 0.063s
#   training loss:		1.008610
#   validation loss:		1.000973
# Epoch 344 of 2500 took 0.062s
#   training loss:		1.007666
#   validation loss:		1.001888
# Epoch 345 of 2500 took 0.059s
#   training loss:		1.008011
#   validation loss:		1.002369
# Epoch 346 of 2500 took 0.063s
#   training loss:		1.007988
#   validation loss:		1.001450
# Epoch 347 of 2500 took 0.060s
#   training loss:		1.007895
#   validation loss:		1.001154
# Epoch 348 of 2500 took 0.059s
#   training loss:		1.007924
#   validation loss:		1.001039
# Epoch 349 of 2500 took 0.058s
#   training loss:		1.008467
#   validation loss:		1.001761
# Epoch 350 of 2500 took 0.056s
#   training loss:		1.007745
#   validation loss:		1.001005
# Epoch 351 of 2500 took 0.060s
#   training loss:		1.007684
#   validation loss:		1.001047
# Epoch 352 of 2500 took 0.061s
#   training loss:		1.007924
#   validation loss:		1.001398
# Epoch 353 of 2500 took 0.062s
#   training loss:		1.007555
#   validation loss:		1.001612
# Epoch 354 of 2500 took 0.062s
#   training loss:		1.007944
#   validation loss:		1.001338
# Epoch 355 of 2500 took 0.066s
#   training loss:		1.007777
#   validation loss:		1.001174
# Epoch 356 of 2500 took 0.083s
#   training loss:		1.008031
#   validation loss:		1.000835
# Epoch 357 of 2500 took 0.077s
#   training loss:		1.007718
#   validation loss:		1.001049
# Epoch 358 of 2500 took 0.092s
#   training loss:		1.007352
#   validation loss:		1.001867
# Epoch 359 of 2500 took 0.106s
#   training loss:		1.007705
#   validation loss:		1.001927
# Epoch 360 of 2500 took 0.057s
#   training loss:		1.008376
#   validation loss:		1.001631
# Epoch 361 of 2500 took 0.058s
#   training loss:		1.007352
#   validation loss:		1.001057
# Epoch 362 of 2500 took 0.058s
#   training loss:		1.007675
#   validation loss:		1.000856
# Epoch 363 of 2500 took 0.060s
#   training loss:		1.007779
#   validation loss:		1.000934
# Epoch 364 of 2500 took 0.063s
#   training loss:		1.007544
#   validation loss:		1.000890
# Epoch 365 of 2500 took 0.063s
#   training loss:		1.007497
#   validation loss:		1.001229
# Epoch 366 of 2500 took 0.057s
#   training loss:		1.007608
#   validation loss:		1.001168
# Epoch 367 of 2500 took 0.056s
#   training loss:		1.007736
#   validation loss:		1.001094
# Epoch 368 of 2500 took 0.061s
#   training loss:		1.007844
#   validation loss:		1.001987
# Epoch 369 of 2500 took 0.063s
#   training loss:		1.007472
#   validation loss:		1.001335
# Epoch 370 of 2500 took 0.062s
#   training loss:		1.007479
#   validation loss:		1.001081
# Epoch 371 of 2500 took 0.068s
#   training loss:		1.007795
#   validation loss:		1.000756
# Epoch 372 of 2500 took 0.058s
#   training loss:		1.007465
#   validation loss:		1.000983
# Epoch 373 of 2500 took 0.060s
#   training loss:		1.007354
#   validation loss:		1.001425
# Epoch 374 of 2500 took 0.057s
#   training loss:		1.007919
#   validation loss:		1.001739
# Epoch 375 of 2500 took 0.056s
#   training loss:		1.007720
#   validation loss:		1.001404
# Epoch 376 of 2500 took 0.054s
#   training loss:		1.007119
#   validation loss:		1.000655
# Epoch 377 of 2500 took 0.056s
#   training loss:		1.008094
#   validation loss:		1.000434
# Epoch 378 of 2500 took 0.054s
#   training loss:		1.007490
#   validation loss:		1.001074
# Epoch 379 of 2500 took 0.057s
#   training loss:		1.007304
#   validation loss:		1.001432
# Epoch 380 of 2500 took 0.055s
#   training loss:		1.007391
#   validation loss:		1.001542
# Epoch 381 of 2500 took 0.056s
#   training loss:		1.007456
#   validation loss:		1.001344
# Epoch 382 of 2500 took 0.056s
#   training loss:		1.007619
#   validation loss:		1.000698
# Epoch 383 of 2500 took 0.056s
#   training loss:		1.007590
#   validation loss:		1.000745
# Epoch 384 of 2500 took 0.056s
#   training loss:		1.007312
#   validation loss:		1.001003
# Epoch 385 of 2500 took 0.056s
#   training loss:		1.007336
#   validation loss:		1.001732
# Epoch 386 of 2500 took 0.054s
#   training loss:		1.007342
#   validation loss:		1.001334
# Epoch 387 of 2500 took 0.056s
#   training loss:		1.007305
#   validation loss:		1.001188
# Epoch 388 of 2500 took 0.055s
#   training loss:		1.007224
#   validation loss:		1.000813
# Epoch 389 of 2500 took 0.057s
#   training loss:		1.007521
#   validation loss:		1.000486
# Epoch 390 of 2500 took 0.055s
#   training loss:		1.007487
#   validation loss:		1.000808
# Epoch 391 of 2500 took 0.058s
#   training loss:		1.007818
#   validation loss:		1.001006
# Epoch 392 of 2500 took 0.055s
#   training loss:		1.007233
#   validation loss:		1.000871
# Epoch 393 of 2500 took 0.056s
#   training loss:		1.007225
#   validation loss:		1.000626
# Epoch 394 of 2500 took 0.055s
#   training loss:		1.007446
#   validation loss:		1.000928
# Epoch 395 of 2500 took 0.056s
#   training loss:		1.007500
#   validation loss:		1.001303
# Epoch 396 of 2500 took 0.054s
#   training loss:		1.007243
#   validation loss:		1.000726
# Epoch 397 of 2500 took 0.056s
#   training loss:		1.007070
#   validation loss:		1.000577
# Epoch 398 of 2500 took 0.059s
#   training loss:		1.007359
#   validation loss:		1.000573
# Epoch 399 of 2500 took 0.059s
#   training loss:		1.007198
#   validation loss:		1.000792
# Epoch 400 of 2500 took 0.055s
#   training loss:		1.007048
#   validation loss:		1.000926
# Epoch 401 of 2500 took 0.056s
#   training loss:		1.007258
#   validation loss:		1.000964
# Epoch 402 of 2500 took 0.059s
#   training loss:		1.007454
#   validation loss:		1.000490
# Epoch 403 of 2500 took 0.056s
#   training loss:		1.007032
#   validation loss:		1.000683
# Epoch 404 of 2500 took 0.058s
#   training loss:		1.006958
#   validation loss:		1.001160
# Epoch 405 of 2500 took 0.059s
#   training loss:		1.007112
#   validation loss:		1.001436
# Epoch 406 of 2500 took 0.065s
#   training loss:		1.006999
#   validation loss:		1.000869
# Epoch 407 of 2500 took 0.066s
#   training loss:		1.007353
#   validation loss:		1.000330
# Epoch 408 of 2500 took 0.062s
#   training loss:		1.007200
#   validation loss:		1.000324
# Epoch 409 of 2500 took 0.059s
#   training loss:		1.006804
#   validation loss:		1.000869
# Epoch 410 of 2500 took 0.060s
#   training loss:		1.006875
#   validation loss:		1.001146
# Epoch 411 of 2500 took 0.065s
#   training loss:		1.006965
#   validation loss:		1.001068
# Epoch 412 of 2500 took 0.061s
#   training loss:		1.006968
#   validation loss:		1.000775
# Epoch 413 of 2500 took 0.061s
#   training loss:		1.007118
#   validation loss:		1.000146
# Epoch 414 of 2500 took 0.058s
#   training loss:		1.006887
#   validation loss:		1.000239
# Epoch 415 of 2500 took 0.065s
#   training loss:		1.006937
#   validation loss:		1.000790
# Epoch 416 of 2500 took 0.060s
#   training loss:		1.007013
#   validation loss:		1.000523
# Epoch 417 of 2500 took 0.059s
#   training loss:		1.006898
#   validation loss:		1.000259
# Epoch 418 of 2500 took 0.057s
#   training loss:		1.006937
#   validation loss:		1.000790
# Epoch 419 of 2500 took 0.063s
#   training loss:		1.006727
#   validation loss:		1.000659
# Epoch 420 of 2500 took 0.061s
#   training loss:		1.006802
#   validation loss:		1.000188
# Epoch 421 of 2500 took 0.060s
#   training loss:		1.006738
#   validation loss:		1.000231
# Epoch 422 of 2500 took 0.063s
#   training loss:		1.006708
#   validation loss:		1.000019
# Epoch 423 of 2500 took 0.063s
#   training loss:		1.006860
#   validation loss:		1.000312
# Epoch 424 of 2500 took 0.066s
#   training loss:		1.006597
#   validation loss:		1.000298
# Epoch 425 of 2500 took 0.063s
#   training loss:		1.006769
#   validation loss:		1.000326
# Epoch 426 of 2500 took 0.060s
#   training loss:		1.006723
#   validation loss:		1.000011
# Epoch 427 of 2500 took 0.063s
#   training loss:		1.006634
#   validation loss:		1.000079
# Epoch 428 of 2500 took 0.062s
#   training loss:		1.006863
#   validation loss:		1.000612
# Epoch 429 of 2500 took 0.060s
#   training loss:		1.006573
#   validation loss:		1.000261
# Epoch 430 of 2500 took 0.056s
#   training loss:		1.006496
#   validation loss:		1.000074
# Epoch 431 of 2500 took 0.057s
#   training loss:		1.006474
#   validation loss:		1.000092
# Epoch 432 of 2500 took 0.062s
#   training loss:		1.006846
#   validation loss:		1.000241
# Epoch 433 of 2500 took 0.062s
#   training loss:		1.006399
#   validation loss:		1.000192
# Epoch 434 of 2500 took 0.057s
#   training loss:		1.006345
#   validation loss:		0.999852
# Epoch 435 of 2500 took 0.058s
#   training loss:		1.006249
#   validation loss:		0.999938
# Epoch 436 of 2500 took 0.059s
#   training loss:		1.006486
#   validation loss:		0.999756
# Epoch 437 of 2500 took 0.061s
#   training loss:		1.006280
#   validation loss:		1.000181
# Epoch 438 of 2500 took 0.059s
#   training loss:		1.006347
#   validation loss:		0.999973
# Epoch 439 of 2500 took 0.062s
#   training loss:		1.006248
#   validation loss:		1.000015
# Epoch 440 of 2500 took 0.056s
#   training loss:		1.006923
#   validation loss:		1.000529
# Epoch 441 of 2500 took 0.056s
#   training loss:		1.006567
#   validation loss:		1.000015
# Epoch 442 of 2500 took 0.060s
#   training loss:		1.006345
#   validation loss:		0.999258
# Epoch 443 of 2500 took 0.106s
#   training loss:		1.006381
#   validation loss:		0.999478
# Epoch 444 of 2500 took 0.081s
#   training loss:		1.005968
#   validation loss:		0.999662
# Epoch 445 of 2500 took 0.060s
#   training loss:		1.006169
#   validation loss:		1.000236
# Epoch 446 of 2500 took 0.066s
#   training loss:		1.006915
#   validation loss:		0.999614
# Epoch 447 of 2500 took 0.064s
#   training loss:		1.005918
#   validation loss:		0.999886
# Epoch 448 of 2500 took 0.060s
#   training loss:		1.005841
#   validation loss:		0.999866
# Epoch 449 of 2500 took 0.056s
#   training loss:		1.006007
#   validation loss:		0.999826
# Epoch 450 of 2500 took 0.062s
#   training loss:		1.005798
#   validation loss:		0.999560
# Epoch 451 of 2500 took 0.061s
#   training loss:		1.005858
#   validation loss:		0.999214
# Epoch 452 of 2500 took 0.062s
#   training loss:		1.006161
#   validation loss:		0.999379
# Epoch 453 of 2500 took 0.059s
#   training loss:		1.005686
#   validation loss:		0.999124
# Epoch 454 of 2500 took 0.058s
#   training loss:		1.005804
#   validation loss:		0.999166
# Epoch 455 of 2500 took 0.055s
#   training loss:		1.005561
#   validation loss:		0.999437
# Epoch 456 of 2500 took 0.058s
#   training loss:		1.005675
#   validation loss:		0.999552
# Epoch 457 of 2500 took 0.059s
#   training loss:		1.005897
#   validation loss:		0.999162
# Epoch 458 of 2500 took 0.055s
#   training loss:		1.005512
#   validation loss:		0.999518
# Epoch 459 of 2500 took 0.054s
#   training loss:		1.005543
#   validation loss:		0.999462
# Epoch 460 of 2500 took 0.057s
#   training loss:		1.006139
#   validation loss:		0.998899
# Epoch 461 of 2500 took 0.058s
#   training loss:		1.005333
#   validation loss:		0.999264
# Epoch 462 of 2500 took 0.058s
#   training loss:		1.005421
#   validation loss:		0.999231
# Epoch 463 of 2500 took 0.058s
#   training loss:		1.005726
#   validation loss:		0.998789
# Epoch 464 of 2500 took 0.058s
#   training loss:		1.005402
#   validation loss:		0.999185
# Epoch 465 of 2500 took 0.056s
#   training loss:		1.005866
#   validation loss:		0.998710
# Epoch 466 of 2500 took 0.056s
#   training loss:		1.005026
#   validation loss:		0.999215
# Epoch 467 of 2500 took 0.056s
#   training loss:		1.005310
#   validation loss:		0.999289
# Epoch 468 of 2500 took 0.057s
#   training loss:		1.005369
#   validation loss:		0.999239
# Epoch 469 of 2500 took 0.056s
#   training loss:		1.004943
#   validation loss:		0.998382
# Epoch 470 of 2500 took 0.057s
#   training loss:		1.005615
#   validation loss:		0.998097
# Epoch 471 of 2500 took 0.054s
#   training loss:		1.005008
#   validation loss:		0.998552
# Epoch 472 of 2500 took 0.056s
#   training loss:		1.004676
#   validation loss:		0.998972
# Epoch 473 of 2500 took 0.056s
#   training loss:		1.005745
#   validation loss:		0.999501
# Epoch 474 of 2500 took 0.057s
#   training loss:		1.004979
#   validation loss:		0.998469
# Epoch 475 of 2500 took 0.055s
#   training loss:		1.004792
#   validation loss:		0.998141
# Epoch 476 of 2500 took 0.055s
#   training loss:		1.004627
#   validation loss:		0.997873
# Epoch 477 of 2500 took 0.058s
#   training loss:		1.005116
#   validation loss:		0.997775
# Epoch 478 of 2500 took 0.055s
#   training loss:		1.004646
#   validation loss:		0.998623
# Epoch 479 of 2500 took 0.055s
#   training loss:		1.004353
#   validation loss:		0.998435
# Epoch 480 of 2500 took 0.057s
#   training loss:		1.005124
#   validation loss:		0.997763
# Epoch 481 of 2500 took 0.059s
#   training loss:		1.005358
#   validation loss:		0.998689
# Epoch 482 of 2500 took 0.077s
#   training loss:		1.004365
#   validation loss:		0.998038
# Epoch 483 of 2500 took 0.082s
#   training loss:		1.004025
#   validation loss:		0.997417
# Epoch 484 of 2500 took 0.083s
#   training loss:		1.004082
#   validation loss:		0.997338
# Epoch 485 of 2500 took 0.077s
#   training loss:		1.003961
#   validation loss:		0.997435
# Epoch 486 of 2500 took 0.061s
#   training loss:		1.004005
#   validation loss:		0.997824
# Epoch 487 of 2500 took 0.058s
#   training loss:		1.004048
#   validation loss:		0.997339
# Epoch 488 of 2500 took 0.056s
#   training loss:		1.003840
#   validation loss:		0.997658
# Epoch 489 of 2500 took 0.057s
#   training loss:		1.003863
#   validation loss:		0.997422
# Epoch 490 of 2500 took 0.058s
#   training loss:		1.003455
#   validation loss:		0.996922
# Epoch 491 of 2500 took 0.069s
#   training loss:		1.003903
#   validation loss:		0.996649
# Epoch 492 of 2500 took 0.091s
#   training loss:		1.003540
#   validation loss:		0.997109
# Epoch 493 of 2500 took 0.097s
#   training loss:		1.003589
#   validation loss:		0.997601
# Epoch 494 of 2500 took 0.081s
#   training loss:		1.003494
#   validation loss:		0.997090
# Epoch 495 of 2500 took 0.070s
#   training loss:		1.002928
#   validation loss:		0.996542
# Epoch 496 of 2500 took 0.061s
#   training loss:		1.002944
#   validation loss:		0.996132
# Epoch 497 of 2500 took 0.074s
#   training loss:		1.003619
#   validation loss:		0.996447
# Epoch 498 of 2500 took 0.084s
#   training loss:		1.002674
#   validation loss:		0.996086
# Epoch 499 of 2500 took 0.085s
#   training loss:		1.002639
#   validation loss:		0.995930
# Epoch 500 of 2500 took 0.082s
#   training loss:		1.002769
#   validation loss:		0.996079
# Epoch 501 of 2500 took 0.089s
#   training loss:		1.002287
#   validation loss:		0.995886
# Epoch 502 of 2500 took 0.080s
#   training loss:		1.002072
#   validation loss:		0.995570
# Epoch 503 of 2500 took 0.070s
#   training loss:		1.002218
#   validation loss:		0.995396
# Epoch 504 of 2500 took 0.061s
#   training loss:		1.001979
#   validation loss:		0.995581
# Epoch 505 of 2500 took 0.059s
#   training loss:		1.001768
#   validation loss:		0.995772
# Epoch 506 of 2500 took 0.056s
#   training loss:		1.001682
#   validation loss:		0.995245
# Epoch 507 of 2500 took 0.060s
#   training loss:		1.002047
#   validation loss:		0.995554
# Epoch 508 of 2500 took 0.060s
#   training loss:		1.002115
#   validation loss:		0.994430
# Epoch 509 of 2500 took 0.057s
#   training loss:		1.001441
#   validation loss:		0.994515
# Epoch 510 of 2500 took 0.058s
#   training loss:		1.001172
#   validation loss:		0.994867
# Epoch 511 of 2500 took 0.059s
#   training loss:		1.000678
#   validation loss:		0.994544
# Epoch 512 of 2500 took 0.056s
#   training loss:		1.001021
#   validation loss:		0.993925
# Epoch 513 of 2500 took 0.057s
#   training loss:		1.000477
#   validation loss:		0.994160
# Epoch 514 of 2500 took 0.055s
#   training loss:		1.000145
#   validation loss:		0.994298
# Epoch 515 of 2500 took 0.064s
#   training loss:		1.000089
#   validation loss:		0.993962
# Epoch 516 of 2500 took 0.055s
#   training loss:		0.999882
#   validation loss:		0.993801
# Epoch 517 of 2500 took 0.079s
#   training loss:		0.999602
#   validation loss:		0.993217
# Epoch 518 of 2500 took 0.086s
#   training loss:		0.999897
#   validation loss:		0.992528
# Epoch 519 of 2500 took 0.086s
#   training loss:		0.999364
#   validation loss:		0.992665
# Epoch 520 of 2500 took 0.083s
#   training loss:		0.998917
#   validation loss:		0.992911
# Epoch 521 of 2500 took 0.068s
#   training loss:		0.998860
#   validation loss:		0.992237
# Epoch 522 of 2500 took 0.082s
#   training loss:		0.998328
#   validation loss:		0.992193
# Epoch 523 of 2500 took 0.083s
#   training loss:		0.998179
#   validation loss:		0.991876
# Epoch 524 of 2500 took 0.068s
#   training loss:		0.998479
#   validation loss:		0.991812
# Epoch 525 of 2500 took 0.085s
#   training loss:		0.997666
#   validation loss:		0.990672
# Epoch 526 of 2500 took 0.081s
#   training loss:		0.997284
#   validation loss:		0.990478
# Epoch 527 of 2500 took 0.080s
#   training loss:		0.997099
#   validation loss:		0.990340
# Epoch 528 of 2500 took 0.083s
#   training loss:		0.996742
#   validation loss:		0.990384
# Epoch 529 of 2500 took 0.081s
#   training loss:		0.996805
#   validation loss:		0.990501
# Epoch 530 of 2500 took 0.058s
#   training loss:		0.995848
#   validation loss:		0.989360
# Epoch 531 of 2500 took 0.083s
#   training loss:		0.996467
#   validation loss:		0.988601
# Epoch 532 of 2500 took 0.092s
#   training loss:		0.995839
#   validation loss:		0.989038
# Epoch 533 of 2500 took 0.091s
#   training loss:		0.995117
#   validation loss:		0.988076
# Epoch 534 of 2500 took 0.082s
#   training loss:		0.994462
#   validation loss:		0.987981
# Epoch 535 of 2500 took 0.083s
#   training loss:		0.993797
#   validation loss:		0.987484
# Epoch 536 of 2500 took 0.081s
#   training loss:		0.994104
#   validation loss:		0.986773
# Epoch 537 of 2500 took 0.084s
#   training loss:		0.993005
#   validation loss:		0.986712
# Epoch 538 of 2500 took 0.090s
#   training loss:		0.992414
#   validation loss:		0.986212
# Epoch 539 of 2500 took 0.074s
#   training loss:		0.992149
#   validation loss:		0.985522
# Epoch 540 of 2500 took 0.073s
#   training loss:		0.991335
#   validation loss:		0.984740
# Epoch 541 of 2500 took 0.060s
#   training loss:		0.990796
#   validation loss:		0.983997
# Epoch 542 of 2500 took 0.068s
#   training loss:		0.990481
#   validation loss:		0.983859
# Epoch 543 of 2500 took 0.084s
#   training loss:		0.989628
#   validation loss:		0.982921
# Epoch 544 of 2500 took 0.085s
#   training loss:		0.988875
#   validation loss:		0.981923
# Epoch 545 of 2500 took 0.078s
#   training loss:		0.988065
#   validation loss:		0.981047
# Epoch 546 of 2500 took 0.079s
#   training loss:		0.987568
#   validation loss:		0.980383
# Epoch 547 of 2500 took 0.078s
#   training loss:		0.986645
#   validation loss:		0.980327
# Epoch 548 of 2500 took 0.079s
#   training loss:		0.985858
#   validation loss:		0.979021
# Epoch 549 of 2500 took 0.078s
#   training loss:		0.984667
#   validation loss:		0.978247
# Epoch 550 of 2500 took 0.066s
#   training loss:		0.983912
#   validation loss:		0.976960
# Epoch 551 of 2500 took 0.074s
#   training loss:		0.982858
#   validation loss:		0.976207
# Epoch 552 of 2500 took 0.081s
#   training loss:		0.982013
#   validation loss:		0.974734
# Epoch 553 of 2500 took 0.083s
#   training loss:		0.980967
#   validation loss:		0.973994
# Epoch 554 of 2500 took 0.079s
#   training loss:		0.979718
#   validation loss:		0.972198
# Epoch 555 of 2500 took 0.061s
#   training loss:		0.978705
#   validation loss:		0.971305
# Epoch 556 of 2500 took 0.060s
#   training loss:		0.977442
#   validation loss:		0.969533
# Epoch 557 of 2500 took 0.059s
#   training loss:		0.975793
#   validation loss:		0.969010
# Epoch 558 of 2500 took 0.059s
#   training loss:		0.974181
#   validation loss:		0.967117
# Epoch 559 of 2500 took 0.057s
# ...
# Epoch 2318 of 2500 took 0.056s
#   training loss:		0.152051
#   validation loss:		0.141951
# Epoch 2319 of 2500 took 0.070s
#   training loss:		0.149092
#   validation loss:		0.138780
# Epoch 2320 of 2500 took 0.062s
#   training loss:		0.148114
#   validation loss:		0.140244
# Epoch 2321 of 2500 took 0.076s
#   training loss:		0.148973
#   validation loss:		0.140819
# Epoch 2322 of 2500 took 0.058s
#   training loss:		0.149137
#   validation loss:		0.152410
# Epoch 2323 of 2500 took 0.063s
#   training loss:		0.150858
#   validation loss:		0.138013
# Epoch 2324 of 2500 took 0.061s
#   training loss:		0.149744
#   validation loss:		0.142670
# Epoch 2325 of 2500 took 0.060s
#   training loss:		0.155874
#   validation loss:		0.139033
# Epoch 2326 of 2500 took 0.053s
#   training loss:		0.148504
#   validation loss:		0.142537
# Epoch 2327 of 2500 took 0.058s
#   training loss:		0.152719
#   validation loss:		0.138858
# Epoch 2328 of 2500 took 0.056s
#   training loss:		0.149954
#   validation loss:		0.143313
# Epoch 2329 of 2500 took 0.059s
#   training loss:		0.150044
#   validation loss:		0.142138
# Epoch 2330 of 2500 took 0.058s
#   training loss:		0.150040
#   validation loss:		0.145181
# Epoch 2331 of 2500 took 0.059s
#   training loss:		0.150018
#   validation loss:		0.143968
# Epoch 2332 of 2500 took 0.060s
#   training loss:		0.151594
#   validation loss:		0.139182
# Epoch 2333 of 2500 took 0.057s
#   training loss:		0.149198
#   validation loss:		0.142692
# Epoch 2334 of 2500 took 0.057s
#   training loss:		0.150834
#   validation loss:		0.148500
# Epoch 2335 of 2500 took 0.058s
#   training loss:		0.151244
#   validation loss:		0.137370
# Epoch 2336 of 2500 took 0.057s
#   training loss:		0.149628
#   validation loss:		0.139861
# Epoch 2337 of 2500 took 0.062s
#   training loss:		0.152862
#   validation loss:		0.150517
# Epoch 2338 of 2500 took 0.055s
#   training loss:		0.151997
#   validation loss:		0.139027
# Epoch 2339 of 2500 took 0.059s
#   training loss:		0.152812
#   validation loss:		0.151181
# Epoch 2340 of 2500 took 0.057s
#   training loss:		0.154297
#   validation loss:		0.141318
# Epoch 2341 of 2500 took 0.060s
#   training loss:		0.149062
#   validation loss:		0.139329
# Epoch 2342 of 2500 took 0.056s
#   training loss:		0.148427
#   validation loss:		0.145926
# Epoch 2343 of 2500 took 0.060s
#   training loss:		0.150268
#   validation loss:		0.140228
# Epoch 2344 of 2500 took 0.059s
#   training loss:		0.149518
#   validation loss:		0.147389
# Epoch 2345 of 2500 took 0.058s
#   training loss:		0.152186
#   validation loss:		0.140198
# Epoch 2346 of 2500 took 0.057s
#   training loss:		0.148882
#   validation loss:		0.137723
# Epoch 2347 of 2500 took 0.058s
#   training loss:		0.149847
#   validation loss:		0.143691
# Epoch 2348 of 2500 took 0.058s
#   training loss:		0.150181
#   validation loss:		0.140372
# Epoch 2349 of 2500 took 0.061s
#   training loss:		0.149348
#   validation loss:		0.140003
# Epoch 2350 of 2500 took 0.056s
#   training loss:		0.151162
#   validation loss:		0.142089
# Epoch 2351 of 2500 took 0.061s
#   training loss:		0.150334
#   validation loss:		0.143388
# Epoch 2352 of 2500 took 0.058s
#   training loss:		0.148231
#   validation loss:		0.142006
# Epoch 2353 of 2500 took 0.059s
#   training loss:		0.148822
#   validation loss:		0.140261
# Epoch 2354 of 2500 took 0.058s
#   training loss:		0.147869
#   validation loss:		0.140471
# Epoch 2355 of 2500 took 0.057s
#   training loss:		0.151306
#   validation loss:		0.142019
# Epoch 2356 of 2500 took 0.058s
#   training loss:		0.148123
#   validation loss:		0.140018
# Epoch 2357 of 2500 took 0.059s
#   training loss:		0.149650
#   validation loss:		0.140558
# Epoch 2358 of 2500 took 0.059s
#   training loss:		0.153340
#   validation loss:		0.141610
# Epoch 2359 of 2500 took 0.059s
#   training loss:		0.150389
#   validation loss:		0.142136
# Epoch 2360 of 2500 took 0.056s
#   training loss:		0.150159
#   validation loss:		0.145506
# Epoch 2361 of 2500 took 0.061s
#   training loss:		0.152698
#   validation loss:		0.137237
# Epoch 2362 of 2500 took 0.054s
#   training loss:		0.156130
#   validation loss:		0.147576
# Epoch 2363 of 2500 took 0.060s
#   training loss:		0.151474
#   validation loss:		0.138586
# Epoch 2364 of 2500 took 0.057s
#   training loss:		0.149585
#   validation loss:		0.138100
# Epoch 2365 of 2500 took 0.059s
#   training loss:		0.153426
#   validation loss:		0.138918
# Epoch 2366 of 2500 took 0.056s
#   training loss:		0.149511
#   validation loss:		0.139093
# Epoch 2367 of 2500 took 0.060s
#   training loss:		0.152398
#   validation loss:		0.142484
# Epoch 2368 of 2500 took 0.059s
#   training loss:		0.149802
#   validation loss:		0.144140
# Epoch 2369 of 2500 took 0.056s
#   training loss:		0.149679
#   validation loss:		0.136895
# Epoch 2370 of 2500 took 0.057s
#   training loss:		0.148579
#   validation loss:		0.138633
# Epoch 2371 of 2500 took 0.060s
#   training loss:		0.148121
#   validation loss:		0.139570
# Epoch 2372 of 2500 took 0.058s
#   training loss:		0.148502
#   validation loss:		0.139507
# Epoch 2373 of 2500 took 0.061s
#   training loss:		0.149734
#   validation loss:		0.141620
# Epoch 2374 of 2500 took 0.054s
#   training loss:		0.154034
#   validation loss:		0.141162
# Epoch 2375 of 2500 took 0.060s
#   training loss:		0.151222
#   validation loss:		0.140016
# Epoch 2376 of 2500 took 0.057s
#   training loss:		0.148275
#   validation loss:		0.143770
# Epoch 2377 of 2500 took 0.062s
#   training loss:		0.151954
#   validation loss:		0.147173
# Epoch 2378 of 2500 took 0.056s
#   training loss:		0.153359
#   validation loss:		0.141897
# Epoch 2379 of 2500 took 0.062s
#   training loss:		0.147696
#   validation loss:		0.138558
# Epoch 2380 of 2500 took 0.057s
#   training loss:		0.148558
#   validation loss:		0.139849
# Epoch 2381 of 2500 took 0.056s
#   training loss:		0.149007
#   validation loss:		0.156688
# Epoch 2382 of 2500 took 0.057s
#   training loss:		0.153965
#   validation loss:		0.139946
# Epoch 2383 of 2500 took 0.054s
#   training loss:		0.149405
#   validation loss:		0.146091
# Epoch 2384 of 2500 took 0.057s
#   training loss:		0.150004
#   validation loss:		0.138423
# Epoch 2385 of 2500 took 0.061s
#   training loss:		0.150881
#   validation loss:		0.141742
# Epoch 2386 of 2500 took 0.058s
#   training loss:		0.149119
#   validation loss:		0.139735
# Epoch 2387 of 2500 took 0.059s
#   training loss:		0.148279
#   validation loss:		0.141579
# Epoch 2388 of 2500 took 0.059s
#   training loss:		0.149777
#   validation loss:		0.145635
# Epoch 2389 of 2500 took 0.057s
#   training loss:		0.149405
#   validation loss:		0.144230
# Epoch 2390 of 2500 took 0.059s
#   training loss:		0.154322
#   validation loss:		0.138724
# Epoch 2391 of 2500 took 0.056s
#   training loss:		0.149861
#   validation loss:		0.140347
# Epoch 2392 of 2500 took 0.062s
#   training loss:		0.152868
#   validation loss:		0.141209
# Epoch 2393 of 2500 took 0.075s
#   training loss:		0.149414
#   validation loss:		0.138900
# Epoch 2394 of 2500 took 0.059s
#   training loss:		0.149012
#   validation loss:		0.140965
# Epoch 2395 of 2500 took 0.070s
#   training loss:		0.151527
#   validation loss:		0.147459
# Epoch 2396 of 2500 took 0.066s
#   training loss:		0.150492
#   validation loss:		0.148053
# Epoch 2397 of 2500 took 0.067s
#   training loss:		0.151208
#   validation loss:		0.140856
# Epoch 2398 of 2500 took 0.061s
#   training loss:		0.150217
#   validation loss:		0.138454
# Epoch 2399 of 2500 took 0.057s
#   training loss:		0.148667
#   validation loss:		0.139850
# Epoch 2400 of 2500 took 0.061s
#   training loss:		0.149432
#   validation loss:		0.146773
# Epoch 2401 of 2500 took 0.061s
#   training loss:		0.152081
#   validation loss:		0.137863
# Epoch 2402 of 2500 took 0.056s
#   training loss:		0.149742
#   validation loss:		0.161844
# Epoch 2403 of 2500 took 0.073s
#   training loss:		0.157859
#   validation loss:		0.139291
# Epoch 2404 of 2500 took 0.072s
#   training loss:		0.149826
#   validation loss:		0.137692
# Epoch 2405 of 2500 took 0.072s
#   training loss:		0.149114
#   validation loss:		0.141608
# Epoch 2406 of 2500 took 0.085s
#   training loss:		0.148817
#   validation loss:		0.143619
# Epoch 2407 of 2500 took 0.070s
#   training loss:		0.150412
#   validation loss:		0.143761
# Epoch 2408 of 2500 took 0.074s
#   training loss:		0.148200
#   validation loss:		0.139184
# Epoch 2409 of 2500 took 0.060s
#   training loss:		0.149812
#   validation loss:		0.139023
# Epoch 2410 of 2500 took 0.062s
#   training loss:		0.149595
#   validation loss:		0.140197
# Epoch 2411 of 2500 took 0.063s
#   training loss:		0.149758
#   validation loss:		0.147160
# Epoch 2412 of 2500 took 0.067s
#   training loss:		0.150712
#   validation loss:		0.146380
# Epoch 2413 of 2500 took 0.066s
#   training loss:		0.149405
#   validation loss:		0.137406
# Epoch 2414 of 2500 took 0.058s
#   training loss:		0.154161
#   validation loss:		0.139022
# Epoch 2415 of 2500 took 0.067s
#   training loss:		0.148305
#   validation loss:		0.142860
# Epoch 2416 of 2500 took 0.062s
#   training loss:		0.150569
#   validation loss:		0.141725
# Epoch 2417 of 2500 took 0.057s
#   training loss:		0.148646
#   validation loss:		0.138235
# Epoch 2418 of 2500 took 0.065s
#   training loss:		0.152924
#   validation loss:		0.145936
# Epoch 2419 of 2500 took 0.061s
#   training loss:		0.150814
#   validation loss:		0.149429
# Epoch 2420 of 2500 took 0.072s
#   training loss:		0.152305
#   validation loss:		0.148261
# Epoch 2421 of 2500 took 0.058s
#   training loss:		0.149859
#   validation loss:		0.138560
# Epoch 2422 of 2500 took 0.068s
#   training loss:		0.149894
#   validation loss:		0.144160
# Epoch 2423 of 2500 took 0.058s
#   training loss:		0.151141
#   validation loss:		0.138144
# Epoch 2424 of 2500 took 0.064s
#   training loss:		0.148459
#   validation loss:		0.140663
# Epoch 2425 of 2500 took 0.055s
#   training loss:		0.148100
#   validation loss:		0.140491
# Epoch 2426 of 2500 took 0.057s
#   training loss:		0.148956
#   validation loss:		0.140359
# Epoch 2427 of 2500 took 0.062s
#   training loss:		0.150687
#   validation loss:		0.147542
# Epoch 2428 of 2500 took 0.063s
#   training loss:		0.152076
#   validation loss:		0.143214
# Epoch 2429 of 2500 took 0.056s
#   training loss:		0.148929
#   validation loss:		0.139010
# Epoch 2430 of 2500 took 0.063s
#   training loss:		0.150239
#   validation loss:		0.139342
# Epoch 2431 of 2500 took 0.059s
#   training loss:		0.150224
#   validation loss:		0.140143
# Epoch 2432 of 2500 took 0.058s
#   training loss:		0.149456
#   validation loss:		0.139340
# Epoch 2433 of 2500 took 0.067s
#   training loss:		0.148101
#   validation loss:		0.139092
# Epoch 2434 of 2500 took 0.066s
#   training loss:		0.153603
#   validation loss:		0.142154
# Epoch 2435 of 2500 took 0.063s
#   training loss:		0.151657
#   validation loss:		0.140206
# Epoch 2436 of 2500 took 0.071s
#   training loss:		0.149973
#   validation loss:		0.139585
# Epoch 2437 of 2500 took 0.057s
#   training loss:		0.148468
#   validation loss:		0.144505
# Epoch 2438 of 2500 took 0.059s
#   training loss:		0.151465
#   validation loss:		0.139485
# Epoch 2439 of 2500 took 0.066s
#   training loss:		0.151096
#   validation loss:		0.157083
# Epoch 2440 of 2500 took 0.061s
#   training loss:		0.152627
#   validation loss:		0.137928
# Epoch 2441 of 2500 took 0.058s
#   training loss:		0.150105
#   validation loss:		0.138468
# Epoch 2442 of 2500 took 0.057s
#   training loss:		0.149372
#   validation loss:		0.138827
# Epoch 2443 of 2500 took 0.060s
#   training loss:		0.151472
#   validation loss:		0.138378
# Epoch 2444 of 2500 took 0.064s
#   training loss:		0.148344
#   validation loss:		0.138332
# Epoch 2445 of 2500 took 0.055s
#   training loss:		0.150027
#   validation loss:		0.139958
# Epoch 2446 of 2500 took 0.059s
#   training loss:		0.147487
#   validation loss:		0.138936
# Epoch 2447 of 2500 took 0.060s
#   training loss:		0.150173
#   validation loss:		0.139628
# Epoch 2448 of 2500 took 0.063s
#   training loss:		0.147830
#   validation loss:		0.139254
# Epoch 2449 of 2500 took 0.059s
#   training loss:		0.146972
#   validation loss:		0.139591
# Epoch 2450 of 2500 took 0.055s
#   training loss:		0.150020
#   validation loss:		0.142591
# Epoch 2451 of 2500 took 0.065s
#   training loss:		0.150036
#   validation loss:		0.139115
# Epoch 2452 of 2500 took 0.067s
#   training loss:		0.148872
#   validation loss:		0.142173
# Epoch 2453 of 2500 took 0.062s
#   training loss:		0.148485
#   validation loss:		0.141446
# Epoch 2454 of 2500 took 0.059s
#   training loss:		0.147547
#   validation loss:		0.141380
# Epoch 2455 of 2500 took 0.068s
#   training loss:		0.151960
#   validation loss:		0.139283
# Epoch 2456 of 2500 took 0.061s
#   training loss:		0.150003
#   validation loss:		0.137768
# Epoch 2457 of 2500 took 0.059s
#   training loss:		0.150291
#   validation loss:		0.139738
# Epoch 2458 of 2500 took 0.055s
#   training loss:		0.147241
#   validation loss:		0.140815
# Epoch 2459 of 2500 took 0.059s
#   training loss:		0.148586
#   validation loss:		0.139429
# Epoch 2460 of 2500 took 0.060s
#   training loss:		0.148887
#   validation loss:		0.142032
# Epoch 2461 of 2500 took 0.055s
#   training loss:		0.152560
#   validation loss:		0.141028
# Epoch 2462 of 2500 took 0.065s
#   training loss:		0.148876
#   validation loss:		0.142795
# Epoch 2463 of 2500 took 0.057s
#   training loss:		0.149267
#   validation loss:		0.139827
# Epoch 2464 of 2500 took 0.061s
#   training loss:		0.148960
#   validation loss:		0.143728
# Epoch 2465 of 2500 took 0.056s
#   training loss:		0.152793
#   validation loss:		0.141509
# Epoch 2466 of 2500 took 0.060s
#   training loss:		0.148191
#   validation loss:		0.141293
# Epoch 2467 of 2500 took 0.058s
#   training loss:		0.148740
#   validation loss:		0.144464
# Epoch 2468 of 2500 took 0.068s
#   training loss:		0.149930
#   validation loss:		0.137795
# Epoch 2469 of 2500 took 0.081s
#   training loss:		0.148358
#   validation loss:		0.145415
# Epoch 2470 of 2500 took 0.067s
#   training loss:		0.151801
#   validation loss:		0.138534
# Epoch 2471 of 2500 took 0.058s
#   training loss:		0.150334
#   validation loss:		0.140445
# Epoch 2472 of 2500 took 0.079s
#   training loss:		0.149566
#   validation loss:		0.138062
# Epoch 2473 of 2500 took 0.086s
#   training loss:		0.148866
#   validation loss:		0.139036
# Epoch 2474 of 2500 took 0.065s
#   training loss:		0.149297
#   validation loss:		0.140103
# Epoch 2475 of 2500 took 0.057s
#   training loss:		0.147517
#   validation loss:		0.138695
# Epoch 2476 of 2500 took 0.069s
#   training loss:		0.146932
#   validation loss:		0.144762
# Epoch 2477 of 2500 took 0.061s
#   training loss:		0.148623
#   validation loss:		0.140658
# Epoch 2478 of 2500 took 0.058s
#   training loss:		0.148982
#   validation loss:		0.137382
# Epoch 2479 of 2500 took 0.062s
#   training loss:		0.151406
#   validation loss:		0.139625
# Epoch 2480 of 2500 took 0.064s
#   training loss:		0.147656
#   validation loss:		0.137115
# Epoch 2481 of 2500 took 0.061s
#   training loss:		0.150725
#   validation loss:		0.138867
# Epoch 2482 of 2500 took 0.066s
#   training loss:		0.146497
#   validation loss:		0.140082
# Epoch 2483 of 2500 took 0.062s
#   training loss:		0.148716
#   validation loss:		0.139260
# Epoch 2484 of 2500 took 0.065s
#   training loss:		0.151054
#   validation loss:		0.139086
# Epoch 2485 of 2500 took 0.059s
#   training loss:		0.149172
#   validation loss:		0.139413
# Epoch 2486 of 2500 took 0.058s
#   training loss:		0.150962
#   validation loss:		0.140708
# Epoch 2487 of 2500 took 0.067s
#   training loss:		0.151516
#   validation loss:		0.142652
# Epoch 2488 of 2500 took 0.057s
#   training loss:		0.149187
#   validation loss:		0.141590
# Epoch 2489 of 2500 took 0.060s
#   training loss:		0.150314
#   validation loss:		0.137628
# Epoch 2490 of 2500 took 0.067s
#   training loss:		0.150334
#   validation loss:		0.140926
# Epoch 2491 of 2500 took 0.056s
#   training loss:		0.150374
#   validation loss:		0.140024
# Epoch 2492 of 2500 took 0.067s
#   training loss:		0.148880
#   validation loss:		0.143380
# Epoch 2493 of 2500 took 0.057s
#   training loss:		0.149479
#   validation loss:		0.139891
# Epoch 2494 of 2500 took 0.071s
#   training loss:		0.148341
#   validation loss:		0.147691
# Epoch 2495 of 2500 took 0.060s
#   training loss:		0.148708
#   validation loss:		0.140176
# Epoch 2496 of 2500 took 0.058s
#   training loss:		0.148447
#   validation loss:		0.139804
# Epoch 2497 of 2500 took 0.063s
#   training loss:		0.148075
#   validation loss:		0.138088
# Epoch 2498 of 2500 took 0.061s
#   training loss:		0.147848
#   validation loss:		0.139953
# Epoch 2499 of 2500 took 0.057s
#   training loss:		0.149102
#   validation loss:		0.140962
# Epoch 2500 of 2500 took 0.062s
#   training loss:		0.148345
#   validation loss:		0.139802
# Final results:
#   test loss:			0.147328
# cost time:    204.326 s

# %%
np.savez('model/LSTM_3.npz', *lasagne.layers.get_all_param_values(network))

# %%
epoch = range(2500)
plt.figure()
plt.plot(epoch, train_loss, label = 'train loss')
plt.plot(epoch, val_loss, label = 'val loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('epoch')
plt.ylabel('error')


npdata = np.load('data4/num_accident_OH_norm2.npy')
output = lasagne.layers.get_output(network, inputs= npdata[2016:2352, 0:-1].reshape(336,1,8)).eval()
prediction = np.zeros(336)
prediction = output.reshape(336)
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
i = 0
plt.figure(figsize = (10.5,4))
plt.plot(prediction[0:144], color='r')
plt.plot(npdata[2016:2160, -1], color = 'k')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize = 12)
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 3:
    plt.text(24+i*48, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1
#plt.savefig('image/LSTM1_fit_1.eps',format="eps",transparent=True, bbox_inches='tight', pad_inches=0.1)

plt.figure(figsize = (14,4))
plt.plot(prediction[144:], color='r')
plt.plot(npdata[2160:2353, -1], color = 'k')
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 7:
    plt.text(i*48-120, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1
# Out:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
epoch = range(2500)
plt.figure()
plt.plot(epoch, train_loss, label = 'train loss')
plt.plot(epoch, val_loss, label = 'val loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('epoch')
plt.ylabel('error')

# %%
start = time.clock()
x = 0
for i in range(1000):
    x *= 4
end = time.clock()
print ("cost time: {:10.6} s".format(end - start))
# Out:
# cost time:    0.00064 s
