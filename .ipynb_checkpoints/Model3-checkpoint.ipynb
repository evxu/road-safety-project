# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import folium
import time
from IPython.display import display
# %matplotlib inline
matplotlib.style.use('ggplot')
# Out:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
olddata1 = np.load('data4/num_accident2_2009-2015.npy')
olddata2 = np.load('data4/num_accident_tri_OHweekday_2009-2015.npy')
newdata = np.zeros(shape = (2352, 9))
newdata[:, 0:6] = olddata2[:,0:6]
newdata[:, 7] = (olddata1[:,1] - 0.5)/23.5
m = np.mean(olddata1[:,2])
st = np.std(olddata1[:,2])
print (m)
print (st)
newdata[:, 8] = (olddata1[:,2] - m)/st
np.save('data4/num_accident_OH_norm2.npy', newdata)
# Out:
# 43.699829932
# 30.3345860169

# %%
olddata = np.load('data4/num_accident_OH_norm2.npy')
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
models = []
total_loss = np.zeros(7)
start = 0
nfig = 1
plt.figure(figsize = (12,10))
for wd in range(7):
    # Abstract each weekday data
    print (week[wd] + ':')
    newdata = np.zeros(shape = (336,2))
    i = start
    j = 0
    while j<7:
        newdata[j*48:j*48+48, :] = olddata[i:i+48, -2:]
        j+=1
        i+=336
    npdata = newdata
    x = npdata[0:288, 0]
    y = npdata[0:288, 1]
    z = np.polyfit(x, y, 25)
    fitline = np.poly1d(z)
    models.append(fitline)
    
    plt.subplot(3,3,nfig)
    plt.plot(fitline(npdata[288:336, 0]), color = 'r', label = 'prediction')
    plt.plot(npdata[288:336, -1], color = 'k', label = 'observation')
#     plt.xlabel('time slot')
#     plt.ylabel('number of accident(normalised)')
    plt.title(week[wd])
    # compute test loss
    pre = fitline(npdata[288:336, 0])
    ob = npdata[288:336, -1]
    test_err = (pre - ob)**2
    test_err = np.mean(test_err)
    print ('{}test loss:\t\t\t{}'.format(week[wd], test_err))
    total_loss[wd] = test_err
    start += 48
    nfig += 1

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig('image/polynomial_fit2.eps',format="eps",transparent=True, grid = True, bbox_inches='tight', pad_inches=0.1)
print ('Average error on all weekday:\t\t\t{}'.format(total_loss.mean()))
# Out:
# Sunday:
# Sundaytest loss:			0.0843963379143
# Monday:
# Mondaytest loss:			0.165274982197
# Tuesday:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# Tuesdaytest loss:			0.197196196224
# Wednesday:
# Wednesdaytest loss:			0.1535663454
# Thursday:
# Thursdaytest loss:			0.122868977529
# Friday:
# Fridaytest loss:			0.214062126206
# Saturday:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.py:594: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# Saturdaytest loss:			0.100220626371
# Average error on all weekday:			0.14822651312

# %%
from __future__ import print_function

import sys
import os
import time

import numpy as np
import theano
import theano.tensor as T

import lasagne

# ############################# Batch iterator ###############################
# This is just a simple helper function iterating over training data in
# mini-batches of a particular size, optionally in random order. It assumes
# data is available as numpy arrays. For big datasets, you could load numpy
# arrays as memory-mapped files (np.load(..., mmap_mode='r')), or write your
# own custom data iteration function. For small datasets, you can also copy
# them to GPU at once for slightly improved performance. This would involve
# several changes in the main program, though, and is not demonstrated here.
# Notice that this function returns only mini-batches of size `batchsize`.
# If the size of the data is not a multiple of `batchsize`, it will not
# return the last (remaining) mini-batch.

def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]


def train_mlp(model='mlp', num_epochs=50, learning_rate=0.001, train_shuffle=True, batchsize = 336):
    # Load the dataset
    print("Loading data...")
    X_train, y_train, X_val, y_val, X_test, y_test = load_dataset()

    # Prepare Theano variables for inputs and targets
    input_var = T.tensor3('inputs')
    target_var = T.matrix('targets')

    # Create neural network model (depending on first command line parameter)
    print("Building model and compiling functions...")
    
    network = build_mlp(input_var)
    

    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss = lasagne.objectives.squared_error(prediction, target_var)
    loss = loss.mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(
            loss, params, learning_rate=learning_rate, momentum=0.9)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    test_loss = lasagne.objectives.squared_error(test_prediction,
                                                            target_var)
    test_loss = test_loss.mean()
    
    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates, allow_input_downcast = True)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], test_loss, allow_input_downcast = True)

    # Finally, launch the training loop.
    print("Starting training...")
    # We iterate over epochs:
    
    train_loss = np.zeros(num_epochs)
    val_loss = np.zeros(num_epochs)
    
    for epoch in range(num_epochs):
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time.time()
        for batch in iterate_minibatches(X_train, y_train, batchsize = batchsize, shuffle=train_shuffle):
            inputs, targets = batch
            train_err += train_fn(inputs, targets)
            train_batches += 1

        # And a full pass over the validation data:
        val_err = 0
        val_batches = 0
        for batch in iterate_minibatches(X_val, y_val, y_val.shape[0], shuffle=False):
            inputs, targets = batch
            #print (inputs.shape, targets.shape)
            err = val_fn(inputs, targets)
            val_err += err
            val_batches += 1
        
        # save the loss value
        train_loss[epoch] = train_err / train_batches
        val_loss[epoch] = val_err / val_batches
        
        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(
            epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss:\t\t{:.6f}".format(train_loss[epoch]))
        print("  validation loss:\t\t{:.6f}".format(val_loss[epoch]))    

    # After training, we compute and print the test error:
    test_err = 0
    test_batches = 0
    for batch in iterate_minibatches(X_test, y_test, y_test.shape[0], shuffle=False):
        inputs, targets = batch
        err = val_fn(inputs, targets)
        test_err += err
        test_batches += 1
    print("Final results:")
    print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
    return network, train_loss, val_loss
# Optionally, you could now dump the network weights to a file like this:
# np.savez('model.npz', *lasagne.layers.get_all_param_values(network))
#
# And load them again later on like this:
# with np.load('model.npz') as f:
#     param_values = [f['arr_%d' % i] for i in range(len(f.files))]
# lasagne.layers.set_all_param_values(network, param_values)
# Out:
# /Users/XueqiWang/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### ANN network

# %%
def load_dataset():
    npdata = np.load('data4/num_accident_OH_norm2.npy')
    npdata = npdata.astype(np.float32)
    X_train, X_val = npdata[0:1680, 0:-1].reshape(1680,1,8), npdata[1680:2016, 0:-1].reshape(336,1,8)
    y_train, y_val = npdata[0:1680, -1].reshape(1680,1), npdata[1680:2016, -1].reshape(336,1)
    x_test, y_test = npdata[2016:2352, 0:-1].reshape(336,1,8), npdata[2016:2352, -1].reshape(336,1)
    #print (X_train.shape, y_train.shape, X_val.shape, y_val.shape, npdata.shape)
    return X_train, y_train, X_val, y_val, x_test, y_test


def build_mlp(input_var=None, units = 15):
    
    # Input layer, specifying the expected input shape of the network
    l_in = lasagne.layers.InputLayer(shape=(None,1,8),
                                     input_var=input_var)

    l_hid1 = lasagne.layers.LSTMLayer(
            l_in, num_units = units)
    
    l_hid2 = lasagne.layers.DenseLayer(
            l_hid1, num_units = units,
            nonlinearity=lasagne.nonlinearities.sigmoid,
            W=lasagne.init.GlorotUniform())
    
    l_hid3 = lasagne.layers.DenseLayer(
            l_hid2, num_units = units,
            nonlinearity=lasagne.nonlinearities.sigmoid,
            W=lasagne.init.GlorotUniform())
        
    l_out = lasagne.layers.DenseLayer(
            l_hid3, num_units=1,
            nonlinearity=lasagne.nonlinearities.linear)

    return l_out

network, train_loss, val_loss = train_mlp(num_epochs=2500, learning_rate=0.02)
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 2500 took 0.043s
#   training loss:		1.060460
#   validation loss:		1.015413
# Epoch 2 of 2500 took 0.024s
#   training loss:		1.017144
#   validation loss:		1.004697
# Epoch 3 of 2500 took 0.022s
#   training loss:		1.012097
#   validation loss:		1.001655
# Epoch 4 of 2500 took 0.022s
#   training loss:		1.008862
#   validation loss:		1.002062
# Epoch 5 of 2500 took 0.021s
#   training loss:		1.009661
#   validation loss:		1.001516
# Epoch 6 of 2500 took 0.023s
#   training loss:		1.009633
#   validation loss:		1.004418
# Epoch 7 of 2500 took 0.023s
#   training loss:		1.010875
#   validation loss:		1.001545
# Epoch 8 of 2500 took 0.023s
#   training loss:		1.011142
#   validation loss:		1.003121
# Epoch 9 of 2500 took 0.024s
#   training loss:		1.010006
#   validation loss:		1.003561
# Epoch 10 of 2500 took 0.025s
#   training loss:		1.010429
#   validation loss:		1.001524
# Epoch 11 of 2500 took 0.028s
#   training loss:		1.011022
#   validation loss:		1.003399
# Epoch 12 of 2500 took 0.025s
#   training loss:		1.009099
#   validation loss:		1.001993
# Epoch 13 of 2500 took 0.023s
#   training loss:		1.011747
#   validation loss:		1.004191
# Epoch 14 of 2500 took 0.022s
#   training loss:		1.011011
#   validation loss:		1.001959
# Epoch 15 of 2500 took 0.024s
#   training loss:		1.008620
#   validation loss:		1.001217
# Epoch 16 of 2500 took 0.023s
#   training loss:		1.009912
#   validation loss:		1.003290
# Epoch 17 of 2500 took 0.025s
#   training loss:		1.009901
#   validation loss:		1.001162
# Epoch 18 of 2500 took 0.022s
#   training loss:		1.009099
#   validation loss:		1.001854
# Epoch 19 of 2500 took 0.027s
#   training loss:		1.009186
#   validation loss:		1.002821
# Epoch 20 of 2500 took 0.022s
#   training loss:		1.010275
#   validation loss:		1.004238
# Epoch 21 of 2500 took 0.021s
#   training loss:		1.008969
#   validation loss:		1.002704
# Epoch 22 of 2500 took 0.021s
#   training loss:		1.008361
#   validation loss:		1.002599
# Epoch 23 of 2500 took 0.020s
#   training loss:		1.008584
#   validation loss:		1.001410
# Epoch 24 of 2500 took 0.022s
#   training loss:		1.011217
#   validation loss:		1.002427
# Epoch 25 of 2500 took 0.023s
#   training loss:		1.009645
#   validation loss:		1.001650
# Epoch 26 of 2500 took 0.021s
#   training loss:		1.009271
#   validation loss:		1.002359
# Epoch 27 of 2500 took 0.022s
#   training loss:		1.007998
#   validation loss:		1.000969
# Epoch 28 of 2500 took 0.023s
#   training loss:		1.009308
#   validation loss:		1.003886
# Epoch 29 of 2500 took 0.025s
#   training loss:		1.009314
#   validation loss:		1.001200
# Epoch 30 of 2500 took 0.024s
#   training loss:		1.009477
#   validation loss:		1.002232
# Epoch 31 of 2500 took 0.022s
#   training loss:		1.009101
#   validation loss:		1.000850
# Epoch 32 of 2500 took 0.021s
#   training loss:		1.008628
#   validation loss:		1.001513
# Epoch 33 of 2500 took 0.021s
#   training loss:		1.008434
#   validation loss:		1.004310
# Epoch 34 of 2500 took 0.021s
#   training loss:		1.008300
#   validation loss:		1.001017
# Epoch 35 of 2500 took 0.023s
#   training loss:		1.009221
#   validation loss:		1.001919
# Epoch 36 of 2500 took 0.024s
#   training loss:		1.009125
#   validation loss:		1.000952
# Epoch 37 of 2500 took 0.021s
#   training loss:		1.009742
#   validation loss:		1.003918
# Epoch 38 of 2500 took 0.023s
#   training loss:		1.008759
#   validation loss:		1.001221
# Epoch 39 of 2500 took 0.024s
#   training loss:		1.008265
#   validation loss:		1.000771
# Epoch 40 of 2500 took 0.023s
#   training loss:		1.010410
#   validation loss:		1.003284
# Epoch 41 of 2500 took 0.023s
#   training loss:		1.010710
#   validation loss:		1.000502
# Epoch 42 of 2500 took 0.023s
#   training loss:		1.010881
#   validation loss:		1.001071
# Epoch 43 of 2500 took 0.022s
#   training loss:		1.008561
#   validation loss:		1.001592
# Epoch 44 of 2500 took 0.023s
#   training loss:		1.009915
#   validation loss:		1.000394
# Epoch 45 of 2500 took 0.023s
#   training loss:		1.010649
#   validation loss:		1.002907
# Epoch 46 of 2500 took 0.023s
#   training loss:		1.008175
#   validation loss:		1.002303
# Epoch 47 of 2500 took 0.023s
#   training loss:		1.007934
#   validation loss:		1.001815
# Epoch 48 of 2500 took 0.023s
#   training loss:		1.007955
#   validation loss:		1.000754
# Epoch 49 of 2500 took 0.024s
#   training loss:		1.009112
#   validation loss:		1.000234
# Epoch 50 of 2500 took 0.025s
#   training loss:		1.008898
#   validation loss:		1.002699
# Epoch 51 of 2500 took 0.023s
#   training loss:		1.007986
#   validation loss:		1.000381
# Epoch 52 of 2500 took 0.023s
#   training loss:		1.008584
#   validation loss:		1.000836
# Epoch 53 of 2500 took 0.021s
#   training loss:		1.009905
#   validation loss:		1.000236
# Epoch 54 of 2500 took 0.020s
#   training loss:		1.008086
#   validation loss:		1.001871
# Epoch 55 of 2500 took 0.022s
#   training loss:		1.012084
#   validation loss:		1.000040
# Epoch 56 of 2500 took 0.023s
#   training loss:		1.007470
#   validation loss:		1.000480
# Epoch 57 of 2500 took 0.024s
#   training loss:		1.008787
#   validation loss:		1.001642
# Epoch 58 of 2500 took 0.024s
#   training loss:		1.008362
#   validation loss:		1.000165
# Epoch 59 of 2500 took 0.021s
#   training loss:		1.008614
#   validation loss:		1.002219
# Epoch 60 of 2500 took 0.023s
#   training loss:		1.007883
#   validation loss:		1.001589
# Epoch 61 of 2500 took 0.021s
#   training loss:		1.008787
#   validation loss:		1.002777
# Epoch 62 of 2500 took 0.021s
#   training loss:		1.009414
#   validation loss:		1.004993
# Epoch 63 of 2500 took 0.024s
#   training loss:		1.009276
#   validation loss:		1.000719
# Epoch 64 of 2500 took 0.023s
#   training loss:		1.006850
#   validation loss:		0.999730
# Epoch 65 of 2500 took 0.021s
#   training loss:		1.009142
#   validation loss:		0.999675
# Epoch 66 of 2500 took 0.022s
#   training loss:		1.007924
#   validation loss:		0.999697
# Epoch 67 of 2500 took 0.026s
#   training loss:		1.007601
#   validation loss:		1.003522
# Epoch 68 of 2500 took 0.021s
#   training loss:		1.013567
#   validation loss:		0.999740
# Epoch 69 of 2500 took 0.023s
#   training loss:		1.008691
#   validation loss:		0.999482
# Epoch 70 of 2500 took 0.021s
#   training loss:		1.009788
#   validation loss:		1.002217
# Epoch 71 of 2500 took 0.021s
#   training loss:		1.008081
#   validation loss:		0.999739
# Epoch 72 of 2500 took 0.022s
#   training loss:		1.010391
#   validation loss:		1.000300
# Epoch 73 of 2500 took 0.022s
#   training loss:		1.008020
#   validation loss:		0.999493
# Epoch 74 of 2500 took 0.021s
#   training loss:		1.009316
#   validation loss:		0.999258
# Epoch 75 of 2500 took 0.023s
#   training loss:		1.006892
#   validation loss:		0.999871
# Epoch 76 of 2500 took 0.023s
#   training loss:		1.008121
#   validation loss:		0.999555
# Epoch 77 of 2500 took 0.025s
#   training loss:		1.006283
#   validation loss:		1.000445
# Epoch 78 of 2500 took 0.022s
#   training loss:		1.006675
#   validation loss:		0.999439
# Epoch 79 of 2500 took 0.026s
#   training loss:		1.007117
#   validation loss:		0.999867
# Epoch 80 of 2500 took 0.027s
#   training loss:		1.006896
#   validation loss:		0.999232
# Epoch 81 of 2500 took 0.025s
#   training loss:		1.008949
#   validation loss:		0.999494
# Epoch 82 of 2500 took 0.025s
#   training loss:		1.006258
#   validation loss:		0.999459
# Epoch 83 of 2500 took 0.024s
#   training loss:		1.006493
#   validation loss:		0.999513
# Epoch 84 of 2500 took 0.028s
#   training loss:		1.006321
#   validation loss:		0.999294
# Epoch 85 of 2500 took 0.027s
#   training loss:		1.006412
#   validation loss:		1.001031
# Epoch 86 of 2500 took 0.028s
#   training loss:		1.007981
#   validation loss:		0.999076
# Epoch 87 of 2500 took 0.024s
#   training loss:		1.008485
#   validation loss:		1.001027
# Epoch 88 of 2500 took 0.024s
#   training loss:		1.007252
#   validation loss:		0.999885
# Epoch 89 of 2500 took 0.022s
#   training loss:		1.007791
#   validation loss:		1.000203
# Epoch 90 of 2500 took 0.022s
#   training loss:		1.007712
#   validation loss:		0.998384
# Epoch 91 of 2500 took 0.022s
#   training loss:		1.008217
#   validation loss:		1.000217
# Epoch 92 of 2500 took 0.023s
#   training loss:		1.005648
#   validation loss:		0.998860
# Epoch 93 of 2500 took 0.023s
#   training loss:		1.005953
#   validation loss:		0.999538
# Epoch 94 of 2500 took 0.024s
#   training loss:		1.005451
#   validation loss:		0.999473
# Epoch 95 of 2500 took 0.026s
#   training loss:		1.005365
#   validation loss:		0.998452
# Epoch 96 of 2500 took 0.024s
#   training loss:		1.006719
#   validation loss:		1.000557
# Epoch 97 of 2500 took 0.033s
#   training loss:		1.005891
#   validation loss:		0.998205
# Epoch 98 of 2500 took 0.026s
#   training loss:		1.006525
#   validation loss:		0.998237
# Epoch 99 of 2500 took 0.029s
#   training loss:		1.006179
#   validation loss:		0.997775
# Epoch 100 of 2500 took 0.036s
#   training loss:		1.007459
#   validation loss:		0.998471
# Epoch 101 of 2500 took 0.041s
#   training loss:		1.004923
#   validation loss:		0.997757
# Epoch 102 of 2500 took 0.040s
#   training loss:		1.004585
#   validation loss:		0.998750
# Epoch 103 of 2500 took 0.037s
#   training loss:		1.005505
#   validation loss:		0.997441
# Epoch 104 of 2500 took 0.034s
#   training loss:		1.006203
#   validation loss:		0.998253
# Epoch 105 of 2500 took 0.036s
#   training loss:		1.004807
#   validation loss:		1.000671
# Epoch 106 of 2500 took 0.033s
#   training loss:		1.007162
#   validation loss:		0.999283
# Epoch 107 of 2500 took 0.034s
#   training loss:		1.004580
#   validation loss:		0.998378
# Epoch 108 of 2500 took 0.030s
#   training loss:		1.004184
#   validation loss:		0.997736
# Epoch 109 of 2500 took 0.030s
#   training loss:		1.005084
#   validation loss:		0.997680
# Epoch 110 of 2500 took 0.030s
#   training loss:		1.008055
#   validation loss:		0.996842
# Epoch 111 of 2500 took 0.023s
#   training loss:		1.009803
#   validation loss:		1.000056
# Epoch 112 of 2500 took 0.022s
#   training loss:		1.010794
#   validation loss:		0.996601
# Epoch 113 of 2500 took 0.027s
#   training loss:		1.010539
#   validation loss:		0.998176
# Epoch 114 of 2500 took 0.038s
#   training loss:		1.004059
#   validation loss:		0.998922
# Epoch 115 of 2500 took 0.048s
#   training loss:		1.004683
#   validation loss:		0.999158
# Epoch 116 of 2500 took 0.051s
#   training loss:		1.003940
#   validation loss:		0.996388
# Epoch 117 of 2500 took 0.033s
#   training loss:		1.004990
#   validation loss:		0.998389
# Epoch 118 of 2500 took 0.024s
#   training loss:		1.006365
#   validation loss:		0.996146
# Epoch 119 of 2500 took 0.026s
#   training loss:		1.004164
#   validation loss:		0.997114
# Epoch 120 of 2500 took 0.023s
#   training loss:		1.004025
#   validation loss:		1.001313
# Epoch 121 of 2500 took 0.022s
#   training loss:		1.004949
#   validation loss:		0.995697
# Epoch 122 of 2500 took 0.026s
#   training loss:		1.005700
#   validation loss:		0.998231
# Epoch 123 of 2500 took 0.035s
#   training loss:		1.003451
#   validation loss:		0.998821
# Epoch 124 of 2500 took 0.035s
#   training loss:		1.004869
#   validation loss:		0.998710
# Epoch 125 of 2500 took 0.036s
#   training loss:		1.003436
#   validation loss:		0.995255
# Epoch 126 of 2500 took 0.027s
#   training loss:		1.002804
#   validation loss:		0.997694
# Epoch 127 of 2500 took 0.026s
#   training loss:		1.002542
#   validation loss:		0.996402
# Epoch 128 of 2500 took 0.027s
#   training loss:		1.003932
#   validation loss:		0.994963
# Epoch 129 of 2500 took 0.023s
#   training loss:		1.004683
#   validation loss:		0.994419
# Epoch 130 of 2500 took 0.026s
#   training loss:		1.002555
#   validation loss:		0.994282
# Epoch 131 of 2500 took 0.027s
#   training loss:		1.003507
#   validation loss:		1.001246
# Epoch 132 of 2500 took 0.021s
#   training loss:		1.005907
#   validation loss:		0.993847
# Epoch 133 of 2500 took 0.025s
#   training loss:		1.001684
#   validation loss:		0.993890
# Epoch 134 of 2500 took 0.036s
#   training loss:		1.002590
#   validation loss:		0.993571
# Epoch 135 of 2500 took 0.027s
#   training loss:		1.001426
#   validation loss:		0.993695
# Epoch 136 of 2500 took 0.029s
#   training loss:		1.001508
#   validation loss:		0.993191
# Epoch 137 of 2500 took 0.037s
#   training loss:		1.001877
#   validation loss:		0.994824
# Epoch 138 of 2500 took 0.038s
#   training loss:		1.001129
#   validation loss:		0.994648
# Epoch 139 of 2500 took 0.036s
#   training loss:		1.000717
#   validation loss:		0.992438
# Epoch 140 of 2500 took 0.037s
#   training loss:		1.000938
#   validation loss:		0.992231
# Epoch 141 of 2500 took 0.037s
#   training loss:		1.000591
#   validation loss:		0.993219
# Epoch 142 of 2500 took 0.037s
#   training loss:		0.999363
#   validation loss:		0.992300
# Epoch 143 of 2500 took 0.042s
#   training loss:		0.999488
#   validation loss:		0.992137
# Epoch 144 of 2500 took 0.034s
#   training loss:		0.999908
#   validation loss:		0.991627
# Epoch 145 of 2500 took 0.040s
#   training loss:		0.999313
#   validation loss:		0.990943
# Epoch 146 of 2500 took 0.037s
#   training loss:		0.998142
#   validation loss:		0.991363
# Epoch 147 of 2500 took 0.034s
#   training loss:		0.997565
#   validation loss:		0.991897
# Epoch 148 of 2500 took 0.039s
#   training loss:		0.999894
#   validation loss:		0.991809
# Epoch 149 of 2500 took 0.077s
#   training loss:		0.997682
#   validation loss:		0.991123
# Epoch 150 of 2500 took 0.038s
#   training loss:		0.998168
#   validation loss:		0.992020
# Epoch 151 of 2500 took 0.036s
#   training loss:		0.999490
#   validation loss:		0.989491
# Epoch 152 of 2500 took 0.038s
#   training loss:		0.997829
#   validation loss:		0.989561
# Epoch 153 of 2500 took 0.032s
#   training loss:		0.997265
#   validation loss:		0.995149
# Epoch 154 of 2500 took 0.065s
#   training loss:		0.997605
#   validation loss:		0.989989
# Epoch 155 of 2500 took 0.093s
#   training loss:		0.995436
#   validation loss:		0.987628
# Epoch 156 of 2500 took 0.040s
#   training loss:		0.995546
#   validation loss:		0.989012
# Epoch 157 of 2500 took 0.036s
#   training loss:		0.994489
#   validation loss:		0.987563
# Epoch 158 of 2500 took 0.027s
#   training loss:		0.994262
#   validation loss:		0.986862
# Epoch 159 of 2500 took 0.025s
#   training loss:		0.995135
#   validation loss:		0.989368
# Epoch 160 of 2500 took 0.025s
#   training loss:		0.993054
#   validation loss:		0.985516
# Epoch 161 of 2500 took 0.025s
#   training loss:		0.992662
#   validation loss:		0.985014
# Epoch 162 of 2500 took 0.021s
#   training loss:		0.993059
#   validation loss:		0.987709
# Epoch 163 of 2500 took 0.021s
#   training loss:		0.992531
#   validation loss:		0.984063
# Epoch 164 of 2500 took 0.022s
#   training loss:		0.990921
#   validation loss:		0.983481
# Epoch 165 of 2500 took 0.021s
#   training loss:		0.993774
#   validation loss:		0.982730
# Epoch 166 of 2500 took 0.021s
#   training loss:		0.990518
#   validation loss:		0.982976
# Epoch 167 of 2500 took 0.024s
#   training loss:		0.989428
#   validation loss:		0.983546
# Epoch 168 of 2500 took 0.028s
#   training loss:		0.990033
#   validation loss:		0.980835
# Epoch 169 of 2500 took 0.024s
#   training loss:		0.989012
#   validation loss:		0.982108
# Epoch 170 of 2500 took 0.027s
#   training loss:		0.988547
#   validation loss:		0.979842
# Epoch 171 of 2500 took 0.026s
#   training loss:		0.986544
#   validation loss:		0.980652
# Epoch 172 of 2500 took 0.029s
#   training loss:		0.990565
#   validation loss:		0.977831
# Epoch 173 of 2500 took 0.035s
#   training loss:		0.985381
#   validation loss:		0.980420
# Epoch 174 of 2500 took 0.038s
#   training loss:		0.984444
#   validation loss:		0.976345
# Epoch 175 of 2500 took 0.050s
#   training loss:		0.983190
#   validation loss:		0.975730
# Epoch 176 of 2500 took 0.042s
#   training loss:		0.983492
#   validation loss:		0.974903
# Epoch 177 of 2500 took 0.061s
#   training loss:		0.981929
#   validation loss:		0.973180
# Epoch 178 of 2500 took 0.034s
#   training loss:		0.981139
#   validation loss:		0.975148
# Epoch 179 of 2500 took 0.029s
#   training loss:		0.982178
#   validation loss:		0.972545
# Epoch 180 of 2500 took 0.025s
#   training loss:		0.979705
#   validation loss:		0.970614
# Epoch 181 of 2500 took 0.034s
#   training loss:		0.976843
#   validation loss:		0.968785
# Epoch 182 of 2500 took 0.036s
#   training loss:		0.975083
#   validation loss:		0.968224
# Epoch 183 of 2500 took 0.026s
#   training loss:		0.977302
#   validation loss:		0.970101
# Epoch 184 of 2500 took 0.021s
#   training loss:		0.976494
#   validation loss:		0.964481
# Epoch 185 of 2500 took 0.022s
#   training loss:		0.972236
#   validation loss:		0.964571
# Epoch 186 of 2500 took 0.027s
#   training loss:		0.972410
#   validation loss:		0.963263
# Epoch 187 of 2500 took 0.034s
#   training loss:		0.969942
#   validation loss:		0.960252
# Epoch 188 of 2500 took 0.029s
#   training loss:		0.966491
#   validation loss:		0.957965
# Epoch 189 of 2500 took 0.031s
#   training loss:		0.965338
#   validation loss:		0.956015
# Epoch 190 of 2500 took 0.033s
#   training loss:		0.964666
#   validation loss:		0.954589
# Epoch 191 of 2500 took 0.031s
#   training loss:		0.959817
#   validation loss:		0.953689
# Epoch 192 of 2500 took 0.027s
#   training loss:		0.960577
#   validation loss:		0.949951
# Epoch 193 of 2500 took 0.027s
#   training loss:		0.955851
#   validation loss:		0.947819
# Epoch 194 of 2500 took 0.024s
#   training loss:		0.956040
#   validation loss:		0.944756
# Epoch 195 of 2500 took 0.023s
#   training loss:		0.950687
#   validation loss:		0.946348
# Epoch 196 of 2500 took 0.024s
#   training loss:		0.949295
#   validation loss:		0.939402
# Epoch 197 of 2500 took 0.027s
#   training loss:		0.946864
#   validation loss:		0.936990
# Epoch 198 of 2500 took 0.029s
#   training loss:		0.945560
#   validation loss:		0.933553
# Epoch 199 of 2500 took 0.031s
#   training loss:		0.945114
#   validation loss:		0.931016
# Epoch 200 of 2500 took 0.044s
#   training loss:		0.938024
#   validation loss:		0.930920
# Epoch 201 of 2500 took 0.037s
#   training loss:		0.934948
#   validation loss:		0.924035
# Epoch 202 of 2500 took 0.068s
#   training loss:		0.932924
#   validation loss:		0.920194
# Epoch 203 of 2500 took 0.035s
#   training loss:		0.929259
#   validation loss:		0.916922
# Epoch 204 of 2500 took 0.032s
#   training loss:		0.923985
#   validation loss:		0.913803
# Epoch 205 of 2500 took 0.038s
#   training loss:		0.918957
#   validation loss:		0.908857
# Epoch 206 of 2500 took 0.035s
#   training loss:		0.914666
#   validation loss:		0.904105
# Epoch 207 of 2500 took 0.041s
#   training loss:		0.910464
#   validation loss:		0.900203
# Epoch 208 of 2500 took 0.041s
#   training loss:		0.905076
#   validation loss:		0.898677
# Epoch 209 of 2500 took 0.036s
#   training loss:		0.901699
#   validation loss:		0.891181
# Epoch 210 of 2500 took 0.039s
#   training loss:		0.898258
#   validation loss:		0.888579
# Epoch 211 of 2500 took 0.039s
#   training loss:		0.892863
#   validation loss:		0.882862
# Epoch 212 of 2500 took 0.042s
#   training loss:		0.887416
#   validation loss:		0.878107
# Epoch 213 of 2500 took 0.040s
#   training loss:		0.884377
#   validation loss:		0.872561
# Epoch 214 of 2500 took 0.039s
#   training loss:		0.878378
#   validation loss:		0.868829
# Epoch 215 of 2500 took 0.033s
#   training loss:		0.873407
#   validation loss:		0.869401
# Epoch 216 of 2500 took 0.030s
#   training loss:		0.871552
#   validation loss:		0.859170
# Epoch 217 of 2500 took 0.025s
#   training loss:		0.867107
#   validation loss:		0.855046
# Epoch 218 of 2500 took 0.026s
#   training loss:		0.862124
#   validation loss:		0.850386
# Epoch 219 of 2500 took 0.033s
#   training loss:		0.857650
#   validation loss:		0.846219
# Epoch 220 of 2500 took 0.034s
#   training loss:		0.853459
#   validation loss:		0.843705
# Epoch 221 of 2500 took 0.041s
#   training loss:		0.850057
#   validation loss:		0.838195
# Epoch 222 of 2500 took 0.035s
#   training loss:		0.845852
#   validation loss:		0.836889
# Epoch 223 of 2500 took 0.032s
#   training loss:		0.840659
#   validation loss:		0.831155
# Epoch 224 of 2500 took 0.038s
#   training loss:		0.836975
#   validation loss:		0.828224
# Epoch 225 of 2500 took 0.045s
#   training loss:		0.833105
#   validation loss:		0.823700
# Epoch 226 of 2500 took 0.034s
#   training loss:		0.829967
#   validation loss:		0.821195
# Epoch 227 of 2500 took 0.035s
#   training loss:		0.826639
#   validation loss:		0.816323
# Epoch 228 of 2500 took 0.038s
#   training loss:		0.825670
#   validation loss:		0.811934
# Epoch 229 of 2500 took 0.032s
#   training loss:		0.821691
#   validation loss:		0.811083
# Epoch 230 of 2500 took 0.030s
#   training loss:		0.819279
#   validation loss:		0.810815
# Epoch 231 of 2500 took 0.037s
#   training loss:		0.814208
#   validation loss:		0.801877
# Epoch 232 of 2500 took 0.037s
#   training loss:		0.813338
#   validation loss:		0.798443
# Epoch 233 of 2500 took 0.039s
#   training loss:		0.810692
#   validation loss:		0.795478
# Epoch 234 of 2500 took 0.047s
#   training loss:		0.803253
#   validation loss:		0.791766
# Epoch 235 of 2500 took 0.041s
#   training loss:		0.799717
#   validation loss:		0.788978
# Epoch 236 of 2500 took 0.038s
#   training loss:		0.797020
#   validation loss:		0.787926
# Epoch 237 of 2500 took 0.043s
#   training loss:		0.793958
#   validation loss:		0.783070
# Epoch 238 of 2500 took 0.066s
#   training loss:		0.792482
#   validation loss:		0.782570
# Epoch 239 of 2500 took 0.057s
#   training loss:		0.788742
#   validation loss:		0.776682
# Epoch 240 of 2500 took 0.039s
#   training loss:		0.786136
#   validation loss:		0.772259
# Epoch 241 of 2500 took 0.038s
#   training loss:		0.782125
#   validation loss:		0.773051
# Epoch 242 of 2500 took 0.038s
#   training loss:		0.781366
#   validation loss:		0.766060
# Epoch 243 of 2500 took 0.040s
#   training loss:		0.776319
#   validation loss:		0.763202
# Epoch 244 of 2500 took 0.034s
#   training loss:		0.772711
#   validation loss:		0.760550
# Epoch 245 of 2500 took 0.038s
#   training loss:		0.771495
#   validation loss:		0.767563
# Epoch 246 of 2500 took 0.037s
#   training loss:		0.770200
#   validation loss:		0.755729
# Epoch 247 of 2500 took 0.040s
#   training loss:		0.766141
#   validation loss:		0.751416
# Epoch 248 of 2500 took 0.046s
#   training loss:		0.763797
#   validation loss:		0.748948
# Epoch 249 of 2500 took 0.054s
#   training loss:		0.758321
#   validation loss:		0.745846
# Epoch 250 of 2500 took 0.034s
#   training loss:		0.756187
#   validation loss:		0.742774
# Epoch 251 of 2500 took 0.038s
#   training loss:		0.753990
#   validation loss:		0.742052
# Epoch 252 of 2500 took 0.032s
#   training loss:		0.750762
#   validation loss:		0.738346
# Epoch 253 of 2500 took 0.041s
#   training loss:		0.748475
#   validation loss:		0.742370
# Epoch 254 of 2500 took 0.036s
#   training loss:		0.747773
#   validation loss:		0.731901
# Epoch 255 of 2500 took 0.037s
#   training loss:		0.741700
#   validation loss:		0.730703
# Epoch 256 of 2500 took 0.037s
#   training loss:		0.739736
#   validation loss:		0.730117
# Epoch 257 of 2500 took 0.034s
#   training loss:		0.738923
#   validation loss:		0.724326
# Epoch 258 of 2500 took 0.042s
#   training loss:		0.735495
#   validation loss:		0.721415
# Epoch 259 of 2500 took 0.034s
#   training loss:		0.732499
#   validation loss:		0.718975
# Epoch 260 of 2500 took 0.039s
#   training loss:		0.729539
#   validation loss:		0.720495
# Epoch 261 of 2500 took 0.044s
#   training loss:		0.727038
#   validation loss:		0.713710
# Epoch 262 of 2500 took 0.034s
#   training loss:		0.726102
#   validation loss:		0.712003
# Epoch 263 of 2500 took 0.036s
#   training loss:		0.720945
#   validation loss:		0.711501
# Epoch 264 of 2500 took 0.047s
#   training loss:		0.720194
#   validation loss:		0.710918
# Epoch 265 of 2500 took 0.037s
#   training loss:		0.721123
#   validation loss:		0.703906
# Epoch 266 of 2500 took 0.032s
#   training loss:		0.713288
#   validation loss:		0.701360
# Epoch 267 of 2500 took 0.037s
#   training loss:		0.711765
#   validation loss:		0.700409
# Epoch 268 of 2500 took 0.042s
#   training loss:		0.708190
#   validation loss:		0.695625
# Epoch 269 of 2500 took 0.032s
#   training loss:		0.705975
#   validation loss:		0.699634
# Epoch 270 of 2500 took 0.027s
#   training loss:		0.703557
#   validation loss:		0.690275
# Epoch 271 of 2500 took 0.032s
#   training loss:		0.700800
#   validation loss:		0.688948
# Epoch 272 of 2500 took 0.028s
#   training loss:		0.696425
#   validation loss:		0.685669
# Epoch 273 of 2500 took 0.027s
#   training loss:		0.694371
#   validation loss:		0.681796
# Epoch 274 of 2500 took 0.025s
#   training loss:		0.690107
#   validation loss:		0.685056
# Epoch 275 of 2500 took 0.025s
#   training loss:		0.689524
#   validation loss:		0.675883
# Epoch 276 of 2500 took 0.024s
#   training loss:		0.685385
#   validation loss:		0.676039
# Epoch 277 of 2500 took 0.022s
#   training loss:		0.681531
#   validation loss:		0.671161
# Epoch 278 of 2500 took 0.023s
#   training loss:		0.677354
#   validation loss:		0.666522
# Epoch 279 of 2500 took 0.022s
#   training loss:		0.674794
#   validation loss:		0.664695
# Epoch 280 of 2500 took 0.021s
#   training loss:		0.671371
#   validation loss:		0.660056
# Epoch 281 of 2500 took 0.021s
#   training loss:		0.667221
#   validation loss:		0.658014
# Epoch 282 of 2500 took 0.022s
#   training loss:		0.662922
#   validation loss:		0.652130
# Epoch 283 of 2500 took 0.021s
#   training loss:		0.659794
#   validation loss:		0.649667
# Epoch 284 of 2500 took 0.022s
#   training loss:		0.654845
#   validation loss:		0.644296
# Epoch 285 of 2500 took 0.025s
#   training loss:		0.650623
#   validation loss:		0.641103
# Epoch 286 of 2500 took 0.024s
#   training loss:		0.646070
#   validation loss:		0.637745
# Epoch 287 of 2500 took 0.023s
#   training loss:		0.642371
#   validation loss:		0.632022
# Epoch 288 of 2500 took 0.022s
#   training loss:		0.637152
#   validation loss:		0.626995
# Epoch 289 of 2500 took 0.022s
#   training loss:		0.633665
#   validation loss:		0.622758
# Epoch 290 of 2500 took 0.023s
#   training loss:		0.629029
#   validation loss:		0.617750
# Epoch 291 of 2500 took 0.023s
#   training loss:		0.622478
#   validation loss:		0.613093
# Epoch 292 of 2500 took 0.023s
#   training loss:		0.618101
#   validation loss:		0.614696
# Epoch 293 of 2500 took 0.024s
#   training loss:		0.616889
#   validation loss:		0.610101
# Epoch 294 of 2500 took 0.023s
#   training loss:		0.608142
#   validation loss:		0.598687
# Epoch 295 of 2500 took 0.030s
#   training loss:		0.601586
#   validation loss:		0.592225
# Epoch 296 of 2500 took 0.027s
#   training loss:		0.595957
#   validation loss:		0.586809
# Epoch 297 of 2500 took 0.028s
#   training loss:		0.590548
#   validation loss:		0.581432
# Epoch 298 of 2500 took 0.024s
#   training loss:		0.583228
#   validation loss:		0.575732
# Epoch 299 of 2500 took 0.025s
#   training loss:		0.578480
#   validation loss:		0.570803
# Epoch 300 of 2500 took 0.025s
#   training loss:		0.572924
#   validation loss:		0.564716
# Epoch 301 of 2500 took 0.027s
#   training loss:		0.567130
#   validation loss:		0.558516
# Epoch 302 of 2500 took 0.023s
#   training loss:		0.561492
#   validation loss:		0.553129
# Epoch 303 of 2500 took 0.032s
#   training loss:		0.555205
#   validation loss:		0.546858
# Epoch 304 of 2500 took 0.024s
#   training loss:		0.550628
#   validation loss:		0.540936
# Epoch 305 of 2500 took 0.023s
#   training loss:		0.542241
#   validation loss:		0.543697
# Epoch 306 of 2500 took 0.023s
#   training loss:		0.539522
#   validation loss:		0.530682
# Epoch 307 of 2500 took 0.021s
#   training loss:		0.529975
#   validation loss:		0.522821
# Epoch 308 of 2500 took 0.022s
#   training loss:		0.524395
#   validation loss:		0.517099
# Epoch 309 of 2500 took 0.022s
#   training loss:		0.517769
#   validation loss:		0.511763
# Epoch 310 of 2500 took 0.023s
#   training loss:		0.510659
#   validation loss:		0.506513
# Epoch 311 of 2500 took 0.022s
#   training loss:		0.504976
#   validation loss:		0.499348
# Epoch 312 of 2500 took 0.024s
#   training loss:		0.500342
#   validation loss:		0.496178
# Epoch 313 of 2500 took 0.026s
#   training loss:		0.494812
#   validation loss:		0.494379
# Epoch 314 of 2500 took 0.021s
#   training loss:		0.499404
#   validation loss:		0.483896
# Epoch 315 of 2500 took 0.022s
#   training loss:		0.484978
#   validation loss:		0.479288
# Epoch 316 of 2500 took 0.022s
#   training loss:		0.480194
#   validation loss:		0.473982
# Epoch 317 of 2500 took 0.024s
#   training loss:		0.473123
#   validation loss:		0.469874
# Epoch 318 of 2500 took 0.022s
#   training loss:		0.469481
#   validation loss:		0.469060
# Epoch 319 of 2500 took 0.023s
#   training loss:		0.467017
#   validation loss:		0.462608
# Epoch 320 of 2500 took 0.022s
#   training loss:		0.462108
#   validation loss:		0.459804
# Epoch 321 of 2500 took 0.028s
#   training loss:		0.461843
#   validation loss:		0.457506
# Epoch 322 of 2500 took 0.022s
#   training loss:		0.458472
#   validation loss:		0.459779
# Epoch 323 of 2500 took 0.022s
#   training loss:		0.455974
#   validation loss:		0.455936
# Epoch 324 of 2500 took 0.022s
#   training loss:		0.453103
#   validation loss:		0.451966
# Epoch 325 of 2500 took 0.021s
#   training loss:		0.454754
#   validation loss:		0.451303
# Epoch 326 of 2500 took 0.021s
#   training loss:		0.452125
#   validation loss:		0.450509
# Epoch 327 of 2500 took 0.022s
#   training loss:		0.450665
#   validation loss:		0.451961
# Epoch 328 of 2500 took 0.023s
#   training loss:		0.454468
#   validation loss:		0.449548
# Epoch 329 of 2500 took 0.021s
#   training loss:		0.448268
#   validation loss:		0.448483
# Epoch 330 of 2500 took 0.025s
#   training loss:		0.447787
#   validation loss:		0.447529
# Epoch 331 of 2500 took 0.026s
#   training loss:		0.449958
#   validation loss:		0.451660
# Epoch 332 of 2500 took 0.025s
#   training loss:		0.447152
#   validation loss:		0.448378
# Epoch 333 of 2500 took 0.023s
#   training loss:		0.445973
#   validation loss:		0.446630
# Epoch 334 of 2500 took 0.021s
#   training loss:		0.445906
#   validation loss:		0.456132
# Epoch 335 of 2500 took 0.023s
#   training loss:		0.446587
#   validation loss:		0.445937
# Epoch 336 of 2500 took 0.021s
#   training loss:		0.444875
#   validation loss:		0.444977
# Epoch 337 of 2500 took 0.024s
#   training loss:		0.445231
#   validation loss:		0.444514
# Epoch 338 of 2500 took 0.022s
#   training loss:		0.446455
#   validation loss:		0.445671
# Epoch 339 of 2500 took 0.024s
#   training loss:		0.443610
#   validation loss:		0.448684
# Epoch 340 of 2500 took 0.029s
#   training loss:		0.449560
#   validation loss:		0.443605
# Epoch 341 of 2500 took 0.021s
#   training loss:		0.441698
#   validation loss:		0.450557
# Epoch 342 of 2500 took 0.021s
#   training loss:		0.442482
#   validation loss:		0.445566
# Epoch 343 of 2500 took 0.024s
#   training loss:		0.444543
#   validation loss:		0.442389
# Epoch 344 of 2500 took 0.021s
#   training loss:		0.443876
#   validation loss:		0.449988
# Epoch 345 of 2500 took 0.023s
#   training loss:		0.442799
#   validation loss:		0.445765
# Epoch 346 of 2500 took 0.022s
#   training loss:		0.442652
#   validation loss:		0.443420
# Epoch 347 of 2500 took 0.022s
#   training loss:		0.440598
#   validation loss:		0.441082
# Epoch 348 of 2500 took 0.022s
#   training loss:		0.441499
#   validation loss:		0.440663
# Epoch 349 of 2500 took 0.027s
#   training loss:		0.442187
#   validation loss:		0.441988
# Epoch 350 of 2500 took 0.022s
#   training loss:		0.441279
#   validation loss:		0.444991
# Epoch 351 of 2500 took 0.021s
#   training loss:		0.439694
#   validation loss:		0.441674
# Epoch 352 of 2500 took 0.021s
#   training loss:		0.442249
#   validation loss:		0.440054
# Epoch 353 of 2500 took 0.023s
#   training loss:		0.438499
#   validation loss:		0.439911
# Epoch 354 of 2500 took 0.022s
#   training loss:		0.438661
#   validation loss:		0.442016
# Epoch 355 of 2500 took 0.023s
#   training loss:		0.438783
#   validation loss:		0.438412
# Epoch 356 of 2500 took 0.022s
#   training loss:		0.441277
#   validation loss:		0.439350
# Epoch 357 of 2500 took 0.022s
#   training loss:		0.438281
#   validation loss:		0.439573
# Epoch 358 of 2500 took 0.021s
#   training loss:		0.438427
#   validation loss:		0.438195
# Epoch 359 of 2500 took 0.025s
#   training loss:		0.437023
#   validation loss:		0.442378
# Epoch 360 of 2500 took 0.026s
#   training loss:		0.439698
#   validation loss:		0.437236
# Epoch 361 of 2500 took 0.021s
#   training loss:		0.437222
#   validation loss:		0.438162
# Epoch 362 of 2500 took 0.021s
#   training loss:		0.435504
#   validation loss:		0.438758
# Epoch 363 of 2500 took 0.022s
#   training loss:		0.434952
#   validation loss:		0.436398
# Epoch 364 of 2500 took 0.023s
#   training loss:		0.439219
#   validation loss:		0.438326
# Epoch 365 of 2500 took 0.023s
#   training loss:		0.435748
#   validation loss:		0.437308
# Epoch 366 of 2500 took 0.022s
#   training loss:		0.435098
#   validation loss:		0.436591
# Epoch 367 of 2500 took 0.022s
#   training loss:		0.434367
#   validation loss:		0.436024
# Epoch 368 of 2500 took 0.022s
#   training loss:		0.434096
#   validation loss:		0.439267
# Epoch 369 of 2500 took 0.029s
#   training loss:		0.434130
#   validation loss:		0.437527
# Epoch 370 of 2500 took 0.023s
#   training loss:		0.436630
#   validation loss:		0.436230
# Epoch 371 of 2500 took 0.022s
#   training loss:		0.432512
#   validation loss:		0.438234
# Epoch 372 of 2500 took 0.023s
#   training loss:		0.435245
#   validation loss:		0.437241
# Epoch 373 of 2500 took 0.022s
#   training loss:		0.432566
#   validation loss:		0.434908
# Epoch 374 of 2500 took 0.021s
#   training loss:		0.433377
#   validation loss:		0.436982
# Epoch 375 of 2500 took 0.023s
#   training loss:		0.435148
#   validation loss:		0.433671
# Epoch 376 of 2500 took 0.023s
#   training loss:		0.431005
#   validation loss:		0.434932
# Epoch 377 of 2500 took 0.021s
#   training loss:		0.433140
#   validation loss:		0.434255
# Epoch 378 of 2500 took 0.023s
#   training loss:		0.431691
#   validation loss:		0.436783
# Epoch 379 of 2500 took 0.025s
#   training loss:		0.431601
#   validation loss:		0.433276
# Epoch 380 of 2500 took 0.022s
#   training loss:		0.431722
#   validation loss:		0.432786
# Epoch 381 of 2500 took 0.022s
#   training loss:		0.431566
#   validation loss:		0.436404
# Epoch 382 of 2500 took 0.027s
#   training loss:		0.430260
#   validation loss:		0.432574
# Epoch 383 of 2500 took 0.022s
#   training loss:		0.434439
#   validation loss:		0.431833
# Epoch 384 of 2500 took 0.021s
#   training loss:		0.429766
#   validation loss:		0.432975
# Epoch 385 of 2500 took 0.021s
#   training loss:		0.429690
#   validation loss:		0.437912
# Epoch 386 of 2500 took 0.022s
#   training loss:		0.429292
#   validation loss:		0.431130
# Epoch 387 of 2500 took 0.025s
#   training loss:		0.430820
#   validation loss:		0.436570
# Epoch 388 of 2500 took 0.024s
#   training loss:		0.429809
#   validation loss:		0.429941
# Epoch 389 of 2500 took 0.021s
#   training loss:		0.428737
#   validation loss:		0.429798
# Epoch 390 of 2500 took 0.024s
#   training loss:		0.429784
#   validation loss:		0.432642
# Epoch 391 of 2500 took 0.022s
#   training loss:		0.427979
#   validation loss:		0.429987
# Epoch 392 of 2500 took 0.023s
#   training loss:		0.428837
#   validation loss:		0.439048
# Epoch 393 of 2500 took 0.023s
#   training loss:		0.427551
#   validation loss:		0.431464
# Epoch 394 of 2500 took 0.021s
#   training loss:		0.428906
#   validation loss:		0.429248
# Epoch 395 of 2500 took 0.024s
#   training loss:		0.426379
#   validation loss:		0.428136
# Epoch 396 of 2500 took 0.026s
#   training loss:		0.429348
#   validation loss:		0.428053
# Epoch 397 of 2500 took 0.024s
#   training loss:		0.426589
#   validation loss:		0.433698
# Epoch 398 of 2500 took 0.025s
#   training loss:		0.430312
#   validation loss:		0.428773
# Epoch 399 of 2500 took 0.023s
#   training loss:		0.426535
#   validation loss:		0.433642
# Epoch 400 of 2500 took 0.023s
#   training loss:		0.425746
#   validation loss:		0.427831
# Epoch 401 of 2500 took 0.022s
#   training loss:		0.426311
#   validation loss:		0.426651
# Epoch 402 of 2500 took 0.023s
#   training loss:		0.427225
#   validation loss:		0.426849
# Epoch 403 of 2500 took 0.023s
#   training loss:		0.426400
#   validation loss:		0.426111
# Epoch 404 of 2500 took 0.024s
#   training loss:		0.427647
#   validation loss:		0.439203
# Epoch 405 of 2500 took 0.022s
#   training loss:		0.428936
#   validation loss:		0.426921
# Epoch 406 of 2500 took 0.022s
#   training loss:		0.425082
#   validation loss:		0.425989
# Epoch 407 of 2500 took 0.023s
#   training loss:		0.425223
#   validation loss:		0.425548
# Epoch 408 of 2500 took 0.027s
#   training loss:		0.423946
#   validation loss:		0.424862
# Epoch 409 of 2500 took 0.021s
#   training loss:		0.424487
#   validation loss:		0.424743
# Epoch 410 of 2500 took 0.020s
#   training loss:		0.423391
#   validation loss:		0.424553
# Epoch 411 of 2500 took 0.021s
#   training loss:		0.423295
#   validation loss:		0.425646
# Epoch 412 of 2500 took 0.023s
#   training loss:		0.424377
#   validation loss:		0.423853
# Epoch 413 of 2500 took 0.022s
#   training loss:		0.423103
#   validation loss:		0.423687
# Epoch 414 of 2500 took 0.023s
#   training loss:		0.424122
#   validation loss:		0.424008
# Epoch 415 of 2500 took 0.020s
#   training loss:		0.425643
#   validation loss:		0.423501
# Epoch 416 of 2500 took 0.026s
#   training loss:		0.424054
#   validation loss:		0.428586
# Epoch 417 of 2500 took 0.025s
#   training loss:		0.425439
#   validation loss:		0.423508
# Epoch 418 of 2500 took 0.026s
#   training loss:		0.422155
#   validation loss:		0.424587
# Epoch 419 of 2500 took 0.024s
#   training loss:		0.423381
#   validation loss:		0.427123
# Epoch 420 of 2500 took 0.023s
#   training loss:		0.423302
#   validation loss:		0.423398
# Epoch 421 of 2500 took 0.023s
#   training loss:		0.421280
#   validation loss:		0.423532
# Epoch 422 of 2500 took 0.024s
#   training loss:		0.422602
#   validation loss:		0.424090
# Epoch 423 of 2500 took 0.022s
#   training loss:		0.421977
#   validation loss:		0.422222
# Epoch 424 of 2500 took 0.023s
#   training loss:		0.420307
#   validation loss:		0.421756
# Epoch 425 of 2500 took 0.026s
#   training loss:		0.420714
#   validation loss:		0.421531
# Epoch 426 of 2500 took 0.026s
#   training loss:		0.420881
#   validation loss:		0.421053
# Epoch 427 of 2500 took 0.022s
#   training loss:		0.424425
#   validation loss:		0.422447
# Epoch 428 of 2500 took 0.023s
#   training loss:		0.421992
#   validation loss:		0.425133
# Epoch 429 of 2500 took 0.021s
#   training loss:		0.421592
#   validation loss:		0.420319
# Epoch 430 of 2500 took 0.023s
#   training loss:		0.419652
#   validation loss:		0.426384
# Epoch 431 of 2500 took 0.023s
#   training loss:		0.419957
#   validation loss:		0.422418
# Epoch 432 of 2500 took 0.025s
#   training loss:		0.420080
#   validation loss:		0.428161
# Epoch 433 of 2500 took 0.021s
#   training loss:		0.419702
#   validation loss:		0.419519
# Epoch 434 of 2500 took 0.028s
#   training loss:		0.419352
#   validation loss:		0.419499
# Epoch 435 of 2500 took 0.023s
#   training loss:		0.420597
#   validation loss:		0.419228
# Epoch 436 of 2500 took 0.021s
#   training loss:		0.420326
#   validation loss:		0.420027
# Epoch 437 of 2500 took 0.022s
#   training loss:		0.419457
#   validation loss:		0.419096
# Epoch 438 of 2500 took 0.022s
#   training loss:		0.418550
#   validation loss:		0.425203
# Epoch 439 of 2500 took 0.023s
#   training loss:		0.420782
#   validation loss:		0.429515
# Epoch 440 of 2500 took 0.024s
#   training loss:		0.420351
#   validation loss:		0.418512
# Epoch 441 of 2500 took 0.024s
#   training loss:		0.418316
#   validation loss:		0.418693
# Epoch 442 of 2500 took 0.023s
#   training loss:		0.419005
#   validation loss:		0.418090
# Epoch 443 of 2500 took 0.037s
#   training loss:		0.417846
#   validation loss:		0.417663
# Epoch 444 of 2500 took 0.030s
#   training loss:		0.418530
#   validation loss:		0.420744
# Epoch 445 of 2500 took 0.040s
#   training loss:		0.416822
#   validation loss:		0.418899
# Epoch 446 of 2500 took 0.058s
#   training loss:		0.418662
#   validation loss:		0.421782
# Epoch 447 of 2500 took 0.072s
#   training loss:		0.419735
#   validation loss:		0.416640
# Epoch 448 of 2500 took 0.029s
#   training loss:		0.416895
#   validation loss:		0.420693
# Epoch 449 of 2500 took 0.031s
#   training loss:		0.416860
#   validation loss:		0.416790
# Epoch 450 of 2500 took 0.039s
#   training loss:		0.418599
#   validation loss:		0.416727
# Epoch 451 of 2500 took 0.037s
#   training loss:		0.415754
#   validation loss:		0.416548
# Epoch 452 of 2500 took 0.040s
#   training loss:		0.416271
#   validation loss:		0.416628
# Epoch 453 of 2500 took 0.029s
#   training loss:		0.416022
#   validation loss:		0.415849
# Epoch 454 of 2500 took 0.032s
#   training loss:		0.416101
#   validation loss:		0.419177
# Epoch 455 of 2500 took 0.027s
#   training loss:		0.416064
#   validation loss:		0.415304
# Epoch 456 of 2500 took 0.029s
#   training loss:		0.416527
#   validation loss:		0.416725
# Epoch 457 of 2500 took 0.030s
#   training loss:		0.416961
#   validation loss:		0.416199
# Epoch 458 of 2500 took 0.039s
#   training loss:		0.415607
#   validation loss:		0.417522
# Epoch 459 of 2500 took 0.039s
#   training loss:		0.415610
#   validation loss:		0.414855
# Epoch 460 of 2500 took 0.033s
#   training loss:		0.415359
#   validation loss:		0.417268
# Epoch 461 of 2500 took 0.032s
#   training loss:		0.414861
#   validation loss:		0.415347
# Epoch 462 of 2500 took 0.062s
#   training loss:		0.419229
#   validation loss:		0.414138
# Epoch 463 of 2500 took 0.040s
#   training loss:		0.415793
#   validation loss:		0.414400
# Epoch 464 of 2500 took 0.031s
#   training loss:		0.415236
#   validation loss:		0.415461
# Epoch 465 of 2500 took 0.032s
#   training loss:		0.414505
#   validation loss:		0.418021
# Epoch 466 of 2500 took 0.033s
#   training loss:		0.414689
#   validation loss:		0.414209
# Epoch 467 of 2500 took 0.035s
#   training loss:		0.417337
#   validation loss:		0.415281
# Epoch 468 of 2500 took 0.033s
#   training loss:		0.413443
#   validation loss:		0.413797
# Epoch 469 of 2500 took 0.029s
#   training loss:		0.414546
#   validation loss:		0.413266
# Epoch 470 of 2500 took 0.033s
#   training loss:		0.414348
#   validation loss:		0.412759
# Epoch 471 of 2500 took 0.033s
#   training loss:		0.413384
#   validation loss:		0.414766
# Epoch 472 of 2500 took 0.031s
#   training loss:		0.413216
#   validation loss:		0.412716
# Epoch 473 of 2500 took 0.029s
#   training loss:		0.414966
#   validation loss:		0.412795
# Epoch 474 of 2500 took 0.032s
#   training loss:		0.413825
#   validation loss:		0.417576
# Epoch 475 of 2500 took 0.030s
#   training loss:		0.414987
#   validation loss:		0.416394
# Epoch 476 of 2500 took 0.031s
#   training loss:		0.416103
#   validation loss:		0.413943
# Epoch 477 of 2500 took 0.067s
#   training loss:		0.413321
#   validation loss:		0.412105
# Epoch 478 of 2500 took 0.022s
#   training loss:		0.413784
#   validation loss:		0.411474
# Epoch 479 of 2500 took 0.020s
#   training loss:		0.413632
#   validation loss:		0.413053
# Epoch 480 of 2500 took 0.020s
#   training loss:		0.412385
#   validation loss:		0.416672
# Epoch 481 of 2500 took 0.020s
#   training loss:		0.412637
#   validation loss:		0.411671
# Epoch 482 of 2500 took 0.020s
#   training loss:		0.412535
#   validation loss:		0.411348
# Epoch 483 of 2500 took 0.024s
#   training loss:		0.412998
#   validation loss:		0.412104
# Epoch 484 of 2500 took 0.023s
#   training loss:		0.413549
#   validation loss:		0.412309
# Epoch 485 of 2500 took 0.024s
#   training loss:		0.412973
#   validation loss:		0.415652
# Epoch 486 of 2500 took 0.032s
#   training loss:		0.414442
#   validation loss:		0.410619
# Epoch 487 of 2500 took 0.033s
#   training loss:		0.413030
#   validation loss:		0.411016
# Epoch 488 of 2500 took 0.038s
#   training loss:		0.412188
#   validation loss:		0.411079
# Epoch 489 of 2500 took 0.048s
#   training loss:		0.412259
#   validation loss:		0.411964
# Epoch 490 of 2500 took 0.031s
#   training loss:		0.413815
#   validation loss:		0.418327
# Epoch 491 of 2500 took 0.035s
#   training loss:		0.414836
#   validation loss:		0.417944
# Epoch 492 of 2500 took 0.024s
#   training loss:		0.413764
#   validation loss:		0.411620
# Epoch 493 of 2500 took 0.032s
#   training loss:		0.411563
#   validation loss:		0.409463
# Epoch 494 of 2500 took 0.038s
#   training loss:		0.411795
#   validation loss:		0.410441
# Epoch 495 of 2500 took 0.044s
#   training loss:		0.411979
#   validation loss:		0.409873
# Epoch 496 of 2500 took 0.084s
#   training loss:		0.410782
#   validation loss:		0.412537
# Epoch 497 of 2500 took 0.026s
#   training loss:		0.411234
#   validation loss:		0.409880
# Epoch 498 of 2500 took 0.024s
#   training loss:		0.411340
#   validation loss:		0.413413
# Epoch 499 of 2500 took 0.029s
#   training loss:		0.412426
#   validation loss:		0.409391
# Epoch 500 of 2500 took 0.023s
#   training loss:		0.409944
#   validation loss:		0.412629
# Epoch 501 of 2500 took 0.024s
#   training loss:		0.410939
#   validation loss:		0.408767
# Epoch 502 of 2500 took 0.021s
#   training loss:		0.410658
#   validation loss:		0.412959
# Epoch 503 of 2500 took 0.021s
#   training loss:		0.410650
#   validation loss:		0.409447
# Epoch 504 of 2500 took 0.022s
#   training loss:		0.409893
#   validation loss:		0.408439
# Epoch 505 of 2500 took 0.024s
#   training loss:		0.410046
#   validation loss:		0.410160
# Epoch 506 of 2500 took 0.023s
#   training loss:		0.410045
#   validation loss:		0.408677
# Epoch 507 of 2500 took 0.024s
#   training loss:		0.409460
#   validation loss:		0.408361
# Epoch 508 of 2500 took 0.026s
#   training loss:		0.410482
#   validation loss:		0.408152
# Epoch 509 of 2500 took 0.027s
#   training loss:		0.410811
#   validation loss:		0.409110
# Epoch 510 of 2500 took 0.028s
#   training loss:		0.411590
#   validation loss:		0.407722
# Epoch 511 of 2500 took 0.028s
#   training loss:		0.409674
#   validation loss:		0.407881
# Epoch 512 of 2500 took 0.025s
#   training loss:		0.410280
#   validation loss:		0.408577
# Epoch 513 of 2500 took 0.026s
#   training loss:		0.408802
#   validation loss:		0.415809
# Epoch 514 of 2500 took 0.026s
#   training loss:		0.410149
#   validation loss:		0.407383
# Epoch 515 of 2500 took 0.027s
#   training loss:		0.413425
#   validation loss:		0.408325
# Epoch 516 of 2500 took 0.031s
#   training loss:		0.411532
#   validation loss:		0.409431
# Epoch 517 of 2500 took 0.027s
#   training loss:		0.409402
#   validation loss:		0.409254
# Epoch 518 of 2500 took 0.026s
#   training loss:		0.410261
#   validation loss:		0.409725
# Epoch 519 of 2500 took 0.027s
#   training loss:		0.410873
#   validation loss:		0.407135
# Epoch 520 of 2500 took 0.024s
#   training loss:		0.408860
#   validation loss:		0.407164
# Epoch 521 of 2500 took 0.023s
#   training loss:		0.408970
#   validation loss:		0.409778
# Epoch 522 of 2500 took 0.023s
#   training loss:		0.408762
#   validation loss:		0.409553
# Epoch 523 of 2500 took 0.029s
#   training loss:		0.408956
#   validation loss:		0.406925
# Epoch 524 of 2500 took 0.035s
#   training loss:		0.411348
#   validation loss:		0.406985
# Epoch 525 of 2500 took 0.027s
#   training loss:		0.409749
#   validation loss:		0.406716
# Epoch 526 of 2500 took 0.024s
#   training loss:		0.408165
#   validation loss:		0.409123
# Epoch 527 of 2500 took 0.025s
#   training loss:		0.408160
#   validation loss:		0.408189
# Epoch 528 of 2500 took 0.028s
#   training loss:		0.408831
#   validation loss:		0.409848
# Epoch 529 of 2500 took 0.032s
#   training loss:		0.409149
#   validation loss:		0.408655
# Epoch 530 of 2500 took 0.031s
#   training loss:		0.411477
#   validation loss:		0.406206
# Epoch 531 of 2500 took 0.033s
#   training loss:		0.410055
#   validation loss:		0.406190
# Epoch 532 of 2500 took 0.024s
#   training loss:		0.409751
#   validation loss:		0.406262
# Epoch 533 of 2500 took 0.029s
#   training loss:		0.407210
#   validation loss:		0.405402
# Epoch 534 of 2500 took 0.033s
#   training loss:		0.408225
#   validation loss:		0.410464
# Epoch 535 of 2500 took 0.031s
#   training loss:		0.408648
#   validation loss:		0.405758
# Epoch 536 of 2500 took 0.033s
#   training loss:		0.408022
#   validation loss:		0.413520
# Epoch 537 of 2500 took 0.041s
#   training loss:		0.409369
#   validation loss:		0.405118
# Epoch 538 of 2500 took 0.035s
#   training loss:		0.407027
#   validation loss:		0.405391
# Epoch 539 of 2500 took 0.026s
#   training loss:		0.407359
#   validation loss:		0.406997
# Epoch 540 of 2500 took 0.026s
#   training loss:		0.407463
#   validation loss:		0.404770
# Epoch 541 of 2500 took 0.023s
#   training loss:		0.407784
#   validation loss:		0.406275
# Epoch 542 of 2500 took 0.024s
#   training loss:		0.407688
#   validation loss:		0.405820
# Epoch 543 of 2500 took 0.025s
#   training loss:		0.407954
#   validation loss:		0.405473
# Epoch 544 of 2500 took 0.030s
#   training loss:		0.406766
#   validation loss:		0.407372
# Epoch 545 of 2500 took 0.033s
#   training loss:		0.408410
#   validation loss:		0.407158
# Epoch 546 of 2500 took 0.038s
#   training loss:		0.408732
#   validation loss:		0.409587
# Epoch 547 of 2500 took 0.043s
#   training loss:		0.407412
#   validation loss:		0.404489
# Epoch 548 of 2500 took 0.044s
#   training loss:		0.407907
#   validation loss:		0.405516
# Epoch 549 of 2500 took 0.035s
#   training loss:		0.407936
#   validation loss:		0.406540
# Epoch 550 of 2500 took 0.040s
#   training loss:		0.406054
#   validation loss:		0.404420
# Epoch 551 of 2500 took 0.031s
#   training loss:		0.406693
#   validation loss:		0.405117
# Epoch 552 of 2500 took 0.034s
#   training loss:		0.406693
#   validation loss:		0.404563
# Epoch 553 of 2500 took 0.033s
#   training loss:		0.405911
#   validation loss:		0.410558
# Epoch 554 of 2500 took 0.040s
#   training loss:		0.406918
#   validation loss:		0.404610
# Epoch 555 of 2500 took 0.038s
#   training loss:		0.407241
#   validation loss:		0.403740
# Epoch 556 of 2500 took 0.035s
#   training loss:		0.407379
#   validation loss:		0.404487
# Epoch 557 of 2500 took 0.030s
#   training loss:		0.406452
#   validation loss:		0.410003
# Epoch 558 of 2500 took 0.026s
#   training loss:		0.407363
#   validation loss:		0.403334
# Epoch 559 of 2500 took 0.032s
# ...
#   validation loss:		0.148784
# Epoch 2318 of 2500 took 0.022s
#   training loss:		0.154253
#   validation loss:		0.147528
# Epoch 2319 of 2500 took 0.022s
#   training loss:		0.154966
#   validation loss:		0.147846
# Epoch 2320 of 2500 took 0.021s
#   training loss:		0.154990
#   validation loss:		0.148155
# Epoch 2321 of 2500 took 0.021s
#   training loss:		0.154212
#   validation loss:		0.148982
# Epoch 2322 of 2500 took 0.024s
#   training loss:		0.154954
#   validation loss:		0.146265
# Epoch 2323 of 2500 took 0.027s
#   training loss:		0.154406
#   validation loss:		0.150298
# Epoch 2324 of 2500 took 0.022s
#   training loss:		0.155083
#   validation loss:		0.147471
# Epoch 2325 of 2500 took 0.022s
#   training loss:		0.155063
#   validation loss:		0.148898
# Epoch 2326 of 2500 took 0.022s
#   training loss:		0.153942
#   validation loss:		0.147164
# Epoch 2327 of 2500 took 0.020s
#   training loss:		0.154779
#   validation loss:		0.148234
# Epoch 2328 of 2500 took 0.020s
#   training loss:		0.154169
#   validation loss:		0.146878
# Epoch 2329 of 2500 took 0.021s
#   training loss:		0.154421
#   validation loss:		0.147572
# Epoch 2330 of 2500 took 0.021s
#   training loss:		0.154079
#   validation loss:		0.147644
# Epoch 2331 of 2500 took 0.023s
#   training loss:		0.153785
#   validation loss:		0.147247
# Epoch 2332 of 2500 took 0.024s
#   training loss:		0.154649
#   validation loss:		0.146909
# Epoch 2333 of 2500 took 0.025s
#   training loss:		0.153656
#   validation loss:		0.147386
# Epoch 2334 of 2500 took 0.024s
#   training loss:		0.153410
#   validation loss:		0.149109
# Epoch 2335 of 2500 took 0.023s
#   training loss:		0.154354
#   validation loss:		0.147031
# Epoch 2336 of 2500 took 0.021s
#   training loss:		0.153721
#   validation loss:		0.147572
# Epoch 2337 of 2500 took 0.020s
#   training loss:		0.153654
#   validation loss:		0.148013
# Epoch 2338 of 2500 took 0.021s
#   training loss:		0.154037
#   validation loss:		0.146413
# Epoch 2339 of 2500 took 0.020s
#   training loss:		0.153476
#   validation loss:		0.147840
# Epoch 2340 of 2500 took 0.022s
#   training loss:		0.154838
#   validation loss:		0.146885
# Epoch 2341 of 2500 took 0.025s
#   training loss:		0.154141
#   validation loss:		0.146665
# Epoch 2342 of 2500 took 0.023s
#   training loss:		0.153950
#   validation loss:		0.147316
# Epoch 2343 of 2500 took 0.021s
#   training loss:		0.153555
#   validation loss:		0.147095
# Epoch 2344 of 2500 took 0.022s
#   training loss:		0.154371
#   validation loss:		0.147450
# Epoch 2345 of 2500 took 0.023s
#   training loss:		0.155599
#   validation loss:		0.147483
# Epoch 2346 of 2500 took 0.020s
#   training loss:		0.154055
#   validation loss:		0.149983
# Epoch 2347 of 2500 took 0.021s
#   training loss:		0.153964
#   validation loss:		0.145653
# Epoch 2348 of 2500 took 0.020s
#   training loss:		0.154032
#   validation loss:		0.146510
# Epoch 2349 of 2500 took 0.021s
#   training loss:		0.153424
#   validation loss:		0.148163
# Epoch 2350 of 2500 took 0.022s
#   training loss:		0.153011
#   validation loss:		0.146738
# Epoch 2351 of 2500 took 0.026s
#   training loss:		0.154525
#   validation loss:		0.146937
# Epoch 2352 of 2500 took 0.022s
#   training loss:		0.153682
#   validation loss:		0.148592
# Epoch 2353 of 2500 took 0.021s
#   training loss:		0.154307
#   validation loss:		0.147083
# Epoch 2354 of 2500 took 0.025s
#   training loss:		0.153604
#   validation loss:		0.146388
# Epoch 2355 of 2500 took 0.024s
#   training loss:		0.154406
#   validation loss:		0.148631
# Epoch 2356 of 2500 took 0.025s
#   training loss:		0.153574
#   validation loss:		0.146860
# Epoch 2357 of 2500 took 0.029s
#   training loss:		0.153392
#   validation loss:		0.147244
# Epoch 2358 of 2500 took 0.023s
#   training loss:		0.153849
#   validation loss:		0.146588
# Epoch 2359 of 2500 took 0.022s
#   training loss:		0.153712
#   validation loss:		0.147592
# Epoch 2360 of 2500 took 0.021s
#   training loss:		0.153307
#   validation loss:		0.148048
# Epoch 2361 of 2500 took 0.025s
#   training loss:		0.154532
#   validation loss:		0.147027
# Epoch 2362 of 2500 took 0.025s
#   training loss:		0.153485
#   validation loss:		0.147599
# Epoch 2363 of 2500 took 0.023s
#   training loss:		0.153800
#   validation loss:		0.147704
# Epoch 2364 of 2500 took 0.024s
#   training loss:		0.153466
#   validation loss:		0.146800
# Epoch 2365 of 2500 took 0.021s
#   training loss:		0.153531
#   validation loss:		0.147125
# Epoch 2366 of 2500 took 0.020s
#   training loss:		0.154021
#   validation loss:		0.146465
# Epoch 2367 of 2500 took 0.021s
#   training loss:		0.153775
#   validation loss:		0.146140
# Epoch 2368 of 2500 took 0.021s
#   training loss:		0.152871
#   validation loss:		0.146301
# Epoch 2369 of 2500 took 0.023s
#   training loss:		0.152926
#   validation loss:		0.146827
# Epoch 2370 of 2500 took 0.027s
#   training loss:		0.153458
#   validation loss:		0.147843
# Epoch 2371 of 2500 took 0.025s
#   training loss:		0.153214
#   validation loss:		0.147603
# Epoch 2372 of 2500 took 0.031s
#   training loss:		0.153555
#   validation loss:		0.147326
# Epoch 2373 of 2500 took 0.034s
#   training loss:		0.154055
#   validation loss:		0.147550
# Epoch 2374 of 2500 took 0.032s
#   training loss:		0.153349
#   validation loss:		0.146523
# Epoch 2375 of 2500 took 0.024s
#   training loss:		0.153000
#   validation loss:		0.147584
# Epoch 2376 of 2500 took 0.022s
#   training loss:		0.153257
#   validation loss:		0.147226
# Epoch 2377 of 2500 took 0.024s
#   training loss:		0.153414
#   validation loss:		0.147244
# Epoch 2378 of 2500 took 0.022s
#   training loss:		0.153810
#   validation loss:		0.146107
# Epoch 2379 of 2500 took 0.028s
#   training loss:		0.153337
#   validation loss:		0.147660
# Epoch 2380 of 2500 took 0.030s
#   training loss:		0.154456
#   validation loss:		0.146589
# Epoch 2381 of 2500 took 0.030s
#   training loss:		0.152937
#   validation loss:		0.147757
# Epoch 2382 of 2500 took 0.030s
#   training loss:		0.152937
#   validation loss:		0.148176
# Epoch 2383 of 2500 took 0.024s
#   training loss:		0.153047
#   validation loss:		0.146538
# Epoch 2384 of 2500 took 0.021s
#   training loss:		0.155187
#   validation loss:		0.148785
# Epoch 2385 of 2500 took 0.022s
#   training loss:		0.153108
#   validation loss:		0.147036
# Epoch 2386 of 2500 took 0.020s
#   training loss:		0.152908
#   validation loss:		0.147190
# Epoch 2387 of 2500 took 0.026s
#   training loss:		0.152773
#   validation loss:		0.146834
# Epoch 2388 of 2500 took 0.026s
#   training loss:		0.153184
#   validation loss:		0.147184
# Epoch 2389 of 2500 took 0.026s
#   training loss:		0.153784
#   validation loss:		0.147502
# Epoch 2390 of 2500 took 0.024s
#   training loss:		0.154174
#   validation loss:		0.150799
# Epoch 2391 of 2500 took 0.024s
#   training loss:		0.154358
#   validation loss:		0.146813
# Epoch 2392 of 2500 took 0.022s
#   training loss:		0.154097
#   validation loss:		0.148552
# Epoch 2393 of 2500 took 0.022s
#   training loss:		0.153818
#   validation loss:		0.147478
# Epoch 2394 of 2500 took 0.021s
#   training loss:		0.152948
#   validation loss:		0.146949
# Epoch 2395 of 2500 took 0.022s
#   training loss:		0.153230
#   validation loss:		0.147092
# Epoch 2396 of 2500 took 0.026s
#   training loss:		0.153657
#   validation loss:		0.146169
# Epoch 2397 of 2500 took 0.026s
#   training loss:		0.152656
#   validation loss:		0.146071
# Epoch 2398 of 2500 took 0.026s
#   training loss:		0.152791
#   validation loss:		0.145848
# Epoch 2399 of 2500 took 0.027s
#   training loss:		0.152491
#   validation loss:		0.146099
# Epoch 2400 of 2500 took 0.022s
#   training loss:		0.153164
#   validation loss:		0.146490
# Epoch 2401 of 2500 took 0.021s
#   training loss:		0.153163
#   validation loss:		0.147149
# Epoch 2402 of 2500 took 0.022s
#   training loss:		0.153668
#   validation loss:		0.147521
# Epoch 2403 of 2500 took 0.022s
#   training loss:		0.151919
#   validation loss:		0.145616
# Epoch 2404 of 2500 took 0.021s
#   training loss:		0.152998
#   validation loss:		0.147670
# Epoch 2405 of 2500 took 0.025s
#   training loss:		0.153740
#   validation loss:		0.147298
# Epoch 2406 of 2500 took 0.026s
#   training loss:		0.153601
#   validation loss:		0.146283
# Epoch 2407 of 2500 took 0.024s
#   training loss:		0.153643
#   validation loss:		0.145779
# Epoch 2408 of 2500 took 0.023s
#   training loss:		0.153452
#   validation loss:		0.150817
# Epoch 2409 of 2500 took 0.022s
#   training loss:		0.153281
#   validation loss:		0.145237
# Epoch 2410 of 2500 took 0.021s
#   training loss:		0.152965
#   validation loss:		0.148260
# Epoch 2411 of 2500 took 0.021s
#   training loss:		0.153258
#   validation loss:		0.146300
# Epoch 2412 of 2500 took 0.021s
#   training loss:		0.153858
#   validation loss:		0.145580
# Epoch 2413 of 2500 took 0.021s
#   training loss:		0.152196
#   validation loss:		0.147002
# Epoch 2414 of 2500 took 0.025s
#   training loss:		0.152383
#   validation loss:		0.147433
# Epoch 2415 of 2500 took 0.028s
#   training loss:		0.152487
#   validation loss:		0.146143
# Epoch 2416 of 2500 took 0.025s
#   training loss:		0.152765
#   validation loss:		0.146000
# Epoch 2417 of 2500 took 0.024s
#   training loss:		0.152355
#   validation loss:		0.146308
# Epoch 2418 of 2500 took 0.022s
#   training loss:		0.152553
#   validation loss:		0.145819
# Epoch 2419 of 2500 took 0.023s
#   training loss:		0.152803
#   validation loss:		0.147461
# Epoch 2420 of 2500 took 0.021s
#   training loss:		0.152549
#   validation loss:		0.147922
# Epoch 2421 of 2500 took 0.022s
#   training loss:		0.153286
#   validation loss:		0.145956
# Epoch 2422 of 2500 took 0.022s
#   training loss:		0.152102
#   validation loss:		0.146035
# Epoch 2423 of 2500 took 0.025s
#   training loss:		0.152763
#   validation loss:		0.146260
# Epoch 2424 of 2500 took 0.025s
#   training loss:		0.152034
#   validation loss:		0.145213
# Epoch 2425 of 2500 took 0.023s
#   training loss:		0.152027
#   validation loss:		0.146723
# Epoch 2426 of 2500 took 0.023s
#   training loss:		0.152397
#   validation loss:		0.146101
# Epoch 2427 of 2500 took 0.022s
#   training loss:		0.152012
#   validation loss:		0.147021
# Epoch 2428 of 2500 took 0.020s
#   training loss:		0.152781
#   validation loss:		0.147275
# Epoch 2429 of 2500 took 0.021s
#   training loss:		0.152892
#   validation loss:		0.145600
# Epoch 2430 of 2500 took 0.021s
#   training loss:		0.152012
#   validation loss:		0.145596
# Epoch 2431 of 2500 took 0.021s
#   training loss:		0.152475
#   validation loss:		0.145708
# Epoch 2432 of 2500 took 0.025s
#   training loss:		0.151624
#   validation loss:		0.146679
# Epoch 2433 of 2500 took 0.024s
#   training loss:		0.152512
#   validation loss:		0.146860
# Epoch 2434 of 2500 took 0.025s
#   training loss:		0.152316
#   validation loss:		0.147050
# Epoch 2435 of 2500 took 0.030s
#   training loss:		0.152307
#   validation loss:		0.145529
# Epoch 2436 of 2500 took 0.030s
#   training loss:		0.152753
#   validation loss:		0.150316
# Epoch 2437 of 2500 took 0.024s
#   training loss:		0.153717
#   validation loss:		0.146784
# Epoch 2438 of 2500 took 0.022s
#   training loss:		0.151901
#   validation loss:		0.145320
# Epoch 2439 of 2500 took 0.022s
#   training loss:		0.152328
#   validation loss:		0.147553
# Epoch 2440 of 2500 took 0.022s
#   training loss:		0.152480
#   validation loss:		0.146529
# Epoch 2441 of 2500 took 0.027s
#   training loss:		0.151921
#   validation loss:		0.146228
# Epoch 2442 of 2500 took 0.036s
#   training loss:		0.152647
#   validation loss:		0.145314
# Epoch 2443 of 2500 took 0.025s
#   training loss:		0.153858
#   validation loss:		0.146533
# Epoch 2444 of 2500 took 0.025s
#   training loss:		0.151883
#   validation loss:		0.146583
# Epoch 2445 of 2500 took 0.022s
#   training loss:		0.152073
#   validation loss:		0.146949
# Epoch 2446 of 2500 took 0.021s
#   training loss:		0.151779
#   validation loss:		0.144879
# Epoch 2447 of 2500 took 0.022s
#   training loss:		0.152558
#   validation loss:		0.146512
# Epoch 2448 of 2500 took 0.022s
#   training loss:		0.151795
#   validation loss:		0.146803
# Epoch 2449 of 2500 took 0.024s
#   training loss:		0.152234
#   validation loss:		0.145033
# Epoch 2450 of 2500 took 0.029s
#   training loss:		0.152642
#   validation loss:		0.146074
# Epoch 2451 of 2500 took 0.026s
#   training loss:		0.151651
#   validation loss:		0.148248
# Epoch 2452 of 2500 took 0.025s
#   training loss:		0.154427
#   validation loss:		0.145989
# Epoch 2453 of 2500 took 0.024s
#   training loss:		0.152191
#   validation loss:		0.145256
# Epoch 2454 of 2500 took 0.024s
#   training loss:		0.152824
#   validation loss:		0.147157
# Epoch 2455 of 2500 took 0.022s
#   training loss:		0.152764
#   validation loss:		0.147283
# Epoch 2456 of 2500 took 0.022s
#   training loss:		0.151905
#   validation loss:		0.147068
# Epoch 2457 of 2500 took 0.021s
#   training loss:		0.151778
#   validation loss:		0.146532
# Epoch 2458 of 2500 took 0.021s
#   training loss:		0.152061
#   validation loss:		0.147198
# Epoch 2459 of 2500 took 0.027s
#   training loss:		0.151982
#   validation loss:		0.145055
# Epoch 2460 of 2500 took 0.025s
#   training loss:		0.151318
#   validation loss:		0.146493
# Epoch 2461 of 2500 took 0.024s
#   training loss:		0.152271
#   validation loss:		0.144070
# Epoch 2462 of 2500 took 0.024s
#   training loss:		0.151684
#   validation loss:		0.146255
# Epoch 2463 of 2500 took 0.022s
#   training loss:		0.151917
#   validation loss:		0.145712
# Epoch 2464 of 2500 took 0.020s
#   training loss:		0.151977
#   validation loss:		0.145654
# Epoch 2465 of 2500 took 0.021s
#   training loss:		0.151364
#   validation loss:		0.146637
# Epoch 2466 of 2500 took 0.021s
#   training loss:		0.151327
#   validation loss:		0.146121
# Epoch 2467 of 2500 took 0.021s
#   training loss:		0.151334
#   validation loss:		0.145615
# Epoch 2468 of 2500 took 0.023s
#   training loss:		0.151198
#   validation loss:		0.145797
# Epoch 2469 of 2500 took 0.025s
#   training loss:		0.151355
#   validation loss:		0.147048
# Epoch 2470 of 2500 took 0.022s
#   training loss:		0.152637
#   validation loss:		0.144696
# Epoch 2471 of 2500 took 0.023s
#   training loss:		0.151995
#   validation loss:		0.146186
# Epoch 2472 of 2500 took 0.028s
#   training loss:		0.151795
#   validation loss:		0.148471
# Epoch 2473 of 2500 took 0.023s
#   training loss:		0.152515
#   validation loss:		0.144253
# Epoch 2474 of 2500 took 0.022s
#   training loss:		0.152328
#   validation loss:		0.145032
# Epoch 2475 of 2500 took 0.021s
#   training loss:		0.152419
#   validation loss:		0.145683
# Epoch 2476 of 2500 took 0.024s
#   training loss:		0.151088
#   validation loss:		0.145898
# Epoch 2477 of 2500 took 0.024s
#   training loss:		0.152509
#   validation loss:		0.145818
# Epoch 2478 of 2500 took 0.029s
#   training loss:		0.152230
#   validation loss:		0.145110
# Epoch 2479 of 2500 took 0.026s
#   training loss:		0.152123
#   validation loss:		0.146147
# Epoch 2480 of 2500 took 0.023s
#   training loss:		0.151486
#   validation loss:		0.146729
# Epoch 2481 of 2500 took 0.024s
#   training loss:		0.151458
#   validation loss:		0.144962
# Epoch 2482 of 2500 took 0.022s
#   training loss:		0.151034
#   validation loss:		0.145730
# Epoch 2483 of 2500 took 0.022s
#   training loss:		0.150750
#   validation loss:		0.145006
# Epoch 2484 of 2500 took 0.021s
#   training loss:		0.151931
#   validation loss:		0.147663
# Epoch 2485 of 2500 took 0.021s
#   training loss:		0.151376
#   validation loss:		0.144426
# Epoch 2486 of 2500 took 0.021s
#   training loss:		0.150753
#   validation loss:		0.146629
# Epoch 2487 of 2500 took 0.026s
#   training loss:		0.152432
#   validation loss:		0.145821
# Epoch 2488 of 2500 took 0.024s
#   training loss:		0.150993
#   validation loss:		0.144794
# Epoch 2489 of 2500 took 0.024s
#   training loss:		0.152070
#   validation loss:		0.146554
# Epoch 2490 of 2500 took 0.023s
#   training loss:		0.152224
#   validation loss:		0.145585
# Epoch 2491 of 2500 took 0.023s
#   training loss:		0.150771
#   validation loss:		0.144559
# Epoch 2492 of 2500 took 0.022s
#   training loss:		0.152236
#   validation loss:		0.146113
# Epoch 2493 of 2500 took 0.021s
#   training loss:		0.150950
#   validation loss:		0.144843
# Epoch 2494 of 2500 took 0.022s
#   training loss:		0.150770
#   validation loss:		0.146576
# Epoch 2495 of 2500 took 0.022s
#   training loss:		0.150878
#   validation loss:		0.144662
# Epoch 2496 of 2500 took 0.024s
#   training loss:		0.151002
#   validation loss:		0.145922
# Epoch 2497 of 2500 took 0.030s
#   training loss:		0.151617
#   validation loss:		0.146057
# Epoch 2498 of 2500 took 0.025s
#   training loss:		0.150729
#   validation loss:		0.145966
# Epoch 2499 of 2500 took 0.026s
#   training loss:		0.150622
#   validation loss:		0.145916
# Epoch 2500 of 2500 took 0.023s
#   training loss:		0.150671
#   validation loss:		0.144636
# Final results:
#   test loss:			0.143221

# %%
epoch = range(2500)
plt.figure()
plt.plot(epoch, train_loss, label = 'train loss')
plt.plot(epoch, val_loss, label = 'val loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

npdata = np.load('data4/num_accident_OH_norm2.npy')
output = lasagne.layers.get_output(network, inputs= npdata[2016:2352, 0:-1].reshape(336,1,8)).eval()
prediction = np.zeros(336)
prediction = output.reshape(336)

plt.figure(figsize = (35,5))
plt.plot(prediction, color='r')
plt.plot(npdata[2016:2353, -1], color = 'k')

# %% [markdown]
# ### LSTM

# %%
def load_dataset():
    npdata = np.load('data4/num_accident_OH_norm2.npy')
    npdata = npdata.astype(np.float32)
    X_train, X_val = npdata[0:1680, 0:-1].reshape(1680,1,8), npdata[1680:2016, 0:-1].reshape(336,1,8)
    y_train, y_val = npdata[0:1680, -1].reshape(1680,1), npdata[1680:2016, -1].reshape(336,1)
    x_test, y_test = npdata[2016:2352, 0:-1].reshape(336,1,8), npdata[2016:2352, -1].reshape(336,1)
    #print (X_train.shape, y_train.shape, X_val.shape, y_val.shape, npdata.shape)
    return X_train, y_train, X_val, y_val, x_test, y_test


def build_mlp(input_var=None, units = 15):
    
    # Input layer, specifying the expected input shape of the network
    l_in = lasagne.layers.InputLayer(shape=(None,1,8),
                                     input_var=input_var)

    l_hid1 = lasagne.layers.LSTMLayer(
            l_in, num_units = units)
    
    l_hid2 = lasagne.layers.LSTMLayer(
            l_hid1, num_units = units)
    
    l_hid3 = lasagne.layers.LSTMLayer(
            l_hid2, num_units = units)
    
#     l_hid2 = lasagne.layers.DenseLayer(
#             l_hid1, num_units = units*2,
#             nonlinearity=lasagne.nonlinearities.sigmoid,
#             W=lasagne.init.GlorotUniform())
    
#     l_hid3 = lasagne.layers.DenseLayer(
#             l_hid2, num_units = units*2,
#             nonlinearity=lasagne.nonlinearities.sigmoid,
#             W=lasagne.init.GlorotUniform())
        
    l_out = lasagne.layers.DenseLayer(
            l_hid3, num_units=1,
            nonlinearity=lasagne.nonlinearities.linear)

    return l_out

network, train_loss, val_loss = train_mlp(num_epochs=2500, learning_rate=0.02)
np.savez('model/model3.npz', *lasagne.layers.get_all_param_values(network))
# Out:
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 2500 took 0.059s
#   training loss:		1.009313
#   validation loss:		1.002230
# Epoch 2 of 2500 took 0.055s
#   training loss:		1.008601
#   validation loss:		1.001839
# Epoch 3 of 2500 took 0.058s
#   training loss:		1.008729
#   validation loss:		1.002060
# Epoch 4 of 2500 took 0.060s
#   training loss:		1.008401
#   validation loss:		1.002016
# Epoch 5 of 2500 took 0.079s
#   training loss:		1.008369
#   validation loss:		1.001858
# Epoch 6 of 2500 took 0.059s
#   training loss:		1.008382
#   validation loss:		1.002140
# Epoch 7 of 2500 took 0.059s
#   training loss:		1.008376
#   validation loss:		1.002224
# Epoch 8 of 2500 took 0.077s
#   training loss:		1.008430
#   validation loss:		1.002219
# Epoch 9 of 2500 took 0.056s
#   training loss:		1.008362
#   validation loss:		1.002396
# Epoch 10 of 2500 took 0.056s
#   training loss:		1.008439
#   validation loss:		1.002540
# Epoch 11 of 2500 took 0.059s
#   training loss:		1.008378
#   validation loss:		1.001882
# Epoch 12 of 2500 took 0.060s
#   training loss:		1.008819
#   validation loss:		1.001732
# Epoch 13 of 2500 took 0.060s
#   training loss:		1.008319
#   validation loss:		1.002086
# Epoch 14 of 2500 took 0.060s
#   training loss:		1.008361
#   validation loss:		1.002302
# Epoch 15 of 2500 took 0.056s
#   training loss:		1.008472
#   validation loss:		1.002389
# Epoch 16 of 2500 took 0.060s
#   training loss:		1.008438
#   validation loss:		1.002130
# Epoch 17 of 2500 took 0.059s
#   training loss:		1.008366
#   validation loss:		1.001705
# Epoch 18 of 2500 took 0.056s
#   training loss:		1.008574
#   validation loss:		1.001811
# Epoch 19 of 2500 took 0.055s
#   training loss:		1.008382
#   validation loss:		1.002055
# Epoch 20 of 2500 took 0.062s
#   training loss:		1.009214
#   validation loss:		1.002844
# Epoch 21 of 2500 took 0.065s
#   training loss:		1.008356
#   validation loss:		1.002207
# Epoch 22 of 2500 took 0.058s
#   training loss:		1.008354
#   validation loss:		1.001955
# Epoch 23 of 2500 took 0.058s
#   training loss:		1.008266
#   validation loss:		1.001705
# Epoch 24 of 2500 took 0.062s
#   training loss:		1.008995
#   validation loss:		1.001584
# Epoch 25 of 2500 took 0.067s
#   training loss:		1.008494
#   validation loss:		1.002181
# Epoch 26 of 2500 took 0.061s
#   training loss:		1.008283
#   validation loss:		1.002320
# Epoch 27 of 2500 took 0.055s
#   training loss:		1.008678
#   validation loss:		1.002230
# Epoch 28 of 2500 took 0.063s
#   training loss:		1.008569
#   validation loss:		1.001821
# Epoch 29 of 2500 took 0.066s
#   training loss:		1.008562
#   validation loss:		1.001889
# Epoch 30 of 2500 took 0.056s
#   training loss:		1.008187
#   validation loss:		1.002246
# Epoch 31 of 2500 took 0.057s
#   training loss:		1.008300
#   validation loss:		1.002469
# Epoch 32 of 2500 took 0.063s
#   training loss:		1.008629
#   validation loss:		1.002368
# Epoch 33 of 2500 took 0.069s
#   training loss:		1.008585
#   validation loss:		1.001808
# Epoch 34 of 2500 took 0.054s
#   training loss:		1.008784
#   validation loss:		1.001653
# Epoch 35 of 2500 took 0.055s
#   training loss:		1.008474
#   validation loss:		1.002208
# Epoch 36 of 2500 took 0.061s
#   training loss:		1.008975
#   validation loss:		1.002695
# Epoch 37 of 2500 took 0.067s
#   training loss:		1.008291
#   validation loss:		1.001828
# Epoch 38 of 2500 took 0.058s
#   training loss:		1.008677
#   validation loss:		1.001637
# Epoch 39 of 2500 took 0.056s
#   training loss:		1.008302
#   validation loss:		1.001954
# Epoch 40 of 2500 took 0.064s
#   training loss:		1.008259
#   validation loss:		1.002234
# Epoch 41 of 2500 took 0.067s
#   training loss:		1.008603
#   validation loss:		1.002705
# Epoch 42 of 2500 took 0.055s
#   training loss:		1.008714
#   validation loss:		1.001934
# Epoch 43 of 2500 took 0.056s
#   training loss:		1.008421
#   validation loss:		1.001743
# Epoch 44 of 2500 took 0.060s
#   training loss:		1.008584
#   validation loss:		1.001931
# Epoch 45 of 2500 took 0.057s
#   training loss:		1.008458
#   validation loss:		1.002435
# Epoch 46 of 2500 took 0.057s
#   training loss:		1.008269
#   validation loss:		1.002152
# Epoch 47 of 2500 took 0.053s
#   training loss:		1.008246
#   validation loss:		1.002055
# Epoch 48 of 2500 took 0.058s
#   training loss:		1.008383
#   validation loss:		1.001878
# Epoch 49 of 2500 took 0.058s
#   training loss:		1.008312
#   validation loss:		1.002317
# Epoch 50 of 2500 took 0.057s
#   training loss:		1.008490
#   validation loss:		1.002352
# Epoch 51 of 2500 took 0.056s
#   training loss:		1.008214
#   validation loss:		1.001769
# Epoch 52 of 2500 took 0.058s
#   training loss:		1.008370
#   validation loss:		1.001799
# Epoch 53 of 2500 took 0.056s
#   training loss:		1.008652
#   validation loss:		1.001516
# Epoch 54 of 2500 took 0.057s
#   training loss:		1.008357
#   validation loss:		1.002004
# Epoch 55 of 2500 took 0.056s
#   training loss:		1.008321
#   validation loss:		1.002545
# Epoch 56 of 2500 took 0.056s
#   training loss:		1.008538
#   validation loss:		1.002055
# Epoch 57 of 2500 took 0.060s
#   training loss:		1.008886
#   validation loss:		1.002199
# Epoch 58 of 2500 took 0.059s
#   training loss:		1.008436
#   validation loss:		1.001868
# Epoch 59 of 2500 took 0.057s
#   training loss:		1.008249
#   validation loss:		1.001982
# Epoch 60 of 2500 took 0.060s
#   training loss:		1.008275
#   validation loss:		1.002089
# Epoch 61 of 2500 took 0.055s
#   training loss:		1.008332
#   validation loss:		1.001847
# Epoch 62 of 2500 took 0.057s
#   training loss:		1.008572
#   validation loss:		1.002046
# Epoch 63 of 2500 took 0.056s
#   training loss:		1.008129
#   validation loss:		1.001880
# Epoch 64 of 2500 took 0.060s
#   training loss:		1.008165
#   validation loss:		1.001921
# Epoch 65 of 2500 took 0.059s
#   training loss:		1.008268
#   validation loss:		1.001986
# Epoch 66 of 2500 took 0.056s
#   training loss:		1.008535
#   validation loss:		1.001762
# Epoch 67 of 2500 took 0.056s
#   training loss:		1.008131
#   validation loss:		1.002026
# Epoch 68 of 2500 took 0.061s
#   training loss:		1.008342
#   validation loss:		1.002339
# Epoch 69 of 2500 took 0.058s
#   training loss:		1.008266
#   validation loss:		1.002057
# Epoch 70 of 2500 took 0.056s
#   training loss:		1.008249
#   validation loss:		1.001729
# Epoch 71 of 2500 took 0.057s
#   training loss:		1.008419
#   validation loss:		1.001996
# Epoch 72 of 2500 took 0.057s
#   training loss:		1.008526
#   validation loss:		1.001696
# Epoch 73 of 2500 took 0.061s
#   training loss:		1.008122
#   validation loss:		1.001942
# Epoch 74 of 2500 took 0.055s
#   training loss:		1.008576
#   validation loss:		1.002226
# Epoch 75 of 2500 took 0.055s
#   training loss:		1.008178
#   validation loss:		1.002009
# Epoch 76 of 2500 took 0.066s
#   training loss:		1.008266
#   validation loss:		1.001689
# Epoch 77 of 2500 took 0.061s
#   training loss:		1.008276
#   validation loss:		1.002009
# Epoch 78 of 2500 took 0.054s
#   training loss:		1.008474
#   validation loss:		1.002374
# Epoch 79 of 2500 took 0.057s
#   training loss:		1.008495
#   validation loss:		1.002215
# Epoch 80 of 2500 took 0.067s
#   training loss:		1.008007
#   validation loss:		1.001632
# Epoch 81 of 2500 took 0.055s
#   training loss:		1.008122
#   validation loss:		1.001515
# Epoch 82 of 2500 took 0.056s
#   training loss:		1.008209
#   validation loss:		1.001628
# Epoch 83 of 2500 took 0.055s
#   training loss:		1.008078
#   validation loss:		1.002016
# Epoch 84 of 2500 took 0.058s
#   training loss:		1.008210
#   validation loss:		1.002175
# Epoch 85 of 2500 took 0.057s
#   training loss:		1.008333
#   validation loss:		1.002009
# Epoch 86 of 2500 took 0.054s
#   training loss:		1.008063
#   validation loss:		1.002168
# Epoch 87 of 2500 took 0.058s
#   training loss:		1.008192
#   validation loss:		1.002091
# Epoch 88 of 2500 took 0.059s
#   training loss:		1.008235
#   validation loss:		1.002068
# Epoch 89 of 2500 took 0.057s
#   training loss:		1.008165
#   validation loss:		1.002348
# Epoch 90 of 2500 took 0.054s
#   training loss:		1.008344
#   validation loss:		1.002183
# Epoch 91 of 2500 took 0.057s
#   training loss:		1.008230
#   validation loss:		1.001576
# Epoch 92 of 2500 took 0.056s
#   training loss:		1.008738
#   validation loss:		1.002049
# Epoch 93 of 2500 took 0.054s
#   training loss:		1.008315
#   validation loss:		1.001649
# Epoch 94 of 2500 took 0.055s
#   training loss:		1.008379
#   validation loss:		1.001650
# Epoch 95 of 2500 took 0.056s
#   training loss:		1.008800
#   validation loss:		1.001669
# Epoch 96 of 2500 took 0.057s
#   training loss:		1.007986
#   validation loss:		1.002324
# Epoch 97 of 2500 took 0.054s
#   training loss:		1.008089
#   validation loss:		1.002695
# Epoch 98 of 2500 took 0.055s
#   training loss:		1.008313
#   validation loss:		1.002188
# Epoch 99 of 2500 took 0.059s
#   training loss:		1.008584
#   validation loss:		1.001890
# Epoch 100 of 2500 took 0.055s
#   training loss:		1.008179
#   validation loss:		1.001977
# Epoch 101 of 2500 took 0.055s
#   training loss:		1.008109
#   validation loss:		1.002030
# Epoch 102 of 2500 took 0.056s
#   training loss:		1.010379
#   validation loss:		1.001386
# Epoch 103 of 2500 took 0.055s
#   training loss:		1.008421
#   validation loss:		1.002622
# Epoch 104 of 2500 took 0.056s
#   training loss:		1.008719
#   validation loss:		1.002720
# Epoch 105 of 2500 took 0.061s
#   training loss:		1.008723
#   validation loss:		1.001647
# Epoch 106 of 2500 took 0.056s
#   training loss:		1.008496
#   validation loss:		1.001634
# Epoch 107 of 2500 took 0.057s
#   training loss:		1.008509
#   validation loss:		1.001767
# Epoch 108 of 2500 took 0.061s
#   training loss:		1.008114
#   validation loss:		1.001963
# Epoch 109 of 2500 took 0.058s
#   training loss:		1.008289
#   validation loss:		1.002372
# Epoch 110 of 2500 took 0.062s
#   training loss:		1.008624
#   validation loss:		1.001957
# Epoch 111 of 2500 took 0.054s
#   training loss:		1.008527
#   validation loss:		1.002063
# Epoch 112 of 2500 took 0.068s
#   training loss:		1.008056
#   validation loss:		1.001663
# Epoch 113 of 2500 took 0.069s
#   training loss:		1.008227
#   validation loss:		1.001667
# Epoch 114 of 2500 took 0.061s
#   training loss:		1.008104
#   validation loss:		1.002000
# Epoch 115 of 2500 took 0.062s
#   training loss:		1.008288
#   validation loss:		1.001721
# Epoch 116 of 2500 took 0.071s
#   training loss:		1.008076
#   validation loss:		1.001837
# Epoch 117 of 2500 took 0.062s
#   training loss:		1.008137
#   validation loss:		1.002271
# Epoch 118 of 2500 took 0.060s
#   training loss:		1.008432
#   validation loss:		1.001925
# Epoch 119 of 2500 took 0.059s
#   training loss:		1.009591
#   validation loss:		1.002840
# Epoch 120 of 2500 took 0.059s
#   training loss:		1.008262
#   validation loss:		1.001611
# Epoch 121 of 2500 took 0.057s
#   training loss:		1.008317
#   validation loss:		1.001569
# Epoch 122 of 2500 took 0.055s
#   training loss:		1.008474
#   validation loss:		1.001476
# Epoch 123 of 2500 took 0.054s
#   training loss:		1.008102
#   validation loss:		1.002242
# Epoch 124 of 2500 took 0.056s
#   training loss:		1.008175
#   validation loss:		1.002078
# Epoch 125 of 2500 took 0.057s
#   training loss:		1.008071
#   validation loss:		1.002021
# Epoch 126 of 2500 took 0.057s
#   training loss:		1.008340
#   validation loss:		1.001844
# Epoch 127 of 2500 took 0.062s
#   training loss:		1.008137
#   validation loss:		1.002105
# Epoch 128 of 2500 took 0.059s
#   training loss:		1.008341
#   validation loss:		1.001609
# Epoch 129 of 2500 took 0.056s
#   training loss:		1.008009
#   validation loss:		1.001820
# Epoch 130 of 2500 took 0.057s
#   training loss:		1.008185
#   validation loss:		1.001917
# Epoch 131 of 2500 took 0.058s
#   training loss:		1.008027
#   validation loss:		1.001802
# Epoch 132 of 2500 took 0.063s
#   training loss:		1.008163
#   validation loss:		1.001657
# Epoch 133 of 2500 took 0.059s
#   training loss:		1.008093
#   validation loss:		1.001845
# Epoch 134 of 2500 took 0.058s
#   training loss:		1.008356
#   validation loss:		1.001848
# Epoch 135 of 2500 took 0.054s
#   training loss:		1.008599
#   validation loss:		1.002370
# Epoch 136 of 2500 took 0.060s
#   training loss:		1.008100
#   validation loss:		1.001840
# Epoch 137 of 2500 took 0.060s
#   training loss:		1.008611
#   validation loss:		1.001375
# Epoch 138 of 2500 took 0.057s
#   training loss:		1.008149
#   validation loss:		1.001517
# Epoch 139 of 2500 took 0.055s
#   training loss:		1.007878
#   validation loss:		1.001942
# Epoch 140 of 2500 took 0.056s
#   training loss:		1.008216
#   validation loss:		1.002356
# Epoch 141 of 2500 took 0.058s
#   training loss:		1.008240
#   validation loss:		1.001696
# Epoch 142 of 2500 took 0.057s
#   training loss:		1.008044
#   validation loss:		1.001625
# Epoch 143 of 2500 took 0.064s
#   training loss:		1.007920
#   validation loss:		1.001862
# Epoch 144 of 2500 took 0.068s
#   training loss:		1.007989
#   validation loss:		1.001857
# Epoch 145 of 2500 took 0.055s
#   training loss:		1.008064
#   validation loss:		1.002230
# Epoch 146 of 2500 took 0.057s
#   training loss:		1.008099
#   validation loss:		1.001691
# Epoch 147 of 2500 took 0.059s
#   training loss:		1.008450
#   validation loss:		1.001731
# Epoch 148 of 2500 took 0.060s
#   training loss:		1.008289
#   validation loss:		1.001783
# Epoch 149 of 2500 took 0.058s
#   training loss:		1.008270
#   validation loss:		1.001523
# Epoch 150 of 2500 took 0.055s
#   training loss:		1.008129
#   validation loss:		1.001731
# Epoch 151 of 2500 took 0.056s
#   training loss:		1.008179
#   validation loss:		1.001523
# Epoch 152 of 2500 took 0.062s
#   training loss:		1.007961
#   validation loss:		1.001487
# Epoch 153 of 2500 took 0.060s
#   training loss:		1.008057
#   validation loss:		1.001672
# Epoch 154 of 2500 took 0.053s
#   training loss:		1.008113
#   validation loss:		1.001825
# Epoch 155 of 2500 took 0.056s
#   training loss:		1.008211
#   validation loss:		1.001733
# Epoch 156 of 2500 took 0.058s
#   training loss:		1.007852
#   validation loss:		1.001430
# Epoch 157 of 2500 took 0.056s
#   training loss:		1.008436
#   validation loss:		1.001673
# Epoch 158 of 2500 took 0.056s
#   training loss:		1.007916
#   validation loss:		1.001441
# Epoch 159 of 2500 took 0.057s
#   training loss:		1.008032
#   validation loss:		1.001434
# Epoch 160 of 2500 took 0.058s
#   training loss:		1.008146
#   validation loss:		1.001669
# Epoch 161 of 2500 took 0.056s
#   training loss:		1.008066
#   validation loss:		1.001845
# Epoch 162 of 2500 took 0.057s
#   training loss:		1.007956
#   validation loss:		1.001660
# Epoch 163 of 2500 took 0.057s
#   training loss:		1.007858
#   validation loss:		1.001861
# Epoch 164 of 2500 took 0.058s
#   training loss:		1.007999
#   validation loss:		1.001570
# Epoch 165 of 2500 took 0.058s
#   training loss:		1.008092
#   validation loss:		1.001830
# Epoch 166 of 2500 took 0.062s
#   training loss:		1.007888
#   validation loss:		1.001679
# Epoch 167 of 2500 took 0.061s
#   training loss:		1.008018
#   validation loss:		1.001467
# Epoch 168 of 2500 took 0.058s
#   training loss:		1.007947
#   validation loss:		1.001316
# Epoch 169 of 2500 took 0.059s
#   training loss:		1.007841
#   validation loss:		1.001614
# Epoch 170 of 2500 took 0.061s
#   training loss:		1.007925
#   validation loss:		1.001765
# Epoch 171 of 2500 took 0.059s
#   training loss:		1.007941
#   validation loss:		1.001952
# Epoch 172 of 2500 took 0.060s
#   training loss:		1.008134
#   validation loss:		1.001431
# Epoch 173 of 2500 took 0.062s
#   training loss:		1.007848
#   validation loss:		1.001596
# Epoch 174 of 2500 took 0.059s
#   training loss:		1.007936
#   validation loss:		1.001801
# Epoch 175 of 2500 took 0.059s
#   training loss:		1.008219
#   validation loss:		1.002020
# Epoch 176 of 2500 took 0.064s
#   training loss:		1.008100
#   validation loss:		1.001303
# Epoch 177 of 2500 took 0.059s
#   training loss:		1.008039
#   validation loss:		1.001306
# Epoch 178 of 2500 took 0.061s
#   training loss:		1.008233
#   validation loss:		1.002055
# Epoch 179 of 2500 took 0.058s
#   training loss:		1.007957
#   validation loss:		1.001612
# Epoch 180 of 2500 took 0.058s
#   training loss:		1.008358
#   validation loss:		1.001418
# Epoch 181 of 2500 took 0.059s
#   training loss:		1.007724
#   validation loss:		1.001670
# Epoch 182 of 2500 took 0.052s
#   training loss:		1.007871
#   validation loss:		1.001857
# Epoch 183 of 2500 took 0.059s
#   training loss:		1.008065
#   validation loss:		1.001648
# Epoch 184 of 2500 took 0.061s
#   training loss:		1.007930
#   validation loss:		1.001327
# Epoch 185 of 2500 took 0.060s
#   training loss:		1.007790
#   validation loss:		1.001591
# Epoch 186 of 2500 took 0.058s
#   training loss:		1.007920
#   validation loss:		1.001823
# Epoch 187 of 2500 took 0.057s
#   training loss:		1.007790
#   validation loss:		1.001436
# Epoch 188 of 2500 took 0.058s
#   training loss:		1.008025
#   validation loss:		1.001554
# Epoch 189 of 2500 took 0.061s
#   training loss:		1.007944
#   validation loss:		1.001579
# Epoch 190 of 2500 took 0.058s
#   training loss:		1.007890
#   validation loss:		1.001182
# Epoch 191 of 2500 took 0.057s
#   training loss:		1.007904
#   validation loss:		1.001245
# Epoch 192 of 2500 took 0.058s
#   training loss:		1.007667
#   validation loss:		1.001745
# Epoch 193 of 2500 took 0.057s
#   training loss:		1.007829
#   validation loss:		1.001729
# Epoch 194 of 2500 took 0.057s
#   training loss:		1.007698
#   validation loss:		1.002076
# Epoch 195 of 2500 took 0.056s
#   training loss:		1.007705
#   validation loss:		1.001872
# Epoch 196 of 2500 took 0.059s
#   training loss:		1.008215
#   validation loss:		1.001306
# Epoch 197 of 2500 took 0.059s
#   training loss:		1.007677
#   validation loss:		1.001515
# Epoch 198 of 2500 took 0.056s
#   training loss:		1.007718
#   validation loss:		1.001692
# Epoch 199 of 2500 took 0.056s
#   training loss:		1.008135
#   validation loss:		1.001341
# Epoch 200 of 2500 took 0.058s
#   training loss:		1.007697
#   validation loss:		1.001943
# Epoch 201 of 2500 took 0.061s
#   training loss:		1.007930
#   validation loss:		1.002056
# Epoch 202 of 2500 took 0.055s
#   training loss:		1.008218
#   validation loss:		1.001188
# Epoch 203 of 2500 took 0.055s
#   training loss:		1.007644
#   validation loss:		1.001352
# Epoch 204 of 2500 took 0.059s
#   training loss:		1.007762
#   validation loss:		1.001655
# Epoch 205 of 2500 took 0.057s
#   training loss:		1.007720
#   validation loss:		1.001441
# Epoch 206 of 2500 took 0.058s
#   training loss:		1.007656
#   validation loss:		1.001291
# Epoch 207 of 2500 took 0.057s
#   training loss:		1.008010
#   validation loss:		1.001739
# Epoch 208 of 2500 took 0.057s
#   training loss:		1.007611
#   validation loss:		1.001306
# Epoch 209 of 2500 took 0.058s
#   training loss:		1.007632
#   validation loss:		1.001203
# Epoch 210 of 2500 took 0.061s
#   training loss:		1.007747
#   validation loss:		1.001168
# Epoch 211 of 2500 took 0.059s
#   training loss:		1.007770
#   validation loss:		1.001715
# Epoch 212 of 2500 took 0.058s
#   training loss:		1.007863
#   validation loss:		1.001584
# Epoch 213 of 2500 took 0.058s
#   training loss:		1.007636
#   validation loss:		1.001443
# Epoch 214 of 2500 took 0.058s
#   training loss:		1.008082
#   validation loss:		1.001540
# Epoch 215 of 2500 took 0.055s
#   training loss:		1.008132
#   validation loss:		1.000845
# Epoch 216 of 2500 took 0.055s
#   training loss:		1.007636
#   validation loss:		1.001104
# Epoch 217 of 2500 took 0.058s
#   training loss:		1.008106
#   validation loss:		1.001212
# Epoch 218 of 2500 took 0.058s
#   training loss:		1.007456
#   validation loss:		1.001722
# Epoch 219 of 2500 took 0.060s
#   training loss:		1.007594
#   validation loss:		1.001700
# Epoch 220 of 2500 took 0.057s
#   training loss:		1.007674
#   validation loss:		1.001790
# Epoch 221 of 2500 took 0.059s
#   training loss:		1.008177
#   validation loss:		1.001176
# Epoch 222 of 2500 took 0.055s
#   training loss:		1.007584
#   validation loss:		1.001539
# Epoch 223 of 2500 took 0.057s
#   training loss:		1.007587
#   validation loss:		1.001398
# Epoch 224 of 2500 took 0.056s
#   training loss:		1.007447
#   validation loss:		1.001618
# Epoch 225 of 2500 took 0.057s
#   training loss:		1.007805
#   validation loss:		1.001326
# Epoch 226 of 2500 took 0.056s
#   training loss:		1.007950
#   validation loss:		1.001449
# Epoch 227 of 2500 took 0.055s
#   training loss:		1.007840
#   validation loss:		1.001283
# Epoch 228 of 2500 took 0.056s
#   training loss:		1.007428
#   validation loss:		1.001575
# Epoch 229 of 2500 took 0.059s
#   training loss:		1.007726
#   validation loss:		1.001722
# Epoch 230 of 2500 took 0.057s
#   training loss:		1.007384
#   validation loss:		1.001311
# Epoch 231 of 2500 took 0.056s
#   training loss:		1.007475
#   validation loss:		1.000893
# Epoch 232 of 2500 took 0.059s
#   training loss:		1.007704
#   validation loss:		1.001042
# Epoch 233 of 2500 took 0.057s
#   training loss:		1.007603
#   validation loss:		1.001039
# Epoch 234 of 2500 took 0.056s
#   training loss:		1.007862
#   validation loss:		1.001459
# Epoch 235 of 2500 took 0.055s
#   training loss:		1.007621
#   validation loss:		1.001414
# Epoch 236 of 2500 took 0.056s
#   training loss:		1.007445
#   validation loss:		1.000946
# Epoch 237 of 2500 took 0.057s
#   training loss:		1.007972
#   validation loss:		1.001307
# Epoch 238 of 2500 took 0.054s
#   training loss:		1.007503
#   validation loss:		1.001028
# Epoch 239 of 2500 took 0.057s
#   training loss:		1.007789
#   validation loss:		1.000725
# Epoch 240 of 2500 took 0.058s
#   training loss:		1.007528
#   validation loss:		1.001273
# Epoch 241 of 2500 took 0.056s
#   training loss:		1.007728
#   validation loss:		1.001690
# Epoch 242 of 2500 took 0.056s
#   training loss:		1.007524
#   validation loss:		1.001025
# Epoch 243 of 2500 took 0.056s
#   training loss:		1.007696
#   validation loss:		1.000708
# Epoch 244 of 2500 took 0.057s
#   training loss:		1.007398
#   validation loss:		1.001131
# Epoch 245 of 2500 took 0.058s
#   training loss:		1.007451
#   validation loss:		1.001375
# Epoch 246 of 2500 took 0.055s
#   training loss:		1.007357
#   validation loss:		1.000978
# Epoch 247 of 2500 took 0.053s
#   training loss:		1.007250
#   validation loss:		1.001008
# Epoch 248 of 2500 took 0.064s
#   training loss:		1.007368
#   validation loss:		1.000982
# Epoch 249 of 2500 took 0.075s
#   training loss:		1.007642
#   validation loss:		1.000852
# Epoch 250 of 2500 took 0.055s
#   training loss:		1.007156
#   validation loss:		1.001457
# Epoch 251 of 2500 took 0.055s
#   training loss:		1.007413
#   validation loss:		1.001629
# Epoch 252 of 2500 took 0.072s
#   training loss:		1.007488
#   validation loss:		1.001173
# Epoch 253 of 2500 took 0.060s
#   training loss:		1.007662
#   validation loss:		1.000617
# Epoch 254 of 2500 took 0.056s
#   training loss:		1.007511
#   validation loss:		1.001148
# Epoch 255 of 2500 took 0.056s
#   training loss:		1.007292
#   validation loss:		1.001049
# Epoch 256 of 2500 took 0.060s
#   training loss:		1.007332
#   validation loss:		1.001258
# Epoch 257 of 2500 took 0.058s
#   training loss:		1.007128
#   validation loss:		1.000815
# Epoch 258 of 2500 took 0.055s
#   training loss:		1.007296
#   validation loss:		1.000865
# Epoch 259 of 2500 took 0.057s
#   training loss:		1.007198
#   validation loss:		1.000727
# Epoch 260 of 2500 took 0.058s
#   training loss:		1.007791
#   validation loss:		1.001419
# Epoch 261 of 2500 took 0.061s
#   training loss:		1.007247
#   validation loss:		1.000832
# Epoch 262 of 2500 took 0.058s
#   training loss:		1.007337
#   validation loss:		1.001041
# Epoch 263 of 2500 took 0.058s
#   training loss:		1.007260
#   validation loss:		1.000523
# Epoch 264 of 2500 took 0.058s
#   training loss:		1.007276
#   validation loss:		1.000592
# Epoch 265 of 2500 took 0.059s
#   training loss:		1.007574
#   validation loss:		1.000776
# Epoch 266 of 2500 took 0.054s
#   training loss:		1.006950
#   validation loss:		1.001656
# Epoch 267 of 2500 took 0.056s
#   training loss:		1.007664
#   validation loss:		1.002165
# Epoch 268 of 2500 took 0.054s
#   training loss:		1.007358
#   validation loss:		1.000686
# Epoch 269 of 2500 took 0.057s
#   training loss:		1.007018
#   validation loss:		1.000463
# Epoch 270 of 2500 took 0.058s
#   training loss:		1.006995
#   validation loss:		1.000591
# Epoch 271 of 2500 took 0.060s
#   training loss:		1.006973
#   validation loss:		1.000792
# Epoch 272 of 2500 took 0.059s
#   training loss:		1.007566
#   validation loss:		1.001309
# Epoch 273 of 2500 took 0.060s
#   training loss:		1.007112
#   validation loss:		1.000616
# Epoch 274 of 2500 took 0.058s
#   training loss:		1.006853
#   validation loss:		1.000499
# Epoch 275 of 2500 took 0.059s
#   training loss:		1.007046
#   validation loss:		1.000569
# Epoch 276 of 2500 took 0.061s
#   training loss:		1.007579
#   validation loss:		1.001024
# Epoch 277 of 2500 took 0.059s
#   training loss:		1.007016
#   validation loss:		1.000922
# Epoch 278 of 2500 took 0.059s
#   training loss:		1.007141
#   validation loss:		1.000873
# Epoch 279 of 2500 took 0.054s
#   training loss:		1.006836
#   validation loss:		1.000260
# Epoch 280 of 2500 took 0.063s
#   training loss:		1.007068
#   validation loss:		1.000407
# Epoch 281 of 2500 took 0.072s
#   training loss:		1.006808
#   validation loss:		1.000303
# Epoch 282 of 2500 took 0.074s
#   training loss:		1.007015
#   validation loss:		1.000465
# Epoch 283 of 2500 took 0.061s
#   training loss:		1.007446
#   validation loss:		1.001050
# Epoch 284 of 2500 took 0.076s
#   training loss:		1.006986
#   validation loss:		1.000492
# Epoch 285 of 2500 took 0.059s
#   training loss:		1.006804
#   validation loss:		1.000542
# Epoch 286 of 2500 took 0.060s
#   training loss:		1.007011
#   validation loss:		1.000218
# Epoch 287 of 2500 took 0.068s
#   training loss:		1.007096
#   validation loss:		0.999965
# Epoch 288 of 2500 took 0.061s
#   training loss:		1.007009
#   validation loss:		1.000658
# Epoch 289 of 2500 took 0.062s
#   training loss:		1.006577
#   validation loss:		1.000815
# Epoch 290 of 2500 took 0.058s
#   training loss:		1.006548
#   validation loss:		1.000470
# Epoch 291 of 2500 took 0.063s
#   training loss:		1.007223
#   validation loss:		1.000305
# Epoch 292 of 2500 took 0.058s
#   training loss:		1.006578
#   validation loss:		1.000109
# Epoch 293 of 2500 took 0.058s
#   training loss:		1.006745
#   validation loss:		1.000198
# Epoch 294 of 2500 took 0.059s
#   training loss:		1.006431
#   validation loss:		1.000265
# Epoch 295 of 2500 took 0.058s
#   training loss:		1.006659
#   validation loss:		1.000741
# Epoch 296 of 2500 took 0.059s
#   training loss:		1.006370
#   validation loss:		1.000314
# Epoch 297 of 2500 took 0.057s
#   training loss:		1.006962
#   validation loss:		0.999972
# Epoch 298 of 2500 took 0.055s
#   training loss:		1.006531
#   validation loss:		1.000319
# Epoch 299 of 2500 took 0.055s
#   training loss:		1.006624
#   validation loss:		1.000214
# Epoch 300 of 2500 took 0.061s
#   training loss:		1.007049
#   validation loss:		1.000796
# Epoch 301 of 2500 took 0.057s
#   training loss:		1.006380
#   validation loss:		1.000124
# Epoch 302 of 2500 took 0.055s
#   training loss:		1.006575
#   validation loss:		1.000095
# Epoch 303 of 2500 took 0.055s
#   training loss:		1.006328
#   validation loss:		0.999837
# Epoch 304 of 2500 took 0.058s
#   training loss:		1.006503
#   validation loss:		0.999873
# Epoch 305 of 2500 took 0.060s
#   training loss:		1.006737
#   validation loss:		0.999938
# Epoch 306 of 2500 took 0.055s
#   training loss:		1.006438
#   validation loss:		0.999924
# Epoch 307 of 2500 took 0.054s
#   training loss:		1.006181
#   validation loss:		0.999539
# Epoch 308 of 2500 took 0.058s
#   training loss:		1.006373
#   validation loss:		0.999870
# Epoch 309 of 2500 took 0.057s
#   training loss:		1.006304
#   validation loss:		0.999626
# Epoch 310 of 2500 took 0.060s
#   training loss:		1.006001
#   validation loss:		0.999777
# Epoch 311 of 2500 took 0.058s
#   training loss:		1.005962
#   validation loss:		1.000063
# Epoch 312 of 2500 took 0.055s
#   training loss:		1.006083
#   validation loss:		1.000139
# Epoch 313 of 2500 took 0.057s
#   training loss:		1.006075
#   validation loss:		1.000049
# Epoch 314 of 2500 took 0.057s
#   training loss:		1.006119
#   validation loss:		0.999930
# Epoch 315 of 2500 took 0.058s
#   training loss:		1.006031
#   validation loss:		1.000109
# Epoch 316 of 2500 took 0.058s
#   training loss:		1.006133
#   validation loss:		0.999936
# Epoch 317 of 2500 took 0.056s
#   training loss:		1.006012
#   validation loss:		0.999308
# Epoch 318 of 2500 took 0.057s
#   training loss:		1.005896
#   validation loss:		0.999304
# Epoch 319 of 2500 took 0.061s
#   training loss:		1.006104
#   validation loss:		0.999854
# Epoch 320 of 2500 took 0.057s
#   training loss:		1.005794
#   validation loss:		0.999742
# Epoch 321 of 2500 took 0.060s
#   training loss:		1.005613
#   validation loss:		0.999398
# Epoch 322 of 2500 took 0.056s
#   training loss:		1.006039
#   validation loss:		0.999408
# Epoch 323 of 2500 took 0.057s
#   training loss:		1.005689
#   validation loss:		0.999435
# Epoch 324 of 2500 took 0.058s
#   training loss:		1.006383
#   validation loss:		0.998820
# Epoch 325 of 2500 took 0.056s
#   training loss:		1.005851
#   validation loss:		0.999470
# Epoch 326 of 2500 took 0.059s
#   training loss:		1.005737
#   validation loss:		0.999302
# Epoch 327 of 2500 took 0.059s
#   training loss:		1.005488
#   validation loss:		0.999220
# Epoch 328 of 2500 took 0.061s
#   training loss:		1.005531
#   validation loss:		0.999741
# Epoch 329 of 2500 took 0.057s
#   training loss:		1.005404
#   validation loss:		0.999149
# Epoch 330 of 2500 took 0.057s
#   training loss:		1.005267
#   validation loss:		0.998980
# Epoch 331 of 2500 took 0.058s
#   training loss:		1.005168
#   validation loss:		0.999132
# Epoch 332 of 2500 took 0.059s
#   training loss:		1.005173
#   validation loss:		0.999013
# Epoch 333 of 2500 took 0.056s
#   training loss:		1.005134
#   validation loss:		0.998772
# Epoch 334 of 2500 took 0.058s
#   training loss:		1.005195
#   validation loss:		0.998734
# Epoch 335 of 2500 took 0.057s
#   training loss:		1.005186
#   validation loss:		0.999337
# Epoch 336 of 2500 took 0.056s
#   training loss:		1.005169
#   validation loss:		0.999185
# Epoch 337 of 2500 took 0.053s
#   training loss:		1.005242
#   validation loss:		0.998473
# Epoch 338 of 2500 took 0.058s
#   training loss:		1.005286
#   validation loss:		0.998580
# Epoch 339 of 2500 took 0.056s
#   training loss:		1.004714
#   validation loss:		0.998906
# Epoch 340 of 2500 took 0.059s
#   training loss:		1.004741
#   validation loss:		0.998959
# Epoch 341 of 2500 took 0.056s
#   training loss:		1.004937
#   validation loss:		0.998824
# Epoch 342 of 2500 took 0.057s
#   training loss:		1.004543
#   validation loss:		0.998140
# Epoch 343 of 2500 took 0.055s
#   training loss:		1.004575
#   validation loss:		0.997934
# Epoch 344 of 2500 took 0.058s
#   training loss:		1.004531
#   validation loss:		0.998100
# Epoch 345 of 2500 took 0.057s
#   training loss:		1.004548
#   validation loss:		0.998723
# Epoch 346 of 2500 took 0.058s
#   training loss:		1.004545
#   validation loss:		0.998201
# Epoch 347 of 2500 took 0.059s
#   training loss:		1.004369
#   validation loss:		0.998427
# Epoch 348 of 2500 took 0.060s
#   training loss:		1.004233
#   validation loss:		0.998115
# Epoch 349 of 2500 took 0.055s
#   training loss:		1.003990
#   validation loss:		0.997667
# Epoch 350 of 2500 took 0.059s
#   training loss:		1.004648
#   validation loss:		0.997383
# Epoch 351 of 2500 took 0.060s
#   training loss:		1.004079
#   validation loss:		0.997954
# Epoch 352 of 2500 took 0.060s
#   training loss:		1.004507
#   validation loss:		0.998401
# Epoch 353 of 2500 took 0.057s
#   training loss:		1.003781
#   validation loss:		0.997665
# Epoch 354 of 2500 took 0.060s
#   training loss:		1.003952
#   validation loss:		0.997172
# Epoch 355 of 2500 took 0.058s
#   training loss:		1.003628
#   validation loss:		0.997205
# Epoch 356 of 2500 took 0.061s
#   training loss:		1.003943
#   validation loss:		0.997390
# Epoch 357 of 2500 took 0.056s
#   training loss:		1.003665
#   validation loss:		0.997658
# Epoch 358 of 2500 took 0.061s
#   training loss:		1.003869
#   validation loss:		0.997518
# Epoch 359 of 2500 took 0.058s
#   training loss:		1.003689
#   validation loss:		0.996649
# Epoch 360 of 2500 took 0.056s
#   training loss:		1.003275
#   validation loss:		0.996756
# Epoch 361 of 2500 took 0.055s
#   training loss:		1.003148
#   validation loss:		0.996942
# Epoch 362 of 2500 took 0.058s
#   training loss:		1.002971
#   validation loss:		0.997090
# Epoch 363 of 2500 took 0.062s
#   training loss:		1.003138
#   validation loss:		0.996654
# Epoch 364 of 2500 took 0.057s
#   training loss:		1.003184
#   validation loss:		0.996832
# Epoch 365 of 2500 took 0.054s
#   training loss:		1.002709
#   validation loss:		0.996352
# Epoch 366 of 2500 took 0.056s
#   training loss:		1.002603
#   validation loss:		0.996091
# Epoch 367 of 2500 took 0.057s
#   training loss:		1.002570
#   validation loss:		0.996074
# Epoch 368 of 2500 took 0.059s
#   training loss:		1.002562
#   validation loss:		0.996667
# Epoch 369 of 2500 took 0.057s
#   training loss:		1.002620
#   validation loss:		0.996592
# Epoch 370 of 2500 took 0.056s
#   training loss:		1.002353
#   validation loss:		0.995677
# Epoch 371 of 2500 took 0.055s
#   training loss:		1.001974
#   validation loss:		0.995340
# Epoch 372 of 2500 took 0.057s
#   training loss:		1.001766
#   validation loss:		0.995335
# Epoch 373 of 2500 took 0.057s
#   training loss:		1.001715
#   validation loss:		0.995858
# Epoch 374 of 2500 took 0.056s
#   training loss:		1.002034
#   validation loss:		0.995912
# Epoch 375 of 2500 took 0.058s
#   training loss:		1.001410
#   validation loss:		0.994857
# Epoch 376 of 2500 took 0.059s
#   training loss:		1.001183
#   validation loss:		0.994777
# Epoch 377 of 2500 took 0.058s
#   training loss:		1.001056
#   validation loss:		0.994468
# Epoch 378 of 2500 took 0.056s
#   training loss:		1.000923
#   validation loss:		0.994769
# Epoch 379 of 2500 took 0.055s
#   training loss:		1.000482
#   validation loss:		0.994457
# Epoch 380 of 2500 took 0.057s
#   training loss:		1.000567
#   validation loss:		0.994116
# Epoch 381 of 2500 took 0.056s
#   training loss:		1.000268
#   validation loss:		0.994042
# Epoch 382 of 2500 took 0.056s
#   training loss:		1.000163
#   validation loss:		0.994021
# Epoch 383 of 2500 took 0.057s
#   training loss:		0.999819
#   validation loss:		0.993821
# Epoch 384 of 2500 took 0.058s
#   training loss:		0.999648
#   validation loss:		0.993308
# Epoch 385 of 2500 took 0.057s
#   training loss:		0.999913
#   validation loss:		0.993320
# Epoch 386 of 2500 took 0.056s
#   training loss:		0.999220
#   validation loss:		0.992630
# Epoch 387 of 2500 took 0.056s
#   training loss:		0.999203
#   validation loss:		0.992576
# Epoch 388 of 2500 took 0.058s
#   training loss:		0.998979
#   validation loss:		0.992329
# Epoch 389 of 2500 took 0.057s
#   training loss:		0.998330
#   validation loss:		0.992349
# Epoch 390 of 2500 took 0.056s
#   training loss:		0.998558
#   validation loss:		0.992229
# Epoch 391 of 2500 took 0.054s
#   training loss:		0.998014
#   validation loss:		0.991991
# Epoch 392 of 2500 took 0.057s
#   training loss:		0.997588
#   validation loss:		0.991754
# Epoch 393 of 2500 took 0.056s
#   training loss:		0.997448
#   validation loss:		0.990999
# Epoch 394 of 2500 took 0.057s
#   training loss:		0.997266
#   validation loss:		0.991032
# Epoch 395 of 2500 took 0.057s
#   training loss:		0.996832
#   validation loss:		0.990382
# Epoch 396 of 2500 took 0.057s
#   training loss:		0.996408
#   validation loss:		0.990006
# Epoch 397 of 2500 took 0.056s
#   training loss:		0.996123
#   validation loss:		0.990084
# Epoch 398 of 2500 took 0.058s
#   training loss:		0.995838
#   validation loss:		0.989323
# Epoch 399 of 2500 took 0.055s
#   training loss:		0.995565
#   validation loss:		0.988683
# Epoch 400 of 2500 took 0.056s
#   training loss:		0.994990
#   validation loss:		0.988699
# Epoch 401 of 2500 took 0.057s
#   training loss:		0.994371
#   validation loss:		0.988625
# Epoch 402 of 2500 took 0.055s
#   training loss:		0.994009
#   validation loss:		0.987982
# Epoch 403 of 2500 took 0.056s
#   training loss:		0.993698
#   validation loss:		0.987529
# Epoch 404 of 2500 took 0.062s
#   training loss:		0.993289
#   validation loss:		0.986678
# Epoch 405 of 2500 took 0.055s
#   training loss:		0.992515
#   validation loss:		0.986306
# Epoch 406 of 2500 took 0.056s
#   training loss:		0.991959
#   validation loss:		0.985670
# Epoch 407 of 2500 took 0.058s
#   training loss:		0.991874
#   validation loss:		0.985592
# Epoch 408 of 2500 took 0.057s
#   training loss:		0.991131
#   validation loss:		0.984498
# Epoch 409 of 2500 took 0.056s
#   training loss:		0.990360
#   validation loss:		0.984086
# Epoch 410 of 2500 took 0.054s
#   training loss:		0.990135
#   validation loss:		0.983123
# Epoch 411 of 2500 took 0.057s
#   training loss:		0.989070
#   validation loss:		0.982551
# Epoch 412 of 2500 took 0.060s
#   training loss:		0.988247
#   validation loss:		0.982254
# Epoch 413 of 2500 took 0.056s
#   training loss:		0.987612
#   validation loss:		0.981707
# Epoch 414 of 2500 took 0.056s
#   training loss:		0.986924
#   validation loss:		0.980854
# Epoch 415 of 2500 took 0.059s
#   training loss:		0.986121
#   validation loss:		0.979279
# Epoch 416 of 2500 took 0.059s
#   training loss:		0.985147
#   validation loss:		0.978619
# Epoch 417 of 2500 took 0.056s
#   training loss:		0.984030
#   validation loss:		0.977874
# Epoch 418 of 2500 took 0.055s
#   training loss:		0.983473
#   validation loss:		0.976452
# Epoch 419 of 2500 took 0.057s
#   training loss:		0.982434
#   validation loss:		0.975350
# Epoch 420 of 2500 took 0.062s
#   training loss:		0.981492
#   validation loss:		0.975444
# Epoch 421 of 2500 took 0.065s
#   training loss:		0.979840
#   validation loss:		0.973365
# Epoch 422 of 2500 took 0.054s
#   training loss:		0.979179
#   validation loss:		0.971651
# Epoch 423 of 2500 took 0.064s
#   training loss:		0.977588
#   validation loss:		0.970718
# Epoch 424 of 2500 took 0.077s
#   training loss:		0.975866
#   validation loss:		0.969634
# Epoch 425 of 2500 took 0.058s
#   training loss:		0.974488
#   validation loss:		0.967532
# Epoch 426 of 2500 took 0.059s
#   training loss:		0.973065
#   validation loss:		0.966477
# Epoch 427 of 2500 took 0.059s
#   training loss:		0.970900
#   validation loss:		0.964210
# Epoch 428 of 2500 took 0.057s
#   training loss:		0.969206
#   validation loss:		0.962038
# Epoch 429 of 2500 took 0.058s
#   training loss:		0.967344
#   validation loss:		0.959690
# Epoch 430 of 2500 took 0.058s
#   training loss:		0.965182
#   validation loss:		0.958039
# Epoch 431 of 2500 took 0.057s
#   training loss:		0.962841
#   validation loss:		0.955673
# Epoch 432 of 2500 took 0.060s
#   training loss:		0.961079
#   validation loss:		0.953963
# Epoch 433 of 2500 took 0.058s
#   training loss:		0.957659
#   validation loss:		0.950297
# Epoch 434 of 2500 took 0.058s
#   training loss:		0.954853
#   validation loss:		0.947299
# Epoch 435 of 2500 took 0.066s
#   training loss:		0.951886
#   validation loss:		0.944540
# Epoch 436 of 2500 took 0.061s
#   training loss:		0.948780
#   validation loss:		0.942192
# Epoch 437 of 2500 took 0.057s
#   training loss:		0.945755
#   validation loss:		0.937982
# Epoch 438 of 2500 took 0.061s
#   training loss:		0.941698
#   validation loss:		0.933852
# Epoch 439 of 2500 took 0.059s
#   training loss:		0.937550
#   validation loss:		0.930036
# Epoch 440 of 2500 took 0.058s
#   training loss:		0.934095
#   validation loss:		0.925515
# Epoch 441 of 2500 took 0.057s
#   training loss:		0.929185
#   validation loss:		0.921678
# Epoch 442 of 2500 took 0.056s
#   training loss:		0.924592
#   validation loss:		0.916932
# Epoch 443 of 2500 took 0.059s
#   training loss:		0.919368
#   validation loss:		0.911396
# Epoch 444 of 2500 took 0.061s
#   training loss:		0.915915
#   validation loss:		0.905523
# Epoch 445 of 2500 took 0.058s
#   training loss:		0.909039
#   validation loss:		0.901964
# Epoch 446 of 2500 took 0.059s
#   training loss:		0.903719
#   validation loss:		0.895082
# Epoch 447 of 2500 took 0.057s
#   training loss:		0.896933
#   validation loss:		0.888189
# Epoch 448 of 2500 took 0.058s
#   training loss:		0.891089
#   validation loss:		0.881964
# Epoch 449 of 2500 took 0.057s
#   training loss:		0.885034
#   validation loss:		0.876374
# Epoch 450 of 2500 took 0.056s
#   training loss:		0.878721
#   validation loss:		0.869749
# Epoch 451 of 2500 took 0.059s
#   training loss:		0.872966
#   validation loss:		0.862703
# Epoch 452 of 2500 took 0.063s
#   training loss:		0.865570
#   validation loss:		0.857284
# Epoch 453 of 2500 took 0.068s
#   training loss:		0.860029
#   validation loss:		0.851634
# Epoch 454 of 2500 took 0.058s
#   training loss:		0.854164
#   validation loss:		0.844481
# Epoch 455 of 2500 took 0.092s
#   training loss:		0.848512
#   validation loss:		0.838289
# Epoch 456 of 2500 took 0.070s
#   training loss:		0.842754
#   validation loss:		0.832031
# Epoch 457 of 2500 took 0.064s
#   training loss:		0.836571
#   validation loss:		0.826661
# Epoch 458 of 2500 took 0.067s
#   training loss:		0.831333
#   validation loss:		0.820863
# Epoch 459 of 2500 took 0.069s
#   training loss:		0.824902
#   validation loss:		0.815666
# Epoch 460 of 2500 took 0.072s
#   training loss:		0.819824
#   validation loss:		0.808737
# Epoch 461 of 2500 took 0.057s
#   training loss:		0.814642
#   validation loss:		0.802845
# Epoch 462 of 2500 took 0.059s
#   training loss:		0.809076
#   validation loss:		0.796986
# Epoch 463 of 2500 took 0.059s
#   training loss:		0.803667
#   validation loss:		0.792024
# Epoch 464 of 2500 took 0.057s
#   training loss:		0.798451
#   validation loss:		0.787502
# Epoch 465 of 2500 took 0.059s
#   training loss:		0.794071
#   validation loss:		0.781612
# Epoch 466 of 2500 took 0.058s
#   training loss:		0.789477
#   validation loss:		0.776152
# Epoch 467 of 2500 took 0.058s
#   training loss:		0.785010
#   validation loss:		0.772149
# Epoch 468 of 2500 took 0.056s
#   training loss:		0.783644
#   validation loss:		0.765702
# Epoch 469 of 2500 took 0.054s
#   training loss:		0.775691
#   validation loss:		0.763067
# Epoch 470 of 2500 took 0.056s
#   training loss:		0.770836
#   validation loss:		0.756587
# Epoch 471 of 2500 took 0.060s
#   training loss:		0.766812
#   validation loss:		0.752360
# Epoch 472 of 2500 took 0.059s
#   training loss:		0.763422
#   validation loss:		0.747687
# Epoch 473 of 2500 took 0.058s
#   training loss:		0.760737
#   validation loss:		0.745119
# Epoch 474 of 2500 took 0.058s
#   training loss:		0.754968
#   validation loss:		0.739593
# Epoch 475 of 2500 took 0.060s
#   training loss:		0.751105
#   validation loss:		0.736523
# Epoch 476 of 2500 took 0.057s
#   training loss:		0.747026
#   validation loss:		0.733079
# Epoch 477 of 2500 took 0.058s
#   training loss:		0.744020
#   validation loss:		0.729475
# Epoch 478 of 2500 took 0.057s
#   training loss:		0.740836
#   validation loss:		0.726270
# Epoch 479 of 2500 took 0.060s
#   training loss:		0.737573
#   validation loss:		0.724175
# Epoch 480 of 2500 took 0.059s
#   training loss:		0.734762
#   validation loss:		0.720762
# Epoch 481 of 2500 took 0.057s
#   training loss:		0.732265
#   validation loss:		0.717539
# Epoch 482 of 2500 took 0.059s
#   training loss:		0.730097
#   validation loss:		0.715466
# Epoch 483 of 2500 took 0.059s
#   training loss:		0.726539
#   validation loss:		0.714183
# Epoch 484 of 2500 took 0.056s
#   training loss:		0.725312
#   validation loss:		0.710288
# Epoch 485 of 2500 took 0.058s
#   training loss:		0.721647
#   validation loss:		0.707350
# Epoch 486 of 2500 took 0.062s
#   training loss:		0.720051
#   validation loss:		0.705556
# Epoch 487 of 2500 took 0.070s
#   training loss:		0.716968
#   validation loss:		0.703743
# Epoch 488 of 2500 took 0.058s
#   training loss:		0.715031
#   validation loss:		0.700383
# Epoch 489 of 2500 took 0.060s
#   training loss:		0.712052
#   validation loss:		0.697583
# Epoch 490 of 2500 took 0.059s
#   training loss:		0.709989
#   validation loss:		0.695457
# Epoch 491 of 2500 took 0.059s
#   training loss:		0.707346
#   validation loss:		0.694095
# Epoch 492 of 2500 took 0.060s
#   training loss:		0.704470
#   validation loss:		0.690562
# Epoch 493 of 2500 took 0.057s
#   training loss:		0.701861
#   validation loss:		0.688308
# Epoch 494 of 2500 took 0.059s
#   training loss:		0.700007
#   validation loss:		0.685484
# Epoch 495 of 2500 took 0.058s
#   training loss:		0.696776
#   validation loss:		0.683638
# Epoch 496 of 2500 took 0.056s
#   training loss:		0.694173
#   validation loss:		0.680954
# Epoch 497 of 2500 took 0.056s
#   training loss:		0.690810
#   validation loss:		0.678282
# Epoch 498 of 2500 took 0.057s
#   training loss:		0.688344
#   validation loss:		0.675139
# Epoch 499 of 2500 took 0.059s
#   training loss:		0.685043
#   validation loss:		0.672201
# Epoch 500 of 2500 took 0.057s
#   training loss:		0.682926
#   validation loss:		0.669750
# Epoch 501 of 2500 took 0.059s
#   training loss:		0.679290
#   validation loss:		0.666743
# Epoch 502 of 2500 took 0.059s
#   training loss:		0.676831
#   validation loss:		0.664171
# Epoch 503 of 2500 took 0.059s
#   training loss:		0.673676
#   validation loss:		0.661164
# Epoch 504 of 2500 took 0.057s
#   training loss:		0.670937
#   validation loss:		0.658941
# Epoch 505 of 2500 took 0.058s
#   training loss:		0.667971
#   validation loss:		0.656137
# Epoch 506 of 2500 took 0.057s
#   training loss:		0.665437
#   validation loss:		0.653121
# Epoch 507 of 2500 took 0.060s
#   training loss:		0.662901
#   validation loss:		0.651157
# Epoch 508 of 2500 took 0.057s
#   training loss:		0.660092
#   validation loss:		0.647825
# Epoch 509 of 2500 took 0.059s
#   training loss:		0.657019
#   validation loss:		0.645715
# Epoch 510 of 2500 took 0.055s
#   training loss:		0.654443
#   validation loss:		0.642970
# Epoch 511 of 2500 took 0.065s
#   training loss:		0.652170
#   validation loss:		0.640691
# Epoch 512 of 2500 took 0.057s
#   training loss:		0.649502
#   validation loss:		0.637860
# Epoch 513 of 2500 took 0.056s
#   training loss:		0.648096
#   validation loss:		0.636320
# Epoch 514 of 2500 took 0.056s
#   training loss:		0.644620
#   validation loss:		0.633423
# Epoch 515 of 2500 took 0.059s
#   training loss:		0.642510
#   validation loss:		0.631364
# Epoch 516 of 2500 took 0.057s
#   training loss:		0.640329
#   validation loss:		0.629052
# Epoch 517 of 2500 took 0.056s
#   training loss:		0.638351
#   validation loss:		0.627289
# Epoch 518 of 2500 took 0.058s
#   training loss:		0.636959
#   validation loss:		0.625661
# Epoch 519 of 2500 took 0.060s
#   training loss:		0.635312
#   validation loss:		0.623018
# Epoch 520 of 2500 took 0.060s
#   training loss:		0.632429
#   validation loss:		0.621806
# Epoch 521 of 2500 took 0.059s
#   training loss:		0.631044
#   validation loss:		0.620076
# Epoch 522 of 2500 took 0.057s
#   training loss:		0.628802
#   validation loss:		0.617981
# Epoch 523 of 2500 took 0.057s
#   training loss:		0.627259
#   validation loss:		0.615834
# Epoch 524 of 2500 took 0.059s
#   training loss:		0.625428
#   validation loss:		0.614408
# Epoch 525 of 2500 took 0.059s
#   training loss:		0.624520
#   validation loss:		0.613247
# Epoch 526 of 2500 took 0.056s
#   training loss:		0.621991
#   validation loss:		0.610879
# Epoch 527 of 2500 took 0.057s
#   training loss:		0.620201
#   validation loss:		0.608698
# Epoch 528 of 2500 took 0.059s
#   training loss:		0.618470
#   validation loss:		0.607048
# Epoch 529 of 2500 took 0.059s
#   training loss:		0.616085
#   validation loss:		0.605148
# Epoch 530 of 2500 took 0.058s
#   training loss:		0.614108
#   validation loss:		0.603098
# Epoch 531 of 2500 took 0.058s
#   training loss:		0.611940
#   validation loss:		0.600325
# Epoch 532 of 2500 took 0.061s
#   training loss:		0.609221
#   validation loss:		0.597685
# Epoch 533 of 2500 took 0.062s
#   training loss:		0.606840
#   validation loss:		0.594197
# Epoch 534 of 2500 took 0.058s
#   training loss:		0.603160
#   validation loss:		0.591572
# Epoch 535 of 2500 took 0.057s
#   training loss:		0.599652
#   validation loss:		0.586953
# Epoch 536 of 2500 took 0.062s
#   training loss:		0.595454
#   validation loss:		0.583034
# Epoch 537 of 2500 took 0.063s
#   training loss:		0.591109
#   validation loss:		0.578596
# Epoch 538 of 2500 took 0.060s
#   training loss:		0.586483
#   validation loss:		0.573511
# Epoch 539 of 2500 took 0.057s
#   training loss:		0.582086
#   validation loss:		0.568029
# Epoch 540 of 2500 took 0.057s
#   training loss:		0.576701
#   validation loss:		0.563431
# Epoch 541 of 2500 took 0.057s
#   training loss:		0.571788
#   validation loss:		0.558788
# Epoch 542 of 2500 took 0.054s
#   training loss:		0.566182
#   validation loss:		0.553455
# Epoch 543 of 2500 took 0.061s
#   training loss:		0.561675
#   validation loss:		0.549292
# Epoch 544 of 2500 took 0.055s
#   training loss:		0.557478
#   validation loss:		0.545835
# Epoch 545 of 2500 took 0.055s
#   training loss:		0.553453
#   validation loss:		0.541392
# Epoch 546 of 2500 took 0.058s
#   training loss:		0.549939
#   validation loss:		0.538539
# Epoch 547 of 2500 took 0.060s
#   training loss:		0.546511
#   validation loss:		0.537016
# Epoch 548 of 2500 took 0.059s
#   training loss:		0.544020
#   validation loss:		0.533245
# Epoch 549 of 2500 took 0.057s
#   training loss:		0.541398
#   validation loss:		0.531418
# Epoch 550 of 2500 took 0.056s
#   training loss:		0.539067
#   validation loss:		0.529032
# Epoch 551 of 2500 took 0.061s
#   training loss:		0.537553
#   validation loss:		0.527618
# Epoch 552 of 2500 took 0.057s
#   training loss:		0.535452
#   validation loss:		0.525931
# Epoch 553 of 2500 took 0.057s
#   training loss:		0.533724
#   validation loss:		0.524462
# Epoch 554 of 2500 took 0.058s
#   training loss:		0.531830
#   validation loss:		0.523160
# Epoch 555 of 2500 took 0.059s
#   training loss:		0.529126
#   validation loss:		0.520192
# Epoch 556 of 2500 took 0.058s
#   training loss:		0.527737
#   validation loss:		0.518467
# Epoch 557 of 2500 took 0.058s
#   training loss:		0.525575
#   validation loss:		0.517531
# Epoch 558 of 2500 took 0.055s
#   training loss:		0.522911
#   validation loss:		0.514664
# Epoch 559 of 2500 took 0.058s
# ...
#   validation loss:		0.129781
# Epoch 2318 of 2500 took 0.058s
#   training loss:		0.136010
#   validation loss:		0.129342
# Epoch 2319 of 2500 took 0.062s
#   training loss:		0.133777
#   validation loss:		0.130717
# Epoch 2320 of 2500 took 0.059s
#   training loss:		0.132969
#   validation loss:		0.130172
# Epoch 2321 of 2500 took 0.056s
#   training loss:		0.132241
#   validation loss:		0.133453
# Epoch 2322 of 2500 took 0.063s
#   training loss:		0.134662
#   validation loss:		0.131259
# Epoch 2323 of 2500 took 0.054s
#   training loss:		0.133337
#   validation loss:		0.131218
# Epoch 2324 of 2500 took 0.058s
#   training loss:		0.133771
#   validation loss:		0.130144
# Epoch 2325 of 2500 took 0.056s
#   training loss:		0.134443
#   validation loss:		0.136928
# Epoch 2326 of 2500 took 0.057s
#   training loss:		0.142155
#   validation loss:		0.136236
# Epoch 2327 of 2500 took 0.055s
#   training loss:		0.136455
#   validation loss:		0.129548
# Epoch 2328 of 2500 took 0.059s
#   training loss:		0.133672
#   validation loss:		0.132573
# Epoch 2329 of 2500 took 0.058s
#   training loss:		0.132899
#   validation loss:		0.129679
# Epoch 2330 of 2500 took 0.057s
#   training loss:		0.133872
#   validation loss:		0.129986
# Epoch 2331 of 2500 took 0.054s
#   training loss:		0.133854
#   validation loss:		0.130081
# Epoch 2332 of 2500 took 0.061s
#   training loss:		0.138507
#   validation loss:		0.131911
# Epoch 2333 of 2500 took 0.056s
#   training loss:		0.141708
#   validation loss:		0.129855
# Epoch 2334 of 2500 took 0.058s
#   training loss:		0.135801
#   validation loss:		0.134390
# Epoch 2335 of 2500 took 0.056s
#   training loss:		0.135734
#   validation loss:		0.131694
# Epoch 2336 of 2500 took 0.061s
#   training loss:		0.132488
#   validation loss:		0.132508
# Epoch 2337 of 2500 took 0.058s
#   training loss:		0.132084
#   validation loss:		0.130581
# Epoch 2338 of 2500 took 0.056s
#   training loss:		0.132233
#   validation loss:		0.129241
# Epoch 2339 of 2500 took 0.058s
#   training loss:		0.132398
#   validation loss:		0.130841
# Epoch 2340 of 2500 took 0.069s
#   training loss:		0.137405
#   validation loss:		0.140308
# Epoch 2341 of 2500 took 0.056s
#   training loss:		0.138010
#   validation loss:		0.133856
# Epoch 2342 of 2500 took 0.058s
#   training loss:		0.133106
#   validation loss:		0.127395
# Epoch 2343 of 2500 took 0.080s
#   training loss:		0.138462
#   validation loss:		0.134078
# Epoch 2344 of 2500 took 0.070s
#   training loss:		0.136033
#   validation loss:		0.130590
# Epoch 2345 of 2500 took 0.062s
#   training loss:		0.134037
#   validation loss:		0.128471
# Epoch 2346 of 2500 took 0.077s
#   training loss:		0.133981
#   validation loss:		0.131261
# Epoch 2347 of 2500 took 0.058s
#   training loss:		0.133588
#   validation loss:		0.129465
# Epoch 2348 of 2500 took 0.062s
#   training loss:		0.132391
#   validation loss:		0.128574
# Epoch 2349 of 2500 took 0.057s
#   training loss:		0.133347
#   validation loss:		0.128569
# Epoch 2350 of 2500 took 0.054s
#   training loss:		0.132884
#   validation loss:		0.130450
# Epoch 2351 of 2500 took 0.060s
#   training loss:		0.133313
#   validation loss:		0.130308
# Epoch 2352 of 2500 took 0.056s
#   training loss:		0.132717
#   validation loss:		0.128778
# Epoch 2353 of 2500 took 0.057s
#   training loss:		0.132923
#   validation loss:		0.128765
# Epoch 2354 of 2500 took 0.057s
#   training loss:		0.132068
#   validation loss:		0.130505
# Epoch 2355 of 2500 took 0.060s
#   training loss:		0.136285
#   validation loss:		0.129522
# Epoch 2356 of 2500 took 0.065s
#   training loss:		0.133955
#   validation loss:		0.129808
# Epoch 2357 of 2500 took 0.065s
#   training loss:		0.134327
#   validation loss:		0.129546
# Epoch 2358 of 2500 took 0.057s
#   training loss:		0.132208
#   validation loss:		0.129350
# Epoch 2359 of 2500 took 0.060s
#   training loss:		0.133437
#   validation loss:		0.133876
# Epoch 2360 of 2500 took 0.064s
#   training loss:		0.134988
#   validation loss:		0.131504
# Epoch 2361 of 2500 took 0.060s
#   training loss:		0.133881
#   validation loss:		0.130189
# Epoch 2362 of 2500 took 0.055s
#   training loss:		0.132746
#   validation loss:		0.130376
# Epoch 2363 of 2500 took 0.067s
#   training loss:		0.134119
#   validation loss:		0.129234
# Epoch 2364 of 2500 took 0.061s
#   training loss:		0.132954
#   validation loss:		0.129061
# Epoch 2365 of 2500 took 0.060s
#   training loss:		0.132641
#   validation loss:		0.128492
# Epoch 2366 of 2500 took 0.055s
#   training loss:		0.132268
#   validation loss:		0.129187
# Epoch 2367 of 2500 took 0.066s
#   training loss:		0.133800
#   validation loss:		0.129378
# Epoch 2368 of 2500 took 0.065s
#   training loss:		0.134353
#   validation loss:		0.128584
# Epoch 2369 of 2500 took 0.057s
#   training loss:		0.132910
#   validation loss:		0.129193
# Epoch 2370 of 2500 took 0.059s
#   training loss:		0.132517
#   validation loss:		0.129734
# Epoch 2371 of 2500 took 0.063s
#   training loss:		0.136942
#   validation loss:		0.131102
# Epoch 2372 of 2500 took 0.072s
#   training loss:		0.132683
#   validation loss:		0.128571
# Epoch 2373 of 2500 took 0.070s
#   training loss:		0.132118
#   validation loss:		0.130504
# Epoch 2374 of 2500 took 0.067s
#   training loss:		0.133895
#   validation loss:		0.132339
# Epoch 2375 of 2500 took 0.078s
#   training loss:		0.139220
#   validation loss:		0.131539
# Epoch 2376 of 2500 took 0.073s
#   training loss:		0.139757
#   validation loss:		0.130374
# Epoch 2377 of 2500 took 0.067s
#   training loss:		0.133128
#   validation loss:		0.132891
# Epoch 2378 of 2500 took 0.076s
#   training loss:		0.134094
#   validation loss:		0.132087
# Epoch 2379 of 2500 took 0.080s
#   training loss:		0.134717
#   validation loss:		0.130230
# Epoch 2380 of 2500 took 0.075s
#   training loss:		0.133555
#   validation loss:		0.133200
# Epoch 2381 of 2500 took 0.073s
#   training loss:		0.132556
#   validation loss:		0.129303
# Epoch 2382 of 2500 took 0.064s
#   training loss:		0.132565
#   validation loss:		0.129864
# Epoch 2383 of 2500 took 0.061s
#   training loss:		0.134262
#   validation loss:		0.128026
# Epoch 2384 of 2500 took 0.059s
#   training loss:		0.132178
#   validation loss:		0.130687
# Epoch 2385 of 2500 took 0.061s
#   training loss:		0.132768
#   validation loss:		0.130037
# Epoch 2386 of 2500 took 0.057s
#   training loss:		0.133776
#   validation loss:		0.129055
# Epoch 2387 of 2500 took 0.054s
#   training loss:		0.134667
#   validation loss:		0.132007
# Epoch 2388 of 2500 took 0.065s
#   training loss:		0.133006
#   validation loss:		0.130225
# Epoch 2389 of 2500 took 0.057s
#   training loss:		0.132704
#   validation loss:		0.129363
# Epoch 2390 of 2500 took 0.061s
#   training loss:		0.136002
#   validation loss:		0.135254
# Epoch 2391 of 2500 took 0.055s
#   training loss:		0.135722
#   validation loss:		0.131631
# Epoch 2392 of 2500 took 0.061s
#   training loss:		0.132555
#   validation loss:		0.129839
# Epoch 2393 of 2500 took 0.061s
#   training loss:		0.133593
#   validation loss:		0.130680
# Epoch 2394 of 2500 took 0.059s
#   training loss:		0.133155
#   validation loss:		0.128134
# Epoch 2395 of 2500 took 0.054s
#   training loss:		0.133840
#   validation loss:		0.129518
# Epoch 2396 of 2500 took 0.061s
#   training loss:		0.134221
#   validation loss:		0.132040
# Epoch 2397 of 2500 took 0.058s
#   training loss:		0.133622
#   validation loss:		0.131062
# Epoch 2398 of 2500 took 0.057s
#   training loss:		0.133115
#   validation loss:		0.129057
# Epoch 2399 of 2500 took 0.056s
#   training loss:		0.131809
#   validation loss:		0.129739
# Epoch 2400 of 2500 took 0.059s
#   training loss:		0.133188
#   validation loss:		0.132708
# Epoch 2401 of 2500 took 0.060s
#   training loss:		0.137209
#   validation loss:		0.131184
# Epoch 2402 of 2500 took 0.059s
#   training loss:		0.134739
#   validation loss:		0.131126
# Epoch 2403 of 2500 took 0.058s
#   training loss:		0.133961
#   validation loss:		0.132359
# Epoch 2404 of 2500 took 0.073s
#   training loss:		0.132585
#   validation loss:		0.129540
# Epoch 2405 of 2500 took 0.069s
#   training loss:		0.132690
#   validation loss:		0.128076
# Epoch 2406 of 2500 took 0.056s
#   training loss:		0.133370
#   validation loss:		0.129276
# Epoch 2407 of 2500 took 0.075s
#   training loss:		0.132607
#   validation loss:		0.131225
# Epoch 2408 of 2500 took 0.061s
#   training loss:		0.134171
#   validation loss:		0.129491
# Epoch 2409 of 2500 took 0.056s
#   training loss:		0.132534
#   validation loss:		0.129266
# Epoch 2410 of 2500 took 0.058s
#   training loss:		0.132488
#   validation loss:		0.132599
# Epoch 2411 of 2500 took 0.055s
#   training loss:		0.133880
#   validation loss:		0.132573
# Epoch 2412 of 2500 took 0.062s
#   training loss:		0.134440
#   validation loss:		0.130270
# Epoch 2413 of 2500 took 0.056s
#   training loss:		0.131856
#   validation loss:		0.130629
# Epoch 2414 of 2500 took 0.056s
#   training loss:		0.135190
#   validation loss:		0.131691
# Epoch 2415 of 2500 took 0.054s
#   training loss:		0.132039
#   validation loss:		0.129237
# Epoch 2416 of 2500 took 0.058s
#   training loss:		0.133190
#   validation loss:		0.130105
# Epoch 2417 of 2500 took 0.061s
#   training loss:		0.131935
#   validation loss:		0.129796
# Epoch 2418 of 2500 took 0.057s
#   training loss:		0.133704
#   validation loss:		0.138859
# Epoch 2419 of 2500 took 0.054s
#   training loss:		0.134369
#   validation loss:		0.128967
# Epoch 2420 of 2500 took 0.059s
#   training loss:		0.132920
#   validation loss:		0.127135
# Epoch 2421 of 2500 took 0.057s
#   training loss:		0.133023
#   validation loss:		0.128398
# Epoch 2422 of 2500 took 0.056s
#   training loss:		0.132694
#   validation loss:		0.128158
# Epoch 2423 of 2500 took 0.054s
#   training loss:		0.137030
#   validation loss:		0.130863
# Epoch 2424 of 2500 took 0.061s
#   training loss:		0.134487
#   validation loss:		0.130122
# Epoch 2425 of 2500 took 0.059s
#   training loss:		0.131933
#   validation loss:		0.132436
# Epoch 2426 of 2500 took 0.055s
#   training loss:		0.134660
#   validation loss:		0.129861
# Epoch 2427 of 2500 took 0.054s
#   training loss:		0.132923
#   validation loss:		0.129905
# Epoch 2428 of 2500 took 0.058s
#   training loss:		0.132166
#   validation loss:		0.128673
# Epoch 2429 of 2500 took 0.057s
#   training loss:		0.131426
#   validation loss:		0.128177
# Epoch 2430 of 2500 took 0.056s
#   training loss:		0.133715
#   validation loss:		0.133360
# Epoch 2431 of 2500 took 0.053s
#   training loss:		0.135581
#   validation loss:		0.128776
# Epoch 2432 of 2500 took 0.057s
#   training loss:		0.131348
#   validation loss:		0.129198
# Epoch 2433 of 2500 took 0.066s
#   training loss:		0.132504
#   validation loss:		0.130015
# Epoch 2434 of 2500 took 0.058s
#   training loss:		0.131759
#   validation loss:		0.129241
# Epoch 2435 of 2500 took 0.053s
#   training loss:		0.132727
#   validation loss:		0.128739
# Epoch 2436 of 2500 took 0.059s
#   training loss:		0.133194
#   validation loss:		0.131208
# Epoch 2437 of 2500 took 0.056s
#   training loss:		0.134990
#   validation loss:		0.148103
# Epoch 2438 of 2500 took 0.060s
#   training loss:		0.145120
#   validation loss:		0.128840
# Epoch 2439 of 2500 took 0.053s
#   training loss:		0.135664
#   validation loss:		0.127679
# Epoch 2440 of 2500 took 0.059s
#   training loss:		0.134908
#   validation loss:		0.129615
# Epoch 2441 of 2500 took 0.059s
#   training loss:		0.131549
#   validation loss:		0.128407
# Epoch 2442 of 2500 took 0.057s
#   training loss:		0.131533
#   validation loss:		0.131964
# Epoch 2443 of 2500 took 0.054s
#   training loss:		0.134827
#   validation loss:		0.131463
# Epoch 2444 of 2500 took 0.063s
#   training loss:		0.134910
#   validation loss:		0.129283
# Epoch 2445 of 2500 took 0.058s
#   training loss:		0.131714
#   validation loss:		0.130337
# Epoch 2446 of 2500 took 0.058s
#   training loss:		0.133124
#   validation loss:		0.129524
# Epoch 2447 of 2500 took 0.054s
#   training loss:		0.131586
#   validation loss:		0.129896
# Epoch 2448 of 2500 took 0.059s
#   training loss:		0.134277
#   validation loss:		0.131315
# Epoch 2449 of 2500 took 0.058s
#   training loss:		0.132399
#   validation loss:		0.128814
# Epoch 2450 of 2500 took 0.056s
#   training loss:		0.132139
#   validation loss:		0.131134
# Epoch 2451 of 2500 took 0.054s
#   training loss:		0.133550
#   validation loss:		0.129708
# Epoch 2452 of 2500 took 0.057s
#   training loss:		0.133259
#   validation loss:		0.141108
# Epoch 2453 of 2500 took 0.059s
#   training loss:		0.145123
#   validation loss:		0.132981
# Epoch 2454 of 2500 took 0.057s
#   training loss:		0.135355
#   validation loss:		0.129177
# Epoch 2455 of 2500 took 0.053s
#   training loss:		0.132439
#   validation loss:		0.129793
# Epoch 2456 of 2500 took 0.060s
#   training loss:		0.133358
#   validation loss:		0.128520
# Epoch 2457 of 2500 took 0.058s
#   training loss:		0.132859
#   validation loss:		0.130728
# Epoch 2458 of 2500 took 0.056s
#   training loss:		0.135263
#   validation loss:		0.128846
# Epoch 2459 of 2500 took 0.054s
#   training loss:		0.134923
#   validation loss:		0.130529
# Epoch 2460 of 2500 took 0.057s
#   training loss:		0.132295
#   validation loss:		0.129203
# Epoch 2461 of 2500 took 0.060s
#   training loss:		0.132387
#   validation loss:		0.129297
# Epoch 2462 of 2500 took 0.057s
#   training loss:		0.131619
#   validation loss:		0.128988
# Epoch 2463 of 2500 took 0.056s
#   training loss:		0.131751
#   validation loss:		0.130411
# Epoch 2464 of 2500 took 0.057s
#   training loss:		0.134907
#   validation loss:		0.129005
# Epoch 2465 of 2500 took 0.058s
#   training loss:		0.132510
#   validation loss:		0.128338
# Epoch 2466 of 2500 took 0.058s
#   training loss:		0.133067
#   validation loss:		0.129684
# Epoch 2467 of 2500 took 0.057s
#   training loss:		0.132364
#   validation loss:		0.127524
# Epoch 2468 of 2500 took 0.057s
#   training loss:		0.131312
#   validation loss:		0.128976
# Epoch 2469 of 2500 took 0.061s
#   training loss:		0.132071
#   validation loss:		0.128099
# Epoch 2470 of 2500 took 0.059s
#   training loss:		0.132234
#   validation loss:		0.130268
# Epoch 2471 of 2500 took 0.054s
#   training loss:		0.133239
#   validation loss:		0.131409
# Epoch 2472 of 2500 took 0.062s
#   training loss:		0.134435
#   validation loss:		0.128127
# Epoch 2473 of 2500 took 0.061s
#   training loss:		0.133659
#   validation loss:		0.133116
# Epoch 2474 of 2500 took 0.058s
#   training loss:		0.133548
#   validation loss:		0.128544
# Epoch 2475 of 2500 took 0.054s
#   training loss:		0.134037
#   validation loss:		0.134853
# Epoch 2476 of 2500 took 0.060s
#   training loss:		0.136542
#   validation loss:		0.130018
# Epoch 2477 of 2500 took 0.057s
#   training loss:		0.131989
#   validation loss:		0.128297
# Epoch 2478 of 2500 took 0.058s
#   training loss:		0.132789
#   validation loss:		0.130250
# Epoch 2479 of 2500 took 0.055s
#   training loss:		0.131660
#   validation loss:		0.128717
# Epoch 2480 of 2500 took 0.060s
#   training loss:		0.135202
#   validation loss:		0.131416
# Epoch 2481 of 2500 took 0.057s
#   training loss:		0.134048
#   validation loss:		0.129744
# Epoch 2482 of 2500 took 0.057s
#   training loss:		0.131760
#   validation loss:		0.129859
# Epoch 2483 of 2500 took 0.054s
#   training loss:		0.132775
#   validation loss:		0.129992
# Epoch 2484 of 2500 took 0.058s
#   training loss:		0.132187
#   validation loss:		0.131926
# Epoch 2485 of 2500 took 0.058s
#   training loss:		0.133073
#   validation loss:		0.128313
# Epoch 2486 of 2500 took 0.059s
#   training loss:		0.133105
#   validation loss:		0.132396
# Epoch 2487 of 2500 took 0.053s
#   training loss:		0.140479
#   validation loss:		0.131377
# Epoch 2488 of 2500 took 0.057s
#   training loss:		0.135800
#   validation loss:		0.129445
# Epoch 2489 of 2500 took 0.060s
#   training loss:		0.133591
#   validation loss:		0.129412
# Epoch 2490 of 2500 took 0.056s
#   training loss:		0.132146
#   validation loss:		0.135184
# Epoch 2491 of 2500 took 0.053s
#   training loss:		0.135958
#   validation loss:		0.143358
# Epoch 2492 of 2500 took 0.057s
#   training loss:		0.135207
#   validation loss:		0.130246
# Epoch 2493 of 2500 took 0.059s
#   training loss:		0.135233
#   validation loss:		0.136826
# Epoch 2494 of 2500 took 0.056s
#   training loss:		0.140275
#   validation loss:		0.129370
# Epoch 2495 of 2500 took 0.055s
#   training loss:		0.132831
#   validation loss:		0.128911
# Epoch 2496 of 2500 took 0.058s
#   training loss:		0.132870
#   validation loss:		0.132226
# Epoch 2497 of 2500 took 0.059s
#   training loss:		0.133750
#   validation loss:		0.131706
# Epoch 2498 of 2500 took 0.056s
#   training loss:		0.133461
#   validation loss:		0.129433
# Epoch 2499 of 2500 took 0.054s
#   training loss:		0.133515
#   validation loss:		0.128570
# Epoch 2500 of 2500 took 0.056s
#   training loss:		0.134556
#   validation loss:		0.129090
# Final results:
#   test loss:			0.125681

# %%
npdata = np.load('data4/num_accident_OH_norm2.npy')
output = lasagne.layers.get_output(network, inputs= npdata[2016:2352, 0:-1].reshape(336,1,8)).eval()
prediction = np.zeros(336)
prediction = output.reshape(336)
week = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
i = 0
plt.figure(figsize = (10.5,4))
plt.plot(prediction[0:144], color='r')
plt.plot(npdata[2016:2160, -1], color = 'k')
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 3:
    plt.text(24+i*48, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1
plt.savefig('image/LSTM1_fit_1.eps',format="eps",transparent=True, bbox_inches='tight', pad_inches=0.1)

plt.figure(figsize = (14,4))
plt.plot(prediction[144:], color='r')
plt.plot(npdata[2160:2353, -1], color = 'k')
plt.xlabel('time slot')
plt.ylabel('Number of accident (normalised)')
while i < 7:
    plt.text(i*48-120, 3.0, week[i], ha='center', va='bottom',fontsize = 12)
    i+=1

# %%
epoch = range(2500)
plt.figure()
plt.plot(epoch, train_loss, label = 'train loss')
plt.plot(epoch, val_loss, label = 'val loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('epoch')
plt.ylabel('error')
